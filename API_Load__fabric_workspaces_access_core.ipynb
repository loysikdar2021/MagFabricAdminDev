# %%
# DO NOT DELETE THIS CELL

# ***IMPORTANT***: This is a work in progress! These results are filtered . See line 69 for the query and pay attention to the WHERE clause.

# API Name: Workspaces - List Workspace Access Details
# Command:  GET https://api.fabric.microsoft.com/v1/admin/workspaces/{workspaceId}/users
# Doc:      https://learn.microsoft.com/en-us/rest/api/fabric/admin/workspaces/list-workspace-access-details

# Note: this queries the [fabric_workspaces] table to get a list of [workspaceId] values for the API calls.

# Loads tables: fabric_workspaces_access_core
# Loads tables: fabric_workspaces_access_users
# Loads tables: fabric_workspaces_access_groups
# Loads tables: fabric_workspaces_access_service_principals
# Loads tables: fabric_workspaces_access_service_principal_profiles
# Out:
# StatementMeta(, 19f02840-53b3-4187-a034-d02b3e514cb5, 9, Finished, Available, Finished)

# %%
# CELL 1 - Title and Introduction
# ==================================
# Microsoft Fabric Workspace Access Details to Delta Lake - PySpark Notebook
# This notebook retrieves Microsoft Fabric workspace access details for multiple workspaces
# and loads them into Delta Lake tables with optimization for analytics workloads using a multi-table approach
# Process: Query lakehouse for workspace IDs → Process each workspace sequentially → Load to Delta tables
# ==================================


# CELL 2 - Import Libraries
# ==================================
# Import required libraries
import requests
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_timestamp, lit, from_json, when, isnotnull
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
import logging
from typing import Dict, List, Optional
from delta.tables import DeltaTable
import random
import time
# ==================================


# CELL 3 - Configure Logging and Initialize Spark
# ==================================
# Configure logging
# This helps us track what's happening in our code and debug issues
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize Spark Session with Delta Lake configurations
# In Fabric notebooks, Spark is pre-configured with Delta support
spark = SparkSession.builder \
    .appName("FabricWorkspaceAccessDetailsToDelta") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Set optimal configurations for Delta operations
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "true")
spark.conf.set("spark.databricks.delta.autoCompact.enabled", "true")
# ==================================


# CELL 4 - Configuration Parameters
# ==================================
# Configuration Parameters
# These are the settings we'll use throughout the notebook
CONFIG = {
    "API_BASE_URL": "https://api.fabric.microsoft.com/v1",
    "WORKSPACE_ACCESS_ENDPOINT": "/admin/workspaces/{workspaceId}/users",  # Endpoint for workspace access details
    "MAX_RETRIES": 5,  # Increased number of retries for handling rate limits
    "INITIAL_BACKOFF_SEC": 1,  # Initial backoff time in seconds
    "MAX_BACKOFF_SEC": 60,  # Maximum backoff time in seconds
    "BACKOFF_FACTOR": 2,  # Exponential backoff multiplier
    "JITTER_FACTOR": 0.1,  # Random jitter to add to backoff (as a fraction)
    "TIMEOUT": 30,  # API request timeout in seconds
    # Multi-table approach for different principal types
    "ACCESS_CORE_TABLE_NAME": "fabric_workspaces_access_core",  # Core access table
    "ACCESS_USERS_TABLE_NAME": "fabric_workspaces_access_users",  # User details table
    "ACCESS_GROUPS_TABLE_NAME": "fabric_workspaces_access_groups",  # Group details table
    "ACCESS_SERVICE_PRINCIPALS_TABLE_NAME": "fabric_workspaces_access_service_principals",  # Service principal details table
    "ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME": "fabric_workspaces_access_service_principal_profiles",  # Service principal profile details table
    "LAKEHOUSE_PATH": "Tables",  # Default Tables folder in Fabric Lakehouse
    "DEBUG_MODE": True,  # Set to True to enable extra debugging output
    # Workspace query parameters
    "WORKSPACE_QUERY": """
    SELECT 
    fw.id
    FROM 
    FabricAdmin_Lakehouse.dbo.fabric_capacities AS fc
    JOIN 
    FabricAdmin_Lakehouse.dbo.fabric_workspaces AS fw
    ON UPPER(fc.id) = fw.capacityId  -- Join on capacityId
    WHERE 
    fc.displayName = 'MDA Institutional Capacity - PROD'  -- Filter for specific displayName
    AND fw.state = 'Active'  -- Filter for active workspaces
    AND fw.type <> 'Personal'  -- Exclude personal workspaces
ORDER BY
    fw.name
    """,
    # Rate limiting - API allows 200 requests per hour
    "INTER_WORKSPACE_DELAY_SEC": 5,  # Wait 20 seconds between workspace API calls to respect rate limits
}

logger.info("Configuration initialized successfully")
# ==================================


# CELL 5 - Authentication Function
# ==================================
def get_access_token():
    """
    Get Azure AD access token for Fabric API authentication.
    
    In a Fabric notebook, the token is automatically available through mssparkutils.
    This function retrieves the token that's needed to authenticate with the Fabric REST API.
    
    Returns:
        str: The access token
    
    Note:
        mssparkutils is a utility library provided by Microsoft Fabric
        that handles authentication automatically.
    """
    try:
        # In Fabric notebooks, we can get the token using mssparkutils
        from notebookutils import mssparkutils
        token_response = mssparkutils.credentials.getToken("https://api.fabric.microsoft.com")
        return token_response
    except Exception as e:
        logger.error(f"Failed to get access token: {str(e)}")
        raise
# ==================================


# CELL 6 - Workspace Query Function
# ==================================
def get_workspace_ids_from_lakehouse() -> List[str]:
    """
    Query the lakehouse to get the list of workspace IDs to process.
    
    This function executes the SQL query against the fabric_workspaces table
    to retrieve workspace IDs that match our criteria:
    - Active state
    - Not Personal workspaces
    - Specific capacity ID
    
    Returns:
        List[str]: List of workspace IDs to process
    
    Raises:
        Exception: If the query fails or returns no results
    """
    logger.info("Querying lakehouse for workspace IDs...")
    
    try:
        # Execute the query to get workspace IDs
        workspace_df = spark.sql(CONFIG["WORKSPACE_QUERY"])
        
        # Convert to list of workspace IDs
        workspace_ids = [row['id'] for row in workspace_df.collect()]
        
        logger.info(f"Found {len(workspace_ids)} workspaces to process")
        
        if CONFIG['DEBUG_MODE'] and workspace_ids:
            logger.info(f"First few workspace IDs: {workspace_ids[:5]}")
        
        if not workspace_ids:
            logger.warning("No workspaces found matching the criteria. Please check the query and data.")
            return []
        
        return workspace_ids
        
    except Exception as e:
        logger.error(f"Failed to query workspace IDs from lakehouse: {str(e)}")
        logger.error("Please ensure the FabricAdmin_Lakehouse and fabric_workspaces table exist and are accessible")
        raise
# ==================================


# CELL 7 - API Call Function
# ==================================
def call_fabric_api(endpoint: str, access_token: str, params: Optional[Dict] = None) -> Dict:
    """
    Make a REST API call to Microsoft Fabric with advanced rate limit handling.
    
    This function handles the HTTP request to the Fabric API, including:
    - Setting up authentication headers
    - Managing retries with intelligent backoff for rate limiting (429 errors)
    - Implementing jitter to avoid synchronized retries
    - Detailed error handling and logging
    
    Args:
        endpoint: The API endpoint path (e.g., "/admin/workspaces/{workspaceId}/users")
        access_token: The Azure AD access token
        params: Optional query parameters for the API call
    
    Returns:
        dict: The JSON response from the API
    
    Raises:
        requests.exceptions.RequestException: If the API call fails after all retries
    """
    url = f"{CONFIG['API_BASE_URL']}{endpoint}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    # Initialize backoff time
    backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
    
    # Retry logic with intelligent backoff
    for attempt in range(CONFIG['MAX_RETRIES']):
        try:
            # Log the full URL with parameters for debugging
            logger.info(f"Making API call to: {url} with params: {params} (Attempt {attempt + 1})")
            
            response = requests.get(
                url,
                headers=headers,
                params=params,
                timeout=CONFIG['TIMEOUT']
            )
            
            # Log the response status for debugging
            logger.info(f"Response status: {response.status_code}")
            
            # Rate limit handling (429 Too Many Requests)
            if response.status_code == 429:
                # Get retry-after header if available, otherwise use our backoff
                retry_after = response.headers.get('Retry-After')
                
                if retry_after and retry_after.isdigit():
                    # If server specified a wait time, use it
                    wait_time = int(retry_after)
                else:
                    # Calculate wait time with exponential backoff and jitter
                    jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                    wait_time = backoff_time + jitter
                    # Update backoff for next attempt
                    backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.warning(f"Rate limit exceeded (429). Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
                continue  # Skip to next retry attempt without raising exception
            
            # Log the response for debugging in case of errors
            if response.status_code >= 400:
                logger.error(f"API error: Status {response.status_code}, Response: {response.text}")
                logger.error(f"Request URL: {response.request.url}")
                logger.error(f"Request headers: {response.request.headers}")
            
            # For all other status codes, use raise_for_status to handle
            response.raise_for_status()
            
            # If we get here, the request was successful
            # Reset backoff for next API call (not next attempt)
            backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
            
            # Log a sample of the response content for debugging
            try:
                response_json = response.json()
                if "accessDetails" in response_json and isinstance(response_json["accessDetails"], list):
                    logger.info(f"Response contains {len(response_json['accessDetails'])} items in 'accessDetails' array")
                return response_json
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse response as JSON: {str(e)}")
                logger.error(f"Response content: {response.text[:1000]}")  # Log first 1000 chars of response
                raise
            
        except requests.exceptions.RequestException as e:
            last_attempt = attempt == CONFIG['MAX_RETRIES'] - 1
            
            # Special handling for non-429 errors
            if not (hasattr(e, 'response') and e.response is not None and e.response.status_code == 429):
                logger.warning(f"API call failed (Attempt {attempt + 1}): {str(e)}")
                
                if last_attempt:
                    logger.error(f"All retry attempts failed for endpoint: {endpoint}")
                    logger.error(f"Final error: {str(e)}")
                    raise
                
                # Calculate wait time with exponential backoff and jitter
                jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                wait_time = backoff_time + jitter
                # Update backoff for next attempt
                backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.info(f"Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
# ==================================


# CELL 8 - Get Workspace Access Details Function
# ==================================
def get_workspace_access_details(access_token: str, workspace_id: str) -> List[Dict]:
    """
    Retrieve workspace access details for a specific workspace from the Fabric API.
    
    This function makes a request to the List Workspace Access Details API endpoint
    to get all users, groups, and service principals that have access to the workspace.
    
    Args:
        access_token: The Azure AD access token
        workspace_id: The workspace ID to get access details for
    
    Returns:
        list: A list of all access detail objects containing principal and workspace access information
    """
    logger.info(f"Retrieving access details for workspace: {workspace_id}")
    
    # Construct the endpoint with the workspace ID
    endpoint = CONFIG['WORKSPACE_ACCESS_ENDPOINT'].format(workspaceId=workspace_id)
    
    try:
        # Make the API call
        response_data = call_fabric_api(endpoint, access_token)
        
        # Log the response structure for debugging
        if CONFIG['DEBUG_MODE']:
            logger.info(f"Response keys: {list(response_data.keys())}")
        
        # Extract access details from the response
        access_details = response_data.get("accessDetails", [])
        
        if access_details:
            logger.info(f"Retrieved {len(access_details)} access details for workspace {workspace_id}")
            
            # Log first access detail for debugging
            if CONFIG['DEBUG_MODE'] and access_details:
                logger.info(f"Sample access detail: {json.dumps(access_details[0], indent=2)}")
        else:
            logger.warning(f"No access details found for workspace {workspace_id}")
        
        return access_details
        
    except requests.exceptions.RequestException as e:
        logger.error(f"API call failed for workspace {workspace_id}: {str(e)}")
        # Re-raise the exception so calling function can handle it
        raise
# ==================================


# CELL 9 - Create Core Access DataFrame Function
# ==================================
def create_core_access_dataframe(access_details: List[Dict], workspace_id: str) -> "DataFrame":
    """
    Convert the access details data into a core access PySpark DataFrame.
    
    This function creates the main access table containing the core information
    that's common across all principal types.
    
    Args:
        access_details: List of access detail dictionaries from the API
        workspace_id: The workspace ID this data relates to
    
    Returns:
        DataFrame: A PySpark DataFrame with core access information
    """
    logger.info("Creating core access DataFrame")
    
    # Extract core access information from each access detail
    core_access_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        workspace_access = access_detail.get("workspaceAccessDetails", {})
        
        core_record = {
            "workspace_id": workspace_id,
            "principal_id": principal.get("id"),
            "principal_display_name": principal.get("displayName"),
            "principal_type": principal.get("type"),
            "workspace_role": workspace_access.get("workspaceRole"),
            "workspace_type": workspace_access.get("type")
        }
        core_access_data.append(core_record)
    
    # Define the schema for the core access table
    schema = StructType([
        StructField("workspace_id", StringType(), False),
        StructField("principal_id", StringType(), False),
        StructField("principal_display_name", StringType(), True),
        StructField("principal_type", StringType(), False),
        StructField("workspace_role", StringType(), True),
        StructField("workspace_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not core_access_data:
        logger.warning("No access details found. Creating empty core DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        core_df = spark.createDataFrame(empty_rdd, schema)
        return core_df
    
    # Convert to pandas DataFrame first, then to Spark DataFrame
    pandas_df = pd.DataFrame(core_access_data)
    
    # Create the initial Spark DataFrame
    required_columns = ["workspace_id", "principal_id", "principal_display_name", "principal_type", "workspace_role", "workspace_type"]
    
    # Ensure all columns exist in the pandas DataFrame
    for col_name in required_columns:
        if col_name not in pandas_df.columns:
            pandas_df[col_name] = None
    
    spark_df = spark.createDataFrame(pandas_df[required_columns])
    
    # Add metadata column for tracking when this data was extracted
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created core access DataFrame with {enhanced_df.count()} records")
    return enhanced_df
# ==================================


# CELL 10 - Create Principal-Specific DataFrames Functions
# ==================================
def create_user_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for user principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with user-specific details
    """
    logger.info("Creating user details DataFrame")
    
    user_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process User principals
        if principal.get("type") == "User":
            user_details = principal.get("userDetails", {})
            
            user_record = {
                "principal_id": principal.get("id"),
                "user_principal_name": user_details.get("userPrincipalName")
            }
            user_details_data.append(user_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("user_principal_name", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not user_details_data:
        logger.info("No user principals found. Creating empty user details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        user_df = spark.createDataFrame(empty_rdd, schema)
        return user_df
    
    pandas_df = pd.DataFrame(user_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created user details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_group_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for group principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with group-specific details
    """
    logger.info("Creating group details DataFrame")
    
    group_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process Group principals
        if principal.get("type") == "Group":
            group_details = principal.get("groupDetails", {})
            
            group_record = {
                "principal_id": principal.get("id"),
                "group_type": group_details.get("groupType")
            }
            group_details_data.append(group_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("group_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not group_details_data:
        logger.info("No group principals found. Creating empty group details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        group_df = spark.createDataFrame(empty_rdd, schema)
        return group_df
    
    pandas_df = pd.DataFrame(group_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created group details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_service_principal_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for service principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with service principal-specific details
    """
    logger.info("Creating service principal details DataFrame")
    
    sp_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process ServicePrincipal principals
        if principal.get("type") == "ServicePrincipal":
            sp_details = principal.get("servicePrincipalDetails", {})
            
            sp_record = {
                "principal_id": principal.get("id"),
                "aad_app_id": sp_details.get("aadAppId")
            }
            sp_details_data.append(sp_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("aad_app_id", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not sp_details_data:
        logger.info("No service principals found. Creating empty service principal details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        sp_df = spark.createDataFrame(empty_rdd, schema)
        return sp_df
    
    pandas_df = pd.DataFrame(sp_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created service principal details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_service_principal_profile_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for service principal profile details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with service principal profile-specific details
    """
    logger.info("Creating service principal profile details DataFrame")
    
    spp_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process ServicePrincipalProfile principals
        if principal.get("type") == "ServicePrincipalProfile":
            spp_details = principal.get("servicePrincipalProfileDetails", {})
            parent_principal = spp_details.get("parentPrincipal", {})
            
            spp_record = {
                "principal_id": principal.get("id"),
                "parent_principal_id": parent_principal.get("id"),
                "parent_principal_display_name": parent_principal.get("displayName"),
                "parent_principal_type": parent_principal.get("type")
            }
            spp_details_data.append(spp_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("parent_principal_id", StringType(), True),
        StructField("parent_principal_display_name", StringType(), True),
        StructField("parent_principal_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not spp_details_data:
        logger.info("No service principal profiles found. Creating empty service principal profile details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        spp_df = spark.createDataFrame(empty_rdd, schema)
        return spp_df
    
    pandas_df = pd.DataFrame(spp_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created service principal profile details DataFrame with {enhanced_df.count()} records")
    return enhanced_df
# ==================================


# CELL 11 - Delta Lake Operations Functions
# ==================================
def ensure_delta_table_exists(table_name: str, df_schema):
    """
    Ensure the Delta table exists, creating it if necessary.
    
    Args:
        table_name: Name of the Delta table
        df_schema: Schema of the DataFrame
    """
    try:
        # Check if table exists
        spark.sql(f"DESCRIBE TABLE {table_name}")
        logger.info(f"Delta table '{table_name}' already exists")
    except Exception:
        # Table doesn't exist, create it
        logger.info(f"Creating Delta table '{table_name}'")
        
        # Create an empty DataFrame with the schema
        empty_df = spark.createDataFrame([], df_schema)
        
        # Create the Delta table
        empty_df.write \
            .mode("overwrite") \
            .option("overwriteSchema", "true") \
            .saveAsTable(table_name)
        
        logger.info(f"Delta table '{table_name}' created successfully")


def merge_core_access_data_to_delta(source_df, table_name: str):
    """
    Merge new core access data into the Delta table using MERGE operation.
    
    This function performs an upsert operation:
    - Updates existing records if workspace_id + principal_id matches
    - Inserts new records if the combination doesn't exist
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    source_df.createOrReplaceTempView("access_updates")
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Perform the merge operation (composite key: workspace_id + principal_id)
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING access_updates AS source
    ON target.workspace_id = source.workspace_id AND target.principal_id = source.principal_id
    WHEN MATCHED THEN
        UPDATE SET 
            target.principal_display_name = source.principal_display_name,
            target.principal_type = source.principal_type,
            target.workspace_role = source.workspace_role,
            target.workspace_type = source.workspace_type,
            target.last_updated_timestamp = source.last_updated_timestamp
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    spark.sql(merge_query)
    logger.info("Core access merge operation completed successfully")


def merge_principal_details_to_delta(source_df, table_name: str):
    """
    Merge principal-specific details into the Delta table using MERGE operation.
    
    This function performs an upsert operation based on principal_id.
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    temp_view_name = f"{table_name.replace('fabric_', '')}_updates"
    source_df.createOrReplaceTempView(temp_view_name)
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Get column names excluding principal_id and last_updated_timestamp for dynamic UPDATE SET
    columns = [col for col in source_df.columns if col not in ['principal_id', 'last_updated_timestamp']]
    update_set_clause = ", ".join([f"target.{col} = source.{col}" for col in columns])
    update_set_clause += ", target.last_updated_timestamp = source.last_updated_timestamp"
    
    # Perform the merge operation
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING {temp_view_name} AS source
    ON target.principal_id = source.principal_id
    WHEN MATCHED THEN
        UPDATE SET {update_set_clause}
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    spark.sql(merge_query)
    logger.info(f"Principal details merge operation completed successfully for {table_name}")


def optimize_delta_table(table_name: str):
    """
    Optimize the Delta table for better query performance.
    
    Args:
        table_name: Name of the Delta table to optimize
    """
    logger.info(f"Optimizing Delta table '{table_name}'")
    
    try:
        # Update table statistics for better query planning
        spark.sql(f"ANALYZE TABLE {table_name} COMPUTE STATISTICS")
        logger.info(f"Table statistics updated successfully for {table_name}")
        
        logger.info(f"Delta table optimization completed for {table_name}")
    except Exception as e:
        logger.warning(f"Table optimization step encountered an issue for {table_name}: {str(e)}")
        logger.info("Continuing with process - optimization is not critical for functionality")
# ==================================


# CELL 12 - Process Single Workspace Function
# ==================================
def process_single_workspace(access_token: str, workspace_id: str) -> Dict:
    """
    Process a single workspace: get access details, create DataFrames, and load to Delta tables.
    
    This function handles the complete workflow for one workspace:
    1. Call the API to get workspace access details
    2. Create DataFrames for different principal types
    3. Ensure Delta tables exist with proper schemas
    4. Merge data into Delta tables
    5. Optimize tables for performance
    
    Args:
        access_token: The Azure AD access token
        workspace_id: The workspace ID to process
    
    Returns:
        Dict: Summary of processing results including record counts
    
    Raises:
        Exception: If critical errors occur during processing
    """
    logger.info(f"=== PROCESSING WORKSPACE: {workspace_id} ===")
    processing_start_time = time.time()
    
    try:
        # Step 1: Retrieve workspace access details from API
        logger.info(f"Step 1: Retrieving access details for workspace {workspace_id}...")
        access_details = get_workspace_access_details(access_token, workspace_id)
        
        if not access_details:
            logger.warning(f"No access details found for workspace {workspace_id}. Skipping.")
            return {
                "workspace_id": workspace_id,
                "status": "skipped",
                "reason": "no_access_details",
                "processing_time_sec": time.time() - processing_start_time
            }
        
        # Step 2: Create DataFrames for different principal types
        logger.info(f"Step 2: Creating DataFrames for {len(access_details)} access details...")
        
        # Core access DataFrame (always created)
        core_access_df = create_core_access_dataframe(access_details, workspace_id)
        
        # Principal-specific DataFrames (only created if data exists)
        user_details_df = create_user_details_dataframe(access_details)
        group_details_df = create_group_details_dataframe(access_details)
        sp_details_df = create_service_principal_details_dataframe(access_details)
        spp_details_df = create_service_principal_profile_details_dataframe(access_details)
        
        # Step 3: Process each table (ensure exists, merge data, optimize)
        logger.info("Step 3: Processing Delta tables...")
        
        table_configs = [
            (CONFIG["ACCESS_CORE_TABLE_NAME"], core_access_df, merge_core_access_data_to_delta),
            (CONFIG["ACCESS_USERS_TABLE_NAME"], user_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_GROUPS_TABLE_NAME"], group_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_SERVICE_PRINCIPALS_TABLE_NAME"], sp_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME"], spp_details_df, merge_principal_details_to_delta)
        ]
        
        record_counts = {}
        
        for table_name, df, merge_function in table_configs:
            logger.info(f"Processing table: {table_name}")
            
            # Ensure table exists
            ensure_delta_table_exists(table_name, df.schema)
            
            # Merge data if DataFrame has records
            df_count = df.count()
            record_counts[table_name] = df_count
            
            if df_count > 0:
                merge_function(df, table_name)
                logger.info(f"Successfully merged {df_count} records into {table_name}")
            else:
                logger.info(f"No data to merge for {table_name}")
            
            # Optimize the table (non-critical operation)
            optimize_delta_table(table_name)
        
        # Step 4: Log processing summary for this workspace
        processing_time = time.time() - processing_start_time
        logger.info(f"=== WORKSPACE {workspace_id} COMPLETED SUCCESSFULLY ===")
        logger.info(f"Processing time: {processing_time:.2f} seconds")
        logger.info(f"Record counts: {record_counts}")
        
        return {
            "workspace_id": workspace_id,
            "status": "success",
            "record_counts": record_counts,
            "processing_time_sec": processing_time
        }
        
    except Exception as e:
        processing_time = time.time() - processing_start_time
        logger.error(f"=== ERROR PROCESSING WORKSPACE {workspace_id} ===")
        logger.error(f"Error: {str(e)}")
        logger.error(f"Processing time before error: {processing_time:.2f} seconds")
        
        # Return error details but don't re-raise - let main function handle continuation
        return {
            "workspace_id": workspace_id,
            "status": "error",
            "error": str(e),
            "processing_time_sec": processing_time
        }
# ==================================


# CELL 13 - Main Execution Function
# ==================================
def main():
    """
    Main execution function that orchestrates the entire multi-workspace process.
    
    This function:
    1. Gets the authentication token
    2. Queries the lakehouse for workspace IDs to process
    3. Processes each workspace sequentially:
       - Calls the API for workspace access details
       - Creates DataFrames for different principal types
       - Loads data into Delta Lake tables using merge operations
       - Optimizes tables for analytics performance
    4. Provides comprehensive reporting on processing results
    
    The function processes workspaces one at a time to respect API rate limits
    and ensure data consistency. It continues processing even if individual
    workspaces encounter errors.
    
    Returns:
        List[Dict]: Summary of processing results for all workspaces
    """
    overall_start_time = time.time()
    logger.info("=== STARTING FABRIC WORKSPACE ACCESS DETAILS TO DELTA LAKE PROCESS ===")
    
    try:
        # Step 1: Get authentication token
        logger.info("Step 1: Getting access token...")
        access_token = get_access_token()
        logger.info("Successfully obtained access token")
        
        # Step 2: Get workspace IDs from lakehouse
        logger.info("Step 2: Querying lakehouse for workspace IDs...")
        workspace_ids = get_workspace_ids_from_lakehouse()
        
        if not workspace_ids:
            logger.error("No workspace IDs found. Exiting.")
            return []
        
        logger.info(f"Found {len(workspace_ids)} workspaces to process")
        
        # Step 3: Process each workspace sequentially
        logger.info("Step 3: Processing workspaces sequentially...")
        processing_results = []
        successful_workspaces = 0
        failed_workspaces = 0
        skipped_workspaces = 0
        
        for i, workspace_id in enumerate(workspace_ids, 1):
            logger.info(f"\n--- Processing workspace {i} of {len(workspace_ids)}: {workspace_id} ---")
            
            try:
                # Process the workspace
                result = process_single_workspace(access_token, workspace_id)
                processing_results.append(result)
                
                # Track results
                if result["status"] == "success":
                    successful_workspaces += 1
                elif result["status"] == "error":
                    failed_workspaces += 1
                elif result["status"] == "skipped":
                    skipped_workspaces += 1
                
                # Rate limiting: Wait between API calls to respect the 200 requests/hour limit
                # Only wait if this is not the last workspace
                if i < len(workspace_ids):
                    logger.info(f"Waiting {CONFIG['INTER_WORKSPACE_DELAY_SEC']} seconds before next workspace (rate limiting)...")
                    time.sleep(CONFIG['INTER_WORKSPACE_DELAY_SEC'])
                
            except Exception as e:
                # Log the error but continue with next workspace
                logger.error(f"Unexpected error processing workspace {workspace_id}: {str(e)}")
                failed_workspaces += 1
                processing_results.append({
                    "workspace_id": workspace_id,
                    "status": "error",
                    "error": f"Unexpected error: {str(e)}",
                    "processing_time_sec": 0
                })
        
        # Step 4: Generate comprehensive final report
        overall_processing_time = time.time() - overall_start_time
        logger.info("\n" + "="*80)
        logger.info("=== FINAL PROCESSING REPORT ===")
        logger.info("="*80)
        logger.info(f"Total workspaces processed: {len(workspace_ids)}")
        logger.info(f"Successful: {successful_workspaces}")
        logger.info(f"Failed: {failed_workspaces}")
        logger.info(f"Skipped: {skipped_workspaces}")
        logger.info(f"Overall processing time: {overall_processing_time:.2f} seconds ({overall_processing_time/60:.1f} minutes)")
        
        # Detailed results by status
        if successful_workspaces > 0:
            logger.info(f"\n=== SUCCESSFUL WORKSPACES ({successful_workspaces}) ===")
            successful_results = [r for r in processing_results if r["status"] == "success"]
            for result in successful_results:
                total_records = sum(result.get("record_counts", {}).values())
                logger.info(f"  {result['workspace_id']}: {total_records} total records, {result['processing_time_sec']:.1f}s")
        
        if failed_workspaces > 0:
            logger.info(f"\n=== FAILED WORKSPACES ({failed_workspaces}) ===")
            failed_results = [r for r in processing_results if r["status"] == "error"]
            for result in failed_results:
                logger.info(f"  {result['workspace_id']}: {result.get('error', 'Unknown error')}")
        
        if skipped_workspaces > 0:
            logger.info(f"\n=== SKIPPED WORKSPACES ({skipped_workspaces}) ===")
            skipped_results = [r for r in processing_results if r["status"] == "skipped"]
            for result in skipped_results:
                logger.info(f"  {result['workspace_id']}: {result.get('reason', 'Unknown reason')}")
        
        # Step 5: Display final table statistics and analytics
        logger.info("\n=== FINAL TABLE STATISTICS ===")
        table_names = [
            CONFIG["ACCESS_CORE_TABLE_NAME"],
            CONFIG["ACCESS_USERS_TABLE_NAME"],
            CONFIG["ACCESS_GROUPS_TABLE_NAME"],
            CONFIG["ACCESS_SERVICE_PRINCIPALS_TABLE_NAME"],
            CONFIG["ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME"]
        ]
        
        for table_name in table_names:
            try:
                row_count = spark.table(table_name).count()
                logger.info(f"  {table_name}: {row_count:,} total rows")
            except Exception as e:
                logger.warning(f"  {table_name}: Could not get count - {str(e)}")
        
        # Step 6: Sample analytics queries
        logger.info("\n=== SAMPLE ANALYTICS ===")
        try:
            # Overall summary across all workspaces
            overall_summary = spark.sql(f"""
                SELECT 
                    COUNT(DISTINCT workspace_id) as total_workspaces_with_access,
                    COUNT(*) as total_access_grants,
                    COUNT(DISTINCT principal_id) as unique_principals,
                    COUNT(DISTINCT principal_type) as unique_principal_types
                FROM {CONFIG["ACCESS_CORE_TABLE_NAME"]}
            """)
            
            logger.info("Overall summary across all processed workspaces:")
            overall_summary.show(truncate=False)
            
            # Principal type distribution
            principal_type_summary = spark.sql(f"""
                SELECT 
                    principal_type,
                    workspace_role,
                    COUNT(*) as count,
                    COUNT(DISTINCT workspace_id) as workspaces_count
                FROM {CONFIG["ACCESS_CORE_TABLE_NAME"]}
                GROUP BY principal_type, workspace_role
                ORDER BY principal_type, workspace_role
            """)
            
            logger.info("Principal type and role distribution:")
            principal_type_summary.show(truncate=False)
            
        except Exception as e:
            logger.warning(f"Could not generate final analytics: {str(e)}")
        
        logger.info("="*80)
        logger.info("=== PROCESS COMPLETED ===")
        logger.info("="*80)
        
        return processing_results
        
    except Exception as e:
        overall_processing_time = time.time() - overall_start_time
        logger.error(f"Critical error in main execution: {str(e)}")
        logger.error(f"Total processing time before error: {overall_processing_time:.2f} seconds")
        raise
# ==================================


# CELL 14 - Execute Main Function
# ==================================
# Execute the main function
if __name__ == "__main__":
    # Run the main process to handle all workspaces
    results = main()
    
    # Optional: Store results for further analysis
    # You can uncomment the following lines to save results to a DataFrame
    # if results:
    #     results_df = spark.createDataFrame(pd.DataFrame(results))
    #     results_df.write.mode("overwrite").saveAsTable("fabric_workspace_access_processing_results")
    #     logger.info("Processing results saved to table: fabric_workspace_access_processing_results")
# ==================================
# Out:
# StatementMeta(, 19f02840-53b3-4187-a034-d02b3e514cb5, 10, Finished, Available, Finished)
# 2025-07-16 17:46:04,668 - INFO - Configuration initialized successfully
# 2025-07-16 17:46:04,672 - INFO - === STARTING FABRIC WORKSPACE ACCESS DETAILS TO DELTA LAKE PROCESS ===
# 2025-07-16 17:46:04,673 - INFO - Step 1: Getting access token...
# 2025-07-16 17:46:04,678 - INFO - Successfully obtained access token
# 2025-07-16 17:46:04,678 - INFO - Step 2: Querying lakehouse for workspace IDs...
# 2025-07-16 17:46:04,679 - INFO - Querying lakehouse for workspace IDs...
# 2025-07-16 17:46:07,692 - INFO - Found 33 workspaces to process
# 2025-07-16 17:46:07,692 - INFO - First few workspace IDs: ['3dc16785-8298-4567-880a-9919f074555f', '6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba', '122d675e-1ec9-497d-9709-7084a5bcf3ae', '263575b7-d1ee-4dcc-bd05-ca67158e1bb4', 'cd9d5418-e35d-400e-938d-ea91ea486e07']
# 2025-07-16 17:46:07,693 - INFO - Found 33 workspaces to process
# 2025-07-16 17:46:07,694 - INFO - Step 3: Processing workspaces sequentially...
# 2025-07-16 17:46:07,694 - INFO -
# --- Processing workspace 1 of 33: 3dc16785-8298-4567-880a-9919f074555f ---
# 2025-07-16 17:46:07,695 - INFO - === PROCESSING WORKSPACE: 3dc16785-8298-4567-880a-9919f074555f ===
# 2025-07-16 17:46:07,695 - INFO - Step 1: Retrieving access details for workspace 3dc16785-8298-4567-880a-9919f074555f...
# 2025-07-16 17:46:07,695 - INFO - Retrieving access details for workspace: 3dc16785-8298-4567-880a-9919f074555f
# 2025-07-16 17:46:07,696 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/3dc16785-8298-4567-880a-9919f074555f/users with params: None (Attempt 1)
# 2025-07-16 17:46:08,039 - INFO - Response status: 200
# 2025-07-16 17:46:08,040 - INFO - Response contains 4 items in 'accessDetails' array
# 2025-07-16 17:46:08,043 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:46:08,043 - INFO - Retrieved 4 access details for workspace 3dc16785-8298-4567-880a-9919f074555f
# 2025-07-16 17:46:08,044 - INFO - Sample access detail: {
#   "principal": {
#     "id": "b947c95e-d487-4c9a-96af-502ab9908072",
#     "displayName": "Jarrod Eska",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "JSEska@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:46:08,045 - INFO - Step 2: Creating DataFrames for 4 access details...
# 2025-07-16 17:46:08,045 - INFO - Creating core access DataFrame
# 2025-07-16 17:46:09,701 - INFO - Created core access DataFrame with 4 records
# 2025-07-16 17:46:09,702 - INFO - Creating user details DataFrame
# 2025-07-16 17:46:09,802 - INFO - Created user details DataFrame with 2 records
# 2025-07-16 17:46:09,803 - INFO - Creating group details DataFrame
# 2025-07-16 17:46:09,888 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:46:09,889 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:46:09,889 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:46:09,920 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:46:09,921 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:46:09,937 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:46:09,937 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:46:11,336 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:46:11,419 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:46:24,133 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:46:24,133 - INFO - Successfully merged 4 records into fabric_workspaces_access_core
# 2025-07-16 17:46:24,134 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:46:26,462 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:46:26,462 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:46:26,463 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:46:27,880 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:46:27,961 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:46:34,501 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:46:34,501 - INFO - Successfully merged 2 records into fabric_workspaces_access_users
# 2025-07-16 17:46:34,502 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:46:36,543 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:46:36,544 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:46:36,545 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:46:38,019 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:46:38,067 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:46:46,380 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:46:46,381 - INFO - Successfully merged 2 records into fabric_workspaces_access_groups
# 2025-07-16 17:46:46,382 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:46:48,733 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:46:48,733 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:46:48,734 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:46:49,461 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:46:49,540 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:46:49,541 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:46:51,124 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:46:51,125 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:46:51,125 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:46:51,574 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:46:51,662 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:46:51,663 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:46:53,458 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:46:53,458 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:46:53,459 - INFO - === WORKSPACE 3dc16785-8298-4567-880a-9919f074555f COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:46:53,460 - INFO - Processing time: 45.76 seconds
# 2025-07-16 17:46:53,460 - INFO - Record counts: {'fabric_workspaces_access_core': 4, 'fabric_workspaces_access_users': 2, 'fabric_workspaces_access_groups': 2, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:46:53,461 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:46:58,461 - INFO -
# --- Processing workspace 2 of 33: 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba ---
# 2025-07-16 17:46:58,462 - INFO - === PROCESSING WORKSPACE: 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba ===
# 2025-07-16 17:46:58,463 - INFO - Step 1: Retrieving access details for workspace 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba...
# 2025-07-16 17:46:58,463 - INFO - Retrieving access details for workspace: 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba
# 2025-07-16 17:46:58,463 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/users with params: None (Attempt 1)
# 2025-07-16 17:46:58,766 - INFO - Response status: 200
# 2025-07-16 17:46:58,767 - INFO - Response contains 15 items in 'accessDetails' array
# 2025-07-16 17:46:58,770 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:46:58,771 - INFO - Retrieved 15 access details for workspace 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba
# 2025-07-16 17:46:58,771 - INFO - Sample access detail: {
#   "principal": {
#     "id": "99d560e2-5d13-442f-a25d-6e7e1d9f697f",
#     "displayName": "Hui Zhu",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "HZhu6@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:46:58,772 - INFO - Step 2: Creating DataFrames for 15 access details...
# 2025-07-16 17:46:58,772 - INFO - Creating core access DataFrame
# 2025-07-16 17:46:58,850 - INFO - Created core access DataFrame with 15 records
# 2025-07-16 17:46:58,851 - INFO - Creating user details DataFrame
# 2025-07-16 17:46:58,917 - INFO - Created user details DataFrame with 10 records
# 2025-07-16 17:46:58,918 - INFO - Creating group details DataFrame
# 2025-07-16 17:46:59,042 - INFO - Created group details DataFrame with 5 records
# 2025-07-16 17:46:59,043 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:46:59,043 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:46:59,061 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:46:59,062 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:46:59,078 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:46:59,079 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:46:59,225 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:46:59,288 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:47:08,605 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:47:08,606 - INFO - Successfully merged 15 records into fabric_workspaces_access_core
# 2025-07-16 17:47:08,607 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:47:11,740 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:47:11,741 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:47:11,741 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:47:11,866 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:47:11,918 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:47:19,932 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:47:19,933 - INFO - Successfully merged 10 records into fabric_workspaces_access_users
# 2025-07-16 17:47:19,934 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:47:21,842 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:47:21,843 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:47:21,843 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:47:21,957 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:47:22,005 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:47:25,158 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:47:25,158 - INFO - Successfully merged 5 records into fabric_workspaces_access_groups
# 2025-07-16 17:47:25,159 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:47:26,971 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:47:26,972 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:47:26,972 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:47:27,079 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:47:27,125 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:27,126 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:47:27,700 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:27,700 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:27,701 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:27,824 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:47:27,859 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:27,860 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:47:28,397 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:28,398 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:28,398 - INFO - === WORKSPACE 6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:47:28,399 - INFO - Processing time: 29.94 seconds
# 2025-07-16 17:47:28,399 - INFO - Record counts: {'fabric_workspaces_access_core': 15, 'fabric_workspaces_access_users': 10, 'fabric_workspaces_access_groups': 5, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:47:28,400 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:47:33,400 - INFO -
# --- Processing workspace 3 of 33: 122d675e-1ec9-497d-9709-7084a5bcf3ae ---
# 2025-07-16 17:47:33,401 - INFO - === PROCESSING WORKSPACE: 122d675e-1ec9-497d-9709-7084a5bcf3ae ===
# 2025-07-16 17:47:33,402 - INFO - Step 1: Retrieving access details for workspace 122d675e-1ec9-497d-9709-7084a5bcf3ae...
# 2025-07-16 17:47:33,402 - INFO - Retrieving access details for workspace: 122d675e-1ec9-497d-9709-7084a5bcf3ae
# 2025-07-16 17:47:33,403 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/users with params: None (Attempt 1)
# 2025-07-16 17:47:33,649 - INFO - Response status: 200
# 2025-07-16 17:47:33,650 - INFO - Response contains 4 items in 'accessDetails' array
# 2025-07-16 17:47:33,653 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:47:33,654 - INFO - Retrieved 4 access details for workspace 122d675e-1ec9-497d-9709-7084a5bcf3ae
# 2025-07-16 17:47:33,654 - INFO - Sample access detail: {
#   "principal": {
#     "id": "99d560e2-5d13-442f-a25d-6e7e1d9f697f",
#     "displayName": "Hui Zhu",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "HZhu6@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:47:33,655 - INFO - Step 2: Creating DataFrames for 4 access details...
# 2025-07-16 17:47:33,655 - INFO - Creating core access DataFrame
# 2025-07-16 17:47:33,739 - INFO - Created core access DataFrame with 4 records
# 2025-07-16 17:47:33,740 - INFO - Creating user details DataFrame
# 2025-07-16 17:47:33,808 - INFO - Created user details DataFrame with 1 records
# 2025-07-16 17:47:33,808 - INFO - Creating group details DataFrame
# 2025-07-16 17:47:33,880 - INFO - Created group details DataFrame with 3 records
# 2025-07-16 17:47:33,881 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:47:33,881 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:47:33,897 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:47:33,897 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:47:33,913 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:47:33,914 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:47:34,068 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:47:34,122 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:47:37,693 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:47:37,694 - INFO - Successfully merged 4 records into fabric_workspaces_access_core
# 2025-07-16 17:47:37,695 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:47:39,526 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:47:39,527 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:47:39,527 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:47:39,650 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:47:39,692 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:47:43,017 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:47:43,017 - INFO - Successfully merged 1 records into fabric_workspaces_access_users
# 2025-07-16 17:47:43,018 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:47:44,798 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:47:44,799 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:47:44,799 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:47:44,926 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:47:44,980 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:47:48,514 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:47:48,515 - INFO - Successfully merged 3 records into fabric_workspaces_access_groups
# 2025-07-16 17:47:48,516 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:47:50,435 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:47:50,436 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:47:50,436 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:47:50,546 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:47:50,579 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:50,580 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:47:51,207 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:51,208 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:47:51,209 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:51,319 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:47:51,350 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:51,351 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:47:51,940 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:51,941 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:47:51,941 - INFO - === WORKSPACE 122d675e-1ec9-497d-9709-7084a5bcf3ae COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:47:51,941 - INFO - Processing time: 18.54 seconds
# 2025-07-16 17:47:51,942 - INFO - Record counts: {'fabric_workspaces_access_core': 4, 'fabric_workspaces_access_users': 1, 'fabric_workspaces_access_groups': 3, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:47:51,943 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:47:56,943 - INFO -
# --- Processing workspace 4 of 33: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4 ---
# 2025-07-16 17:47:56,944 - INFO - === PROCESSING WORKSPACE: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4 ===
# 2025-07-16 17:47:56,944 - INFO - Step 1: Retrieving access details for workspace 263575b7-d1ee-4dcc-bd05-ca67158e1bb4...
# 2025-07-16 17:47:56,945 - INFO - Retrieving access details for workspace: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-07-16 17:47:56,945 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/263575b7-d1ee-4dcc-bd05-ca67158e1bb4/users with params: None (Attempt 1)
# 2025-07-16 17:47:57,207 - INFO - Response status: 200
# 2025-07-16 17:47:57,207 - INFO - Response contains 4 items in 'accessDetails' array
# 2025-07-16 17:47:57,211 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:47:57,211 - INFO - Retrieved 4 access details for workspace 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-07-16 17:47:57,211 - INFO - Sample access detail: {
#   "principal": {
#     "id": "eeb21f9e-edfe-40f6-aa48-fb10095de645",
#     "displayName": "",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "edpbiinfrastructure@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "AdminWorkspace",
#     "workspaceRole": "Viewer"
#   }
# }
# 2025-07-16 17:47:57,212 - INFO - Step 2: Creating DataFrames for 4 access details...
# 2025-07-16 17:47:57,212 - INFO - Creating core access DataFrame
# 2025-07-16 17:47:57,275 - INFO - Created core access DataFrame with 4 records
# 2025-07-16 17:47:57,276 - INFO - Creating user details DataFrame
# 2025-07-16 17:47:57,336 - INFO - Created user details DataFrame with 4 records
# 2025-07-16 17:47:57,337 - INFO - Creating group details DataFrame
# 2025-07-16 17:47:57,337 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-07-16 17:47:57,355 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:47:57,355 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:47:57,373 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:47:57,375 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:47:57,391 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:47:57,391 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:47:57,534 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:47:57,578 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:48:00,946 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:48:00,948 - INFO - Successfully merged 4 records into fabric_workspaces_access_core
# 2025-07-16 17:48:00,949 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:48:02,411 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:48:02,411 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:48:02,412 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:48:02,552 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:48:02,594 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:48:05,913 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:05,914 - INFO - Successfully merged 4 records into fabric_workspaces_access_users
# 2025-07-16 17:48:05,915 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:48:07,693 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:07,694 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:48:07,694 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:48:07,810 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:48:07,843 - INFO - No data to merge for fabric_workspaces_access_groups
# 2025-07-16 17:48:07,843 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:48:08,429 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:48:08,429 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:48:08,430 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:48:08,557 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:48:08,591 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:08,591 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:48:09,868 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:09,869 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:09,870 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:09,985 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:48:10,020 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:10,021 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:48:10,672 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:10,673 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:10,673 - INFO - === WORKSPACE 263575b7-d1ee-4dcc-bd05-ca67158e1bb4 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:48:10,674 - INFO - Processing time: 13.73 seconds
# 2025-07-16 17:48:10,675 - INFO - Record counts: {'fabric_workspaces_access_core': 4, 'fabric_workspaces_access_users': 4, 'fabric_workspaces_access_groups': 0, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:48:10,676 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:48:15,676 - INFO -
# --- Processing workspace 5 of 33: cd9d5418-e35d-400e-938d-ea91ea486e07 ---
# 2025-07-16 17:48:15,677 - INFO - === PROCESSING WORKSPACE: cd9d5418-e35d-400e-938d-ea91ea486e07 ===
# 2025-07-16 17:48:15,677 - INFO - Step 1: Retrieving access details for workspace cd9d5418-e35d-400e-938d-ea91ea486e07...
# 2025-07-16 17:48:15,678 - INFO - Retrieving access details for workspace: cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-07-16 17:48:15,679 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/cd9d5418-e35d-400e-938d-ea91ea486e07/users with params: None (Attempt 1)
# 2025-07-16 17:48:15,978 - INFO - Response status: 200
# 2025-07-16 17:48:15,978 - INFO - Response contains 10 items in 'accessDetails' array
# 2025-07-16 17:48:15,981 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:48:15,982 - INFO - Retrieved 10 access details for workspace cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-07-16 17:48:15,982 - INFO - Sample access detail: {
#   "principal": {
#     "id": "c84e2798-cb31-43e5-bb8d-d1d0b8d941b4",
#     "displayName": "AVJoshi Joshi",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "AVJoshi-mda@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:48:15,983 - INFO - Step 2: Creating DataFrames for 10 access details...
# 2025-07-16 17:48:15,983 - INFO - Creating core access DataFrame
# 2025-07-16 17:48:16,058 - INFO - Created core access DataFrame with 10 records
# 2025-07-16 17:48:16,059 - INFO - Creating user details DataFrame
# 2025-07-16 17:48:16,147 - INFO - Created user details DataFrame with 8 records
# 2025-07-16 17:48:16,147 - INFO - Creating group details DataFrame
# 2025-07-16 17:48:16,231 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:48:16,232 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:48:16,233 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:48:16,246 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:48:16,247 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:48:16,264 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:48:16,264 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:48:16,418 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:48:16,467 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:48:20,192 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:48:20,193 - INFO - Successfully merged 10 records into fabric_workspaces_access_core
# 2025-07-16 17:48:20,193 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:48:21,985 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:48:21,986 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:48:21,986 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:48:22,102 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:48:22,157 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:48:25,444 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:25,445 - INFO - Successfully merged 8 records into fabric_workspaces_access_users
# 2025-07-16 17:48:25,445 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:48:27,141 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:27,142 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:48:27,142 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:48:27,260 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:48:27,303 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:48:30,291 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:48:30,292 - INFO - Successfully merged 2 records into fabric_workspaces_access_groups
# 2025-07-16 17:48:30,292 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:48:32,007 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:48:32,007 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:48:32,008 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:48:32,118 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:48:32,149 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:32,150 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:48:32,660 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:32,661 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:32,661 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:32,770 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:48:32,805 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:32,806 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:48:33,382 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:33,383 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:33,384 - INFO - === WORKSPACE cd9d5418-e35d-400e-938d-ea91ea486e07 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:48:33,384 - INFO - Processing time: 17.71 seconds
# 2025-07-16 17:48:33,385 - INFO - Record counts: {'fabric_workspaces_access_core': 10, 'fabric_workspaces_access_users': 8, 'fabric_workspaces_access_groups': 2, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:48:33,385 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:48:38,386 - INFO -
# --- Processing workspace 6 of 33: 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9 ---
# 2025-07-16 17:48:38,387 - INFO - === PROCESSING WORKSPACE: 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9 ===
# 2025-07-16 17:48:38,387 - INFO - Step 1: Retrieving access details for workspace 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9...
# 2025-07-16 17:48:38,388 - INFO - Retrieving access details for workspace: 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9
# 2025-07-16 17:48:38,389 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/8fc8156a-a7d1-40ae-8c3d-9e586cca79a9/users with params: None (Attempt 1)
# 2025-07-16 17:48:38,618 - INFO - Response status: 200
# 2025-07-16 17:48:38,618 - INFO - Response contains 9 items in 'accessDetails' array
# 2025-07-16 17:48:38,622 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:48:38,623 - INFO - Retrieved 9 access details for workspace 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9
# 2025-07-16 17:48:38,623 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:48:38,624 - INFO - Step 2: Creating DataFrames for 9 access details...
# 2025-07-16 17:48:38,624 - INFO - Creating core access DataFrame
# 2025-07-16 17:48:38,701 - INFO - Created core access DataFrame with 9 records
# 2025-07-16 17:48:38,702 - INFO - Creating user details DataFrame
# 2025-07-16 17:48:38,766 - INFO - Created user details DataFrame with 7 records
# 2025-07-16 17:48:38,767 - INFO - Creating group details DataFrame
# 2025-07-16 17:48:38,827 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:48:38,828 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:48:38,828 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:48:38,843 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:48:38,844 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:48:38,859 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:48:38,860 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:48:39,436 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:48:39,483 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:48:42,841 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:48:42,842 - INFO - Successfully merged 9 records into fabric_workspaces_access_core
# 2025-07-16 17:48:42,843 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:48:44,597 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:48:44,598 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:48:44,599 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:48:44,728 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:48:44,775 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:48:48,044 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:48,045 - INFO - Successfully merged 7 records into fabric_workspaces_access_users
# 2025-07-16 17:48:48,045 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:48:49,673 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:48:49,674 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:48:49,675 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:48:49,785 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:48:49,823 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:48:52,760 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:48:52,760 - INFO - Successfully merged 2 records into fabric_workspaces_access_groups
# 2025-07-16 17:48:52,761 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:48:54,458 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:48:54,458 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:48:54,459 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:48:54,602 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:48:54,633 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:54,633 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:48:55,145 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:55,145 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:48:55,146 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:55,249 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:48:55,285 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:55,286 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:48:55,807 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:55,807 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:48:55,808 - INFO - === WORKSPACE 8fc8156a-a7d1-40ae-8c3d-9e586cca79a9 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:48:55,808 - INFO - Processing time: 17.42 seconds
# 2025-07-16 17:48:55,809 - INFO - Record counts: {'fabric_workspaces_access_core': 9, 'fabric_workspaces_access_users': 7, 'fabric_workspaces_access_groups': 2, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:48:55,809 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:49:00,810 - INFO -
# --- Processing workspace 7 of 33: d5f90af2-7d24-4609-859b-4c4d01f471f0 ---
# 2025-07-16 17:49:00,811 - INFO - === PROCESSING WORKSPACE: d5f90af2-7d24-4609-859b-4c4d01f471f0 ===
# 2025-07-16 17:49:00,811 - INFO - Step 1: Retrieving access details for workspace d5f90af2-7d24-4609-859b-4c4d01f471f0...
# 2025-07-16 17:49:00,812 - INFO - Retrieving access details for workspace: d5f90af2-7d24-4609-859b-4c4d01f471f0
# 2025-07-16 17:49:00,812 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/d5f90af2-7d24-4609-859b-4c4d01f471f0/users with params: None (Attempt 1)
# 2025-07-16 17:49:01,070 - INFO - Response status: 200
# 2025-07-16 17:49:01,071 - INFO - Response contains 3 items in 'accessDetails' array
# 2025-07-16 17:49:01,073 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:49:01,074 - INFO - Retrieved 3 access details for workspace d5f90af2-7d24-4609-859b-4c4d01f471f0
# 2025-07-16 17:49:01,075 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:49:01,075 - INFO - Step 2: Creating DataFrames for 3 access details...
# 2025-07-16 17:49:01,075 - INFO - Creating core access DataFrame
# 2025-07-16 17:49:01,149 - INFO - Created core access DataFrame with 3 records
# 2025-07-16 17:49:01,150 - INFO - Creating user details DataFrame
# 2025-07-16 17:49:01,215 - INFO - Created user details DataFrame with 1 records
# 2025-07-16 17:49:01,216 - INFO - Creating group details DataFrame
# 2025-07-16 17:49:01,272 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:49:01,272 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:49:01,273 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:49:01,286 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:49:01,287 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:49:01,300 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:49:01,300 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:49:01,430 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:49:01,476 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:49:04,655 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:49:04,655 - INFO - Successfully merged 3 records into fabric_workspaces_access_core
# 2025-07-16 17:49:04,656 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:49:06,311 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:49:06,311 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:49:06,312 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:49:06,455 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:49:06,515 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:49:09,678 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:49:09,678 - INFO - Successfully merged 1 records into fabric_workspaces_access_users
# 2025-07-16 17:49:09,679 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:49:12,605 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:49:12,606 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:49:12,606 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:49:12,722 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:49:12,765 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:49:15,827 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:49:15,828 - INFO - Successfully merged 2 records into fabric_workspaces_access_groups
# 2025-07-16 17:49:15,829 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:49:17,351 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:49:17,352 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:49:17,352 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:49:17,452 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:49:17,480 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:49:17,481 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:49:17,991 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:49:17,992 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:49:17,992 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:49:18,086 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:49:18,118 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:49:18,119 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:49:18,606 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:49:18,607 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:49:18,608 - INFO - === WORKSPACE d5f90af2-7d24-4609-859b-4c4d01f471f0 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:49:18,608 - INFO - Processing time: 17.80 seconds
# 2025-07-16 17:49:18,609 - INFO - Record counts: {'fabric_workspaces_access_core': 3, 'fabric_workspaces_access_users': 1, 'fabric_workspaces_access_groups': 2, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:49:18,609 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:49:23,610 - INFO -
# --- Processing workspace 8 of 33: 8ee0684d-55f0-4673-b72d-8d63726993cc ---
# 2025-07-16 17:49:23,611 - INFO - === PROCESSING WORKSPACE: 8ee0684d-55f0-4673-b72d-8d63726993cc ===
# 2025-07-16 17:49:23,611 - INFO - Step 1: Retrieving access details for workspace 8ee0684d-55f0-4673-b72d-8d63726993cc...
# 2025-07-16 17:49:23,612 - INFO - Retrieving access details for workspace: 8ee0684d-55f0-4673-b72d-8d63726993cc
# 2025-07-16 17:49:23,612 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/8ee0684d-55f0-4673-b72d-8d63726993cc/users with params: None (Attempt 1)
# 2025-07-16 17:49:23,862 - INFO - Response status: 200
# 2025-07-16 17:49:23,862 - INFO - Response contains 3 items in 'accessDetails' array
# 2025-07-16 17:49:23,866 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:49:23,866 - INFO - Retrieved 3 access details for workspace 8ee0684d-55f0-4673-b72d-8d63726993cc
# 2025-07-16 17:49:23,867 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:49:23,867 - INFO - Step 2: Creating DataFrames for 3 access details...
# 2025-07-16 17:49:23,867 - INFO - Creating core access DataFrame
# 2025-07-16 17:49:23,932 - INFO - Created core access DataFrame with 3 records
# 2025-07-16 17:49:23,933 - INFO - Creating user details DataFrame
# 2025-07-16 17:49:23,988 - INFO - Created user details DataFrame with 1 records
# 2025-07-16 17:49:23,988 - INFO - Creating group details DataFrame
# 2025-07-16 17:49:24,045 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:49:24,046 - INFO - Creating service principal details DataFrame
# ...
# 2025-07-16 17:57:23,236 - INFO - Successfully merged 11 records into fabric_workspaces_access_core
# 2025-07-16 17:57:23,236 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:57:24,939 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:57:24,939 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:57:24,940 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:57:25,049 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:57:25,093 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:57:27,811 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:57:27,812 - INFO - Successfully merged 5 records into fabric_workspaces_access_users
# 2025-07-16 17:57:27,812 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:57:29,375 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:57:29,376 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:57:29,376 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:57:29,483 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:57:29,521 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:57:32,155 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:57:32,156 - INFO - Successfully merged 6 records into fabric_workspaces_access_groups
# 2025-07-16 17:57:32,156 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:57:33,641 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:57:33,642 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:57:33,642 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:57:33,747 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:57:33,772 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:33,773 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:57:34,246 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:34,247 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:34,247 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:34,341 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:57:34,374 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:34,374 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:57:34,842 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:34,843 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:34,844 - INFO - === WORKSPACE 26795226-4c6a-4624-a7c2-6ae70d4f8557 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:57:34,844 - INFO - Processing time: 15.95 seconds
# 2025-07-16 17:57:34,844 - INFO - Record counts: {'fabric_workspaces_access_core': 11, 'fabric_workspaces_access_users': 5, 'fabric_workspaces_access_groups': 6, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:57:34,845 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:57:39,846 - INFO -
# --- Processing workspace 32 of 33: 0ce709ca-36e5-41a1-a318-119dcb311247 ---
# 2025-07-16 17:57:39,847 - INFO - === PROCESSING WORKSPACE: 0ce709ca-36e5-41a1-a318-119dcb311247 ===
# 2025-07-16 17:57:39,847 - INFO - Step 1: Retrieving access details for workspace 0ce709ca-36e5-41a1-a318-119dcb311247...
# 2025-07-16 17:57:39,847 - INFO - Retrieving access details for workspace: 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-07-16 17:57:39,848 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/0ce709ca-36e5-41a1-a318-119dcb311247/users with params: None (Attempt 1)
# 2025-07-16 17:57:40,045 - INFO - Response status: 200
# 2025-07-16 17:57:40,046 - INFO - Response contains 40 items in 'accessDetails' array
# 2025-07-16 17:57:40,049 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:57:40,050 - INFO - Retrieved 40 access details for workspace 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-07-16 17:57:40,050 - INFO - Sample access detail: {
#   "principal": {
#     "id": "67a46eff-10d7-4cd2-9ef2-bea43635d331",
#     "displayName": "James DeLoach",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "JBDeLoach@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Contributor"
#   }
# }
# 2025-07-16 17:57:40,051 - INFO - Step 2: Creating DataFrames for 40 access details...
# 2025-07-16 17:57:40,051 - INFO - Creating core access DataFrame
# 2025-07-16 17:57:40,113 - INFO - Created core access DataFrame with 40 records
# 2025-07-16 17:57:40,113 - INFO - Creating user details DataFrame
# 2025-07-16 17:57:40,177 - INFO - Created user details DataFrame with 38 records
# 2025-07-16 17:57:40,178 - INFO - Creating group details DataFrame
# 2025-07-16 17:57:40,230 - INFO - Created group details DataFrame with 2 records
# 2025-07-16 17:57:40,231 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:57:40,232 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:57:40,244 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:57:40,245 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:57:40,256 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:57:40,257 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:57:40,394 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:57:40,445 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:57:43,342 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:57:43,343 - INFO - Successfully merged 40 records into fabric_workspaces_access_core
# 2025-07-16 17:57:43,343 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:57:44,851 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:57:44,852 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:57:44,853 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:57:44,962 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:57:45,020 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:57:47,769 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:57:47,769 - INFO - Successfully merged 38 records into fabric_workspaces_access_users
# 2025-07-16 17:57:47,770 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:57:49,282 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:57:49,283 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:57:49,283 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:57:49,382 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:57:49,417 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:57:51,949 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:57:51,949 - INFO - Successfully merged 2 records into fabric_workspaces_access_groups
# 2025-07-16 17:57:51,950 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-07-16 17:57:53,470 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-07-16 17:57:53,471 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-07-16 17:57:53,471 - INFO - Processing table: fabric_workspaces_access_service_principals
# 2025-07-16 17:57:53,567 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-07-16 17:57:53,596 - INFO - No data to merge for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:53,596 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-07-16 17:57:54,060 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:54,061 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-07-16 17:57:54,061 - INFO - Processing table: fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:54,162 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-07-16 17:57:54,195 - INFO - No data to merge for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:54,197 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-07-16 17:57:54,672 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:54,673 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-07-16 17:57:54,673 - INFO - === WORKSPACE 0ce709ca-36e5-41a1-a318-119dcb311247 COMPLETED SUCCESSFULLY ===
# 2025-07-16 17:57:54,674 - INFO - Processing time: 14.83 seconds
# 2025-07-16 17:57:54,674 - INFO - Record counts: {'fabric_workspaces_access_core': 40, 'fabric_workspaces_access_users': 38, 'fabric_workspaces_access_groups': 2, 'fabric_workspaces_access_service_principals': 0, 'fabric_workspaces_access_service_principal_profiles': 0}
# 2025-07-16 17:57:54,675 - INFO - Waiting 5 seconds before next workspace (rate limiting)...
# 2025-07-16 17:57:59,676 - INFO -
# --- Processing workspace 33 of 33: 5d190284-0524-4c74-8389-c36e173fd290 ---
# 2025-07-16 17:57:59,676 - INFO - === PROCESSING WORKSPACE: 5d190284-0524-4c74-8389-c36e173fd290 ===
# 2025-07-16 17:57:59,677 - INFO - Step 1: Retrieving access details for workspace 5d190284-0524-4c74-8389-c36e173fd290...
# 2025-07-16 17:57:59,677 - INFO - Retrieving access details for workspace: 5d190284-0524-4c74-8389-c36e173fd290
# 2025-07-16 17:57:59,678 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/5d190284-0524-4c74-8389-c36e173fd290/users with params: None (Attempt 1)
# 2025-07-16 17:57:59,900 - INFO - Response status: 200
# 2025-07-16 17:57:59,901 - INFO - Response contains 32 items in 'accessDetails' array
# 2025-07-16 17:57:59,904 - INFO - Response keys: ['accessDetails']
# 2025-07-16 17:57:59,904 - INFO - Retrieved 32 access details for workspace 5d190284-0524-4c74-8389-c36e173fd290
# 2025-07-16 17:57:59,904 - INFO - Sample access detail: {
#   "principal": {
#     "id": "efffae68-f4de-48e2-a47a-e3f813820089",
#     "displayName": "Netri Mehta",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "nmehta@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-07-16 17:57:59,905 - INFO - Step 2: Creating DataFrames for 32 access details...
# 2025-07-16 17:57:59,906 - INFO - Creating core access DataFrame
# 2025-07-16 17:57:59,964 - INFO - Created core access DataFrame with 32 records
# 2025-07-16 17:57:59,965 - INFO - Creating user details DataFrame
# 2025-07-16 17:58:00,014 - INFO - Created user details DataFrame with 29 records
# 2025-07-16 17:58:00,015 - INFO - Creating group details DataFrame
# 2025-07-16 17:58:00,064 - INFO - Created group details DataFrame with 3 records
# 2025-07-16 17:58:00,065 - INFO - Creating service principal details DataFrame
# 2025-07-16 17:58:00,066 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-07-16 17:58:00,079 - INFO - Creating service principal profile details DataFrame
# 2025-07-16 17:58:00,079 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-07-16 17:58:00,093 - INFO - Step 3: Processing Delta tables...
# 2025-07-16 17:58:00,093 - INFO - Processing table: fabric_workspaces_access_core
# 2025-07-16 17:58:00,231 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-07-16 17:58:00,272 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-07-16 17:58:05,075 - INFO - Core access merge operation completed successfully
# 2025-07-16 17:58:05,076 - INFO - Successfully merged 32 records into fabric_workspaces_access_core
# 2025-07-16 17:58:05,076 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-07-16 17:58:07,149 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-07-16 17:58:07,150 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-07-16 17:58:07,151 - INFO - Processing table: fabric_workspaces_access_users
# 2025-07-16 17:58:07,260 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-07-16 17:58:07,301 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-07-16 17:58:11,563 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-07-16 17:58:11,564 - INFO - Successfully merged 29 records into fabric_workspaces_access_users
# 2025-07-16 17:58:11,565 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-07-16 17:58:13,339 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-07-16 17:58:13,339 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-07-16 17:58:13,340 - INFO - Processing table: fabric_workspaces_access_groups
# 2025-07-16 17:58:13,448 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-07-16 17:58:13,483 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-07-16 17:58:17,638 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-07-16 17:58:17,638 - INFO - Successfully merged 3 records into fabric_workspaces_access_groups
# 2025-07-16 17:58:17,639 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# +----------------------------+-------------------+-----------------+----------------------+
# |total_workspaces_with_access|total_access_grants|unique_principals|unique_principal_types|
# +----------------------------+-------------------+-----------------+----------------------+
# |36                          |468                |280              |3                     |
# +----------------------------+-------------------+-----------------+----------------------+
#
# +----------------+--------------+-----+----------------+
# |principal_type  |workspace_role|count|workspaces_count|
# +----------------+--------------+-----+----------------+
# |Group           |Admin         |66   |32              |
# |Group           |Contributor   |1    |1               |
# |Group           |Member        |3    |3               |
# |Group           |Viewer        |8    |4               |
# |ServicePrincipal|Admin         |1    |1               |
# |ServicePrincipal|Contributor   |3    |1               |
# |User            |Admin         |97   |35              |
# |User            |Contributor   |7    |3               |
# |User            |Member        |78   |21              |
# |User            |Viewer        |204  |15              |
# +----------------+--------------+-----+----------------+

# %%
from pyspark.sql import SparkSession

# create Spark session
spark = SparkSession.builder.appName("Refresh SQL Endpoint Metadata").getOrCreate()

# refresh the specific table
spark.sql("REFRESH TABLE fabric_workspaces_access_core")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE fabric_workspaces_access_users")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE fabric_workspaces_access_groups")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE fabric_workspaces_access_service_principals")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE fabric_workspaces_access_service_principal_profiles")
print("Metadata refresh triggered successfully.")
# Out:
# StatementMeta(, 19f02840-53b3-4187-a034-d02b3e514cb5, 11, Finished, Available, Finished)
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
