# %%
# DO NOT DELETE THIS CELL

# ***IMPORTANT***: Work in progress (WIP). Need to look into 403 errors; may need to grant my account access to each connection;
# This is filtered data. I'm only pulling items on the P1 capacity. See query on line 68. Not all fabric items have connections. 
# See what items are being filtered out in WHERE clause. Also, a particular workspace is being targeted for testing.

# API Name: Items - List Item Connections
# Command:  GET https://api.fabric.microsoft.com/v1/workspaces/{workspaceId}/items/{itemId}/connections
# Doc:      https://learn.microsoft.com/en-us/rest/api/fabric/core/items/list-item-connections

# Loads table: fabric_items_connections
# Out:
# StatementMeta(, d586d30c-5929-4ada-8fa4-df0be3edb891, 5, Finished, Available, Finished)

# %%
# CELL 1 - Title and Introduction
# ==================================
# Microsoft Fabric Item Connections to Delta Lake - PySpark Notebook
# This notebook retrieves Microsoft Fabric item connections and loads them into a Delta Lake table
# with optimization for analytics workloads
# ==================================


# CELL 2 - Import Libraries
# ==================================
# Import required libraries
import requests
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_timestamp, lit, from_json, md5, concat_ws
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
import logging
from typing import Dict, List, Optional, Tuple
from delta.tables import DeltaTable
import random
import time
import hashlib
# ==================================


# CELL 3 - Configure Logging and Initialize Spark
# ==================================
# Configure logging
# This helps us track what's happening in our code and debug issues
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize Spark Session with Delta Lake configurations
# In Fabric notebooks, Spark is pre-configured with Delta support
spark = SparkSession.builder \
    .appName("FabricItemConnectionsToDelta") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Set optimal configurations for Delta operations
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "true")
spark.conf.set("spark.databricks.delta.autoCompact.enabled", "true")
# ==================================


# CELL 4 - Configuration Parameters
# ==================================
# Configuration Parameters
# These are the settings we'll use throughout the notebook
CONFIG = {
    "API_BASE_URL": "https://api.fabric.microsoft.com/v1",
    "CONNECTIONS_ENDPOINT_TEMPLATE": "/workspaces/{workspace_id}/items/{item_id}/connections",  # Template for item connections endpoint
    "MAX_RETRIES": 3,  # Increased number of retries for handling rate limits
    "INITIAL_BACKOFF_SEC": 1,  # Initial backoff time in seconds
    "MAX_BACKOFF_SEC": 60,  # Maximum backoff time in seconds
    "BACKOFF_FACTOR": 2,  # Exponential backoff multiplier
    "JITTER_FACTOR": 0.1,  # Random jitter to add to backoff (as a fraction)
    "TIMEOUT": 30,  # API request timeout in seconds
    "CONNECTIONS_TABLE_NAME": "fabric_items_connections",  # Name of the target Delta table
    "LAKEHOUSE_PATH": "Tables",  # Default Tables folder in Fabric Lakehouse
    "DEBUG_MODE": True,  # Set to True to enable extra debugging output
    "BATCH_SIZE": 20,  # Number of items to process in each batch (to manage rate limits)
    "BATCH_DELAY_SEC": 2  # Delay between batches to avoid overwhelming the API
}

# Source query to get workspace and item IDs
WORKSPACE_ITEMS_QUERY = """
SELECT 
    fw.id AS WorkspaceID, 
    FI.id AS ItemID 
FROM 
    FabricAdmin_Lakehouse.dbo.fabric_capacities AS fc
JOIN 
    FabricAdmin_Lakehouse.dbo.fabric_workspaces AS fw
    ON UPPER(fc.id) = fw.capacityId  -- Join on capacityId
JOIN 
    FabricAdmin_Lakehouse.dbo.fabric_items AS FI
    ON fw.id = FI.workspace_id
WHERE 
    fc.displayName = 'MDA Institutional Capacity - PROD'  -- Filter for specific displayName
    AND fw.state = 'Active'  -- Filter for active workspaces
    AND fw.type <> 'Personal'  -- Exclude personal workspaces
    AND FI.type NOT IN ('Report','Dashboard','Notebook')
ORDER BY
    fw.name,  FI.type, FI.name
"""
# ==================================


# CELL 5 - Authentication Function
# ==================================
def get_access_token():
    """
    Get Azure AD access token for Fabric API authentication.
    
    In a Fabric notebook, the token is automatically available through mssparkutils.
    This function retrieves the token that's needed to authenticate with the Fabric REST API.
    
    Returns:
        str: The access token
    
    Note:
        mssparkutils is a utility library provided by Microsoft Fabric
        that handles authentication automatically.
    """
    try:
        # In Fabric notebooks, we can get the token using mssparkutils
        from notebookutils import mssparkutils
        token_response = mssparkutils.credentials.getToken("https://api.fabric.microsoft.com")
        return token_response
    except Exception as e:
        logger.error(f"Failed to get access token: {str(e)}")
        raise
# ==================================


# CELL 6 - API Call Function
# ==================================
def call_fabric_api(endpoint: str, access_token: str, params: Optional[Dict] = None) -> Dict:
    """
    Make a REST API call to Microsoft Fabric with advanced rate limit handling.
    
    This function handles the HTTP request to the Fabric API, including:
    - Setting up authentication headers
    - Managing retries with intelligent backoff for rate limiting (429 errors)
    - Implementing jitter to avoid synchronized retries
    - Detailed error handling and logging
    
    Args:
        endpoint: The API endpoint path (e.g., "/workspaces/{id}/items/{id}/connections")
        access_token: The Azure AD access token
        params: Optional query parameters for the API call
    
    Returns:
        dict: The JSON response from the API
    
    Raises:
        requests.exceptions.RequestException: If the API call fails after all retries
    """
    url = f"{CONFIG['API_BASE_URL']}{endpoint}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    # Initialize backoff time
    backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
    
    # Retry logic with intelligent backoff
    for attempt in range(CONFIG['MAX_RETRIES']):
        try:
            # Log the request for debugging
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Making API call to: {url} with params: {params} (Attempt {attempt + 1})")
            
            response = requests.get(
                url,
                headers=headers,
                params=params,
                timeout=CONFIG['TIMEOUT']
            )
            
            # Log the response status
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Response status: {response.status_code}")
            
            # Rate limit handling (429 Too Many Requests)
            if response.status_code == 429:
                # Get retry-after header if available, otherwise use our backoff
                retry_after = response.headers.get('Retry-After')
                
                if retry_after and retry_after.isdigit():
                    # If server specified a wait time, use it
                    wait_time = int(retry_after)
                else:
                    # Calculate wait time with exponential backoff and jitter
                    jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                    wait_time = backoff_time + jitter
                    # Update backoff for next attempt
                    backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.warning(f"Rate limit exceeded (429). Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
                continue  # Skip to next retry attempt without raising exception
            
            # Handle 404 errors gracefully (item may not have connections)
            if response.status_code == 404:
                logger.info(f"No connections found for endpoint: {endpoint}")
                return {"value": []}  # Return empty result structure
            
            # Handle 400 errors with "OperationNotSupportedForItem" gracefully
            if response.status_code == 400:
                try:
                    error_response = response.json()
                    if error_response.get("errorCode") == "OperationNotSupportedForItem":
                        logger.info(f"Item does not support connections API (expected for some item types): {endpoint}")
                        return {"value": []}  # Return empty result structure
                except json.JSONDecodeError:
                    pass  # Fall through to regular error handling
            
            # Log the response for debugging in case of other errors
            if response.status_code >= 400:
                logger.error(f"API error: Status {response.status_code}, Response: {response.text}")
                logger.error(f"Request URL: {response.request.url}")
                logger.error(f"Request headers: {response.request.headers}")
            
            # For all other status codes, use raise_for_status to handle
            response.raise_for_status()
            
            # If we get here, the request was successful
            # Reset backoff for next API call (not next attempt)
            backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
            
            # Parse and return the JSON response
            try:
                response_json = response.json()
                if CONFIG['DEBUG_MODE']:
                    if "value" in response_json and isinstance(response_json["value"], list):
                        logger.info(f"Response contains {len(response_json['value'])} connections")
                return response_json
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse response as JSON: {str(e)}")
                logger.error(f"Response content: {response.text[:1000]}")  # Log first 1000 chars of response
                raise
            
        except requests.exceptions.RequestException as e:
            last_attempt = attempt == CONFIG['MAX_RETRIES'] - 1
            
            # Special handling for non-429 errors
            if not (hasattr(e, 'response') and e.response is not None and e.response.status_code == 429):
                logger.warning(f"API call failed (Attempt {attempt + 1}): {str(e)}")
                
                if last_attempt:
                    logger.error(f"All retry attempts failed for endpoint: {endpoint}")
                    logger.error(f"Final error: {str(e)}")
                    raise
                
                # Calculate wait time with exponential backoff and jitter
                jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                wait_time = backoff_time + jitter
                # Update backoff for next attempt
                backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.info(f"Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
# ==================================


# CELL 7 - Get Workspace Items Function
# ==================================
def get_workspace_items() -> List[Tuple[str, str]]:
    """
    Get workspace and item IDs from the existing Fabric tables.
    
    This function executes the predefined SQL query to retrieve workspace and item IDs
    from the fabric_workspaces and fabric_items tables.
    
    Returns:
        list: A list of tuples containing (workspace_id, item_id) pairs
    """
    try:
        logger.info("Executing query to get workspace and item IDs...")
        logger.info(f"Query: {WORKSPACE_ITEMS_QUERY}")
        
        # Execute the query using Spark SQL
        result_df = spark.sql(WORKSPACE_ITEMS_QUERY)
        
        # Show the results for debugging
        logger.info("Query results:")
        result_df.show(truncate=False)
        
        # Convert to list of tuples
        workspace_items = [(row.WorkspaceID, row.ItemID) for row in result_df.collect()]
        
        logger.info(f"Found {len(workspace_items)} workspace-item pairs to process")
        
        return workspace_items
        
    except Exception as e:
        logger.error(f"Failed to get workspace items: {str(e)}")
        raise
# ==================================


# CELL 8 - Get Item Connections Function
# ==================================
def get_item_connections(workspace_id: str, item_id: str, access_token: str) -> List[Dict]:
    """
    Retrieve all connections for a specific item, handling pagination.
    
    This function makes requests to the List Item Connections API endpoint and
    handles pagination using the continuationToken to retrieve all connections.
    
    Args:
        workspace_id: The workspace ID containing the item
        item_id: The item ID to get connections for
        access_token: The Azure AD access token
    
    Returns:
        list: A list of all connection objects for the item
    """
    all_connections = []
    continuation_token = None
    page_count = 0
    
    # Build the endpoint URL
    endpoint = CONFIG['CONNECTIONS_ENDPOINT_TEMPLATE'].format(
        workspace_id=workspace_id, 
        item_id=item_id
    )
    
    try:
        while True:
            page_count += 1
            
            # Prepare parameters for pagination
            params = {}
            if continuation_token:
                params['continuationToken'] = continuation_token
                logger.info(f"Page {page_count}: Making request with continuation token for item {item_id}")
            else:
                logger.info(f"Page {page_count}: Making initial request for item {item_id}")
            
            # Make the API call
            response_data = call_fabric_api(endpoint, access_token, params)
            
            # Extract connections from the response
            connections = response_data.get("value", [])
            
            if connections:
                # Add workspace_id and item_id to each connection for context
                for connection in connections:
                    connection['_workspace_id'] = workspace_id
                    connection['_item_id'] = item_id
                
                all_connections.extend(connections)
                logger.info(f"Retrieved {len(connections)} connections on page {page_count} for item {item_id}")
                
                # Log sample connection for debugging
                if CONFIG['DEBUG_MODE'] and connections:
                    logger.info(f"Sample connection: {json.dumps(connections[0], indent=2)}")
            else:
                logger.info(f"No connections found on page {page_count} for item {item_id}")
            
            # Check if there are more pages
            continuation_token = response_data.get("continuationToken")
            
            if continuation_token:
                logger.info(f"Found continuation token for item {item_id}: {continuation_token}")
            else:
                logger.info(f"No continuation token found for item {item_id} - finished")
                break
        
    except Exception as e:
        error_msg = str(e)
        
        # Check if this is the "OperationNotSupportedForItem" error
        if "OperationNotSupportedForItem" in error_msg:
            logger.info(f"Item {item_id} does not support connections API (expected for some item types)")
            return []
        
        logger.error(f"Error retrieving connections for item {item_id} in workspace {workspace_id}: {error_msg}")
        # Don't re-raise - we want to continue with other items
        return []
    
    logger.info(f"Finished retrieving connections for item {item_id}. Total count: {len(all_connections)}")
    return all_connections
# ==================================


# CELL 9 - Get All Item Connections Function
# ==================================
def get_all_item_connections(workspace_items: List[Tuple[str, str]], access_token: str) -> List[Dict]:
    """
    Retrieve connections for all workspace-item pairs with batching and rate limiting.
    
    This function processes multiple workspace-item pairs and retrieves their connections,
    implementing batching to manage API rate limits.
    
    Args:
        workspace_items: List of (workspace_id, item_id) tuples
        access_token: The Azure AD access token
    
    Returns:
        list: A list of all connection objects from all items
    """
    all_connections = []
    total_items = len(workspace_items)
    
    logger.info(f"Starting to process {total_items} workspace-item pairs")
    
    # Process items in batches to manage rate limits
    for i in range(0, total_items, CONFIG['BATCH_SIZE']):
        batch_end = min(i + CONFIG['BATCH_SIZE'], total_items)
        batch = workspace_items[i:batch_end]
        batch_num = (i // CONFIG['BATCH_SIZE']) + 1
        total_batches = (total_items + CONFIG['BATCH_SIZE'] - 1) // CONFIG['BATCH_SIZE']
        
        logger.info(f"Processing batch {batch_num}/{total_batches} (items {i+1}-{batch_end})")
        
        # Process each item in the current batch
        batch_success_count = 0
        batch_connections_count = 0
        
        for idx, (workspace_id, item_id) in enumerate(batch, start=i+1):
            logger.info(f"Processing item {idx}/{total_items}: workspace={workspace_id}, item={item_id}")
            
            try:
                # Get connections for this item
                item_connections = get_item_connections(workspace_id, item_id, access_token)
                
                if item_connections:
                    all_connections.extend(item_connections)
                    batch_connections_count += len(item_connections)
                    logger.info(f"Added {len(item_connections)} connections from item {item_id}")
                else:
                    logger.debug(f"No connections found for item {item_id}")
                
                batch_success_count += 1
                
            except Exception as e:
                logger.error(f"Failed to process item {item_id}: {str(e)}")
                # Continue with next item
        
        logger.info(f"Batch {batch_num} summary: {batch_success_count}/{len(batch)} items processed successfully, {batch_connections_count} connections found")
        
        # Add delay between batches to avoid overwhelming the API
        if batch_end < total_items:  # Don't delay after the last batch
            logger.info(f"Batch {batch_num} completed. Waiting {CONFIG['BATCH_DELAY_SEC']} seconds before next batch...")
            time.sleep(CONFIG['BATCH_DELAY_SEC'])
    
    logger.info(f"Finished processing all items. Total connections found: {len(all_connections)}")
    return all_connections
# ==================================


# CELL 10 - Create Enhanced DataFrame Function
# ==================================
def create_enhanced_connections_dataframe(connections_data: List[Dict]) -> "DataFrame":
    """
    Convert the connections data into an enhanced PySpark DataFrame for Delta Lake.
    
    This function:
    - Creates a structured DataFrame with the connection data
    - Extracts and flattens the nested JSON structure
    - Adds metadata columns for tracking and change detection
    - Generates a hash for efficient change detection
    
    Args:
        connections_data: List of connection dictionaries from the API
    
    Returns:
        DataFrame: An enhanced PySpark DataFrame ready for Delta Lake
    """
    # Extract and flatten the connection data
    flattened_connections = []
    
    for connection in connections_data:
        # Extract the main connection fields
        workspace_id = connection.get("_workspace_id")
        item_id = connection.get("_item_id")
        connection_id = connection.get("id")  # May be None for some connection types
        display_name = connection.get("displayName")  # May be None
        connectivity_type = connection.get("connectivityType", "Unknown")
        gateway_id = connection.get("gatewayId")  # May be None
        
        # Extract connection details
        connection_details = connection.get("connectionDetails", {})
        connection_details_type = connection_details.get("type", "Unknown")
        connection_details_path = connection_details.get("path", "")
        
        # Create a hash for change detection
        # Use key fields that would indicate a meaningful change
        hash_string = f"{workspace_id}|{item_id}|{connectivity_type}|{connection_details_type}|{connection_details_path}|{gateway_id or ''}"
        connection_hash = hashlib.md5(hash_string.encode()).hexdigest()
        
        flattened_connection = {
            "workspace_id": workspace_id,
            "item_id": item_id,
            "connection_id": connection_id,
            "display_name": display_name,
            "connectivity_type": connectivity_type,
            "gateway_id": gateway_id,
            "connection_details_type": connection_details_type,
            "connection_details_path": connection_details_path,
            "connection_hash": connection_hash
        }
        
        flattened_connections.append(flattened_connection)
    
    # Define the schema for the DataFrame
    schema = StructType([
        StructField("workspace_id", StringType(), False),        # Not nullable - required
        StructField("item_id", StringType(), False),             # Not nullable - required
        StructField("connection_id", StringType(), True),        # Nullable - not always present
        StructField("display_name", StringType(), True),         # Nullable - not always present
        StructField("connectivity_type", StringType(), False),   # Not nullable - always present
        StructField("gateway_id", StringType(), True),           # Nullable - only for gateway connections
        StructField("connection_details_type", StringType(), False),  # Not nullable - always present
        StructField("connection_details_path", StringType(), False),  # Not nullable - always present
        StructField("connection_hash", StringType(), False),     # Not nullable - calculated
        StructField("extraction_timestamp", TimestampType(), False)  # Not nullable - added by us
    ])
    
    # Create DataFrame
    if not flattened_connections:
        logger.warning("No connections found. Creating empty DataFrame.")
        # Create an empty DataFrame with the schema
        empty_rdd = spark.sparkContext.emptyRDD()
        enhanced_df = spark.createDataFrame(empty_rdd, schema)
        return enhanced_df
    
    # Convert to pandas DataFrame first for easier handling
    pandas_df = pd.DataFrame(flattened_connections)
    
    # Ensure all columns exist and handle None values appropriately
    required_columns = ["workspace_id", "item_id", "connection_id", "display_name", 
                       "connectivity_type", "gateway_id", "connection_details_type", 
                       "connection_details_path", "connection_hash"]
    
    for col_name in required_columns:
        if col_name not in pandas_df.columns:
            pandas_df[col_name] = None
    
    # Create the initial Spark DataFrame (excluding extraction_timestamp)
    spark_df = spark.createDataFrame(pandas_df[required_columns])
    
    # Add metadata column for tracking when this data was extracted
    enhanced_df = spark_df.withColumn("extraction_timestamp", current_timestamp())
    
    return enhanced_df
# ==================================


# CELL 11 - Delta Lake Operations Functions
# ==================================
def ensure_delta_table_exists(table_name: str, df_schema):
    """
    Ensure the Delta table exists, creating it if necessary.
    
    Args:
        table_name: Name of the Delta table
        df_schema: Schema of the DataFrame
    """
    try:
        # Check if table exists
        spark.sql(f"DESCRIBE TABLE {table_name}")
        logger.info(f"Delta table '{table_name}' already exists")
    except Exception:
        # Table doesn't exist, create it
        logger.info(f"Creating Delta table '{table_name}'")
        
        # Create an empty DataFrame with the schema
        empty_df = spark.createDataFrame([], df_schema)
        
        # Create the Delta table
        empty_df.write \
            .mode("overwrite") \
            .option("overwriteSchema", "true") \
            .saveAsTable(table_name)
        
        logger.info(f"Delta table '{table_name}' created successfully")


def merge_data_to_delta(source_df, table_name: str):
    """
    Merge new connection data into the Delta table using MERGE operation.
    
    This function performs an upsert operation:
    - Updates existing records if the composite key matches
    - Inserts new records if the composite key doesn't exist
    
    The composite key consists of: workspace_id, item_id, connection_hash
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    source_df.createOrReplaceTempView("connection_updates")
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Perform the merge operation using composite key
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING connection_updates AS source
    ON target.workspace_id = source.workspace_id 
       AND target.item_id = source.item_id 
       AND target.connection_hash = source.connection_hash
    WHEN MATCHED THEN
        UPDATE SET 
            target.connection_id = source.connection_id,
            target.display_name = source.display_name,
            target.connectivity_type = source.connectivity_type,
            target.gateway_id = source.gateway_id,
            target.connection_details_type = source.connection_details_type,
            target.connection_details_path = source.connection_details_path,
            target.extraction_timestamp = source.extraction_timestamp
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    spark.sql(merge_query)
    logger.info("Merge operation completed successfully")


def optimize_delta_table(table_name: str):
    """
    Optimize the Delta table for better query performance.
    
    This function:
    - Updates table statistics for query optimization
    - Uses a compatible method for Microsoft Fabric
    
    Args:
        table_name: Name of the Delta table to optimize
    """
    logger.info(f"Optimizing Delta table '{table_name}'")
    
    try:
        # Update table statistics for better query planning
        spark.sql(f"ANALYZE TABLE {table_name} COMPUTE STATISTICS")
        logger.info("Table statistics updated successfully")
        
        # Note: In Microsoft Fabric, Delta table optimization may be handled automatically
        # or through different commands than traditional Delta Lake
        
        logger.info("Delta table optimization completed via statistics computation")
        logger.info("Note: Microsoft Fabric may automatically optimize Delta tables")
    except Exception as e:
        logger.warning(f"Table optimization step encountered an issue: {str(e)}")
        logger.info("Continuing with process - optimization is not critical for functionality")
# ==================================


# CELL 12 - Main Execution Function
# ==================================
def main():
    """
    Main execution function that orchestrates the entire process.
    
    This function:
    1. Gets the authentication token
    2. Retrieves workspace and item IDs from existing tables
    3. Retrieves all item connections from the API
    4. Creates an enhanced PySpark DataFrame with the connection data
    5. Loads data into a Delta Lake table
    6. Optimizes the table for analytics
    """
    try:
        logger.info("Starting Fabric Item Connections to Delta Lake process")
        
        # Step 1: Get authentication token
        logger.info("Getting access token...")
        access_token = get_access_token()
        logger.info("Successfully obtained access token")
        
        # Step 2: Get workspace and item IDs
        logger.info("Retrieving workspace and item IDs...")
        workspace_items = get_workspace_items()
        
        if not workspace_items:
            logger.warning("No workspace-item pairs found. Please check the query and source tables.")
            return None
        
        # Step 3: Retrieve all item connections
        logger.info("Retrieving item connections from Fabric API...")
        connections_data = get_all_item_connections(workspace_items, access_token)
        
        if not connections_data:
            logger.warning("No connections found for any items. Creating empty DataFrame.")
            # Create empty dataframe with schema for consistent table structure
            empty_schema = StructType([
                StructField("workspace_id", StringType(), False),
                StructField("item_id", StringType(), False),
                StructField("connection_id", StringType(), True),
                StructField("display_name", StringType(), True),
                StructField("connectivity_type", StringType(), False),
                StructField("gateway_id", StringType(), True),
                StructField("connection_details_type", StringType(), False),
                StructField("connection_details_path", StringType(), False),
                StructField("connection_hash", StringType(), False),
                StructField("extraction_timestamp", TimestampType(), False)
            ])
            connections_df = spark.createDataFrame([], empty_schema)
        else:
            # Step 4: Create enhanced DataFrame
            logger.info(f"Creating DataFrame for {len(connections_data)} connections...")
            connections_df = create_enhanced_connections_dataframe(connections_data)
        
        # Show sample data
        logger.info("Sample of enhanced connections data:")
        connections_df.show(5, truncate=False)
        
        # Step 5: Prepare Delta table
        table_name = CONFIG["CONNECTIONS_TABLE_NAME"]
        ensure_delta_table_exists(table_name, connections_df.schema)
        
        # Step 6: Merge data into Delta table (if we have data)
        if connections_data:
            merge_data_to_delta(connections_df, table_name)
            
            # Step 7: Optimize the Delta table
            optimize_delta_table(table_name)
        
        # Step 8: Display final statistics
        logger.info("Loading completed successfully!")
        
        # Show table information
        spark.sql(f"DESCRIBE DETAIL {table_name}").show(truncate=False)
        
        # Show row count
        row_count = spark.table(table_name).count()
        logger.info(f"Total rows in {table_name}: {row_count}")
        
        # Show summary statistics
        summary_stats = spark.sql(f"""
            SELECT 
                COUNT(*) as total_connections,
                COUNT(DISTINCT workspace_id) as unique_workspaces,
                COUNT(DISTINCT item_id) as unique_items,
                COUNT(DISTINCT connectivity_type) as connectivity_types,
                COUNT(DISTINCT connection_details_type) as connection_detail_types,
                MAX(extraction_timestamp) as last_updated
            FROM {table_name}
        """)
        
        logger.info("Summary statistics:")
        summary_stats.show(truncate=False)
        
        # Optional: Show distribution by connectivity type
        connectivity_distribution = spark.sql(f"""
            SELECT 
                connectivity_type,
                COUNT(*) as count
            FROM {table_name}
            GROUP BY connectivity_type
            ORDER BY count DESC
        """)
        
        logger.info("Connection distribution by connectivity type:")
        connectivity_distribution.show(truncate=False)
        
        # Optional: Show distribution by connection details type
        details_distribution = spark.sql(f"""
            SELECT 
                connection_details_type,
                COUNT(*) as count
            FROM {table_name}
            GROUP BY connection_details_type
            ORDER BY count DESC
        """)
        
        logger.info("Connection distribution by connection details type:")
        details_distribution.show(truncate=False)
        
        return connections_df
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")
        raise
# ==================================


# CELL 13 - Execute Main Function
# ==================================
# Execute the main function
if __name__ == "__main__":
    connections_df = main()
# ==================================
# Out:
# StatementMeta(, d586d30c-5929-4ada-8fa4-df0be3edb891, 6, Finished, Available, Finished)
# 2025-07-16 18:19:38,089 - INFO - Starting Fabric Item Connections to Delta Lake process
# 2025-07-16 18:19:38,090 - INFO - Getting access token...
# 2025-07-16 18:19:38,095 - INFO - Successfully obtained access token
# 2025-07-16 18:19:38,095 - INFO - Retrieving workspace and item IDs...
# 2025-07-16 18:19:38,096 - INFO - Executing query to get workspace and item IDs...
# 2025-07-16 18:19:38,096 - INFO - Query:
# SELECT
#     fw.id AS WorkspaceID,
#     FI.id AS ItemID
# FROM
#     FabricAdmin_Lakehouse.dbo.fabric_capacities AS fc
# JOIN
#     FabricAdmin_Lakehouse.dbo.fabric_workspaces AS fw
#     ON UPPER(fc.id) = fw.capacityId  -- Join on capacityId
# JOIN
#     FabricAdmin_Lakehouse.dbo.fabric_items AS FI
#     ON fw.id = FI.workspace_id
# WHERE
#     fc.displayName = 'MDA Institutional Capacity - PROD'  -- Filter for specific displayName
#     AND fw.state = 'Active'  -- Filter for active workspaces
#     AND fw.type <> 'Personal'  -- Exclude personal workspaces
#     AND FI.type NOT IN ('Report','Dashboard','Notebook')
# ORDER BY
#     fw.name,  FI.type, FI.name
#
# 2025-07-16 18:19:51,273 - INFO - Query results:
# 2025-07-16 18:20:03,370 - INFO - Found 231 workspace-item pairs to process
# 2025-07-16 18:20:03,370 - INFO - Retrieving item connections from Fabric API...
# 2025-07-16 18:20:03,371 - INFO - Starting to process 231 workspace-item pairs
# 2025-07-16 18:20:03,371 - INFO - Processing batch 1/12 (items 1-20)
# 2025-07-16 18:20:03,372 - INFO - Processing item 1/231: workspace=3dc16785-8298-4567-880a-9919f074555f, item=fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-16 18:20:03,372 - INFO - Page 1: Making initial request for item fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-16 18:20:03,373 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/3dc16785-8298-4567-880a-9919f074555f/items/fe1918d6-0a63-4b30-9208-afc8e5c1d5df/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:04,483 - INFO - Response status: 200
# 2025-07-16 18:20:04,484 - INFO - Response contains 15 connections
# 2025-07-16 18:20:04,488 - INFO - Retrieved 15 connections on page 1 for item fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-16 18:20:04,488 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "fe1af4fe-6046-46f7-be68-71961d8aff0b",
#   "gatewayId": "a9ef46b6-b653-474e-ad63-a58c7287c40c",
#   "connectionDetails": {
#     "path": "file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Data%20Files_Extracts/Archived%20SI%20Extracts/SI_Extract.csv",
#     "type": "File"
#   },
#   "_workspace_id": "3dc16785-8298-4567-880a-9919f074555f",
#   "_item_id": "fe1918d6-0a63-4b30-9208-afc8e5c1d5df"
# }
# 2025-07-16 18:20:04,488 - INFO - No continuation token found for item fe1918d6-0a63-4b30-9208-afc8e5c1d5df - finished
# 2025-07-16 18:20:04,489 - INFO - Finished retrieving connections for item fe1918d6-0a63-4b30-9208-afc8e5c1d5df. Total count: 15
# 2025-07-16 18:20:04,490 - INFO - Added 15 connections from item fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-16 18:20:04,491 - INFO - Processing item 2/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=f08cffd2-bd9f-4c46-b4bd-1c58f9153fde
# 2025-07-16 18:20:04,491 - INFO - Page 1: Making initial request for item f08cffd2-bd9f-4c46-b4bd-1c58f9153fde
# 2025-07-16 18:20:04,492 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/f08cffd2-bd9f-4c46-b4bd-1c58f9153fde/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:05,208 - INFO - Response status: 200
# 2025-07-16 18:20:05,209 - INFO - Response contains 1 connections
# 2025-07-16 18:20:05,212 - INFO - Retrieved 1 connections on page 1 for item f08cffd2-bd9f-4c46-b4bd-1c58f9153fde
# 2025-07-16 18:20:05,212 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "f08cffd2-bd9f-4c46-b4bd-1c58f9153fde"
# }
# 2025-07-16 18:20:05,213 - INFO - No continuation token found for item f08cffd2-bd9f-4c46-b4bd-1c58f9153fde - finished
# 2025-07-16 18:20:05,213 - INFO - Finished retrieving connections for item f08cffd2-bd9f-4c46-b4bd-1c58f9153fde. Total count: 1
# 2025-07-16 18:20:05,214 - INFO - Added 1 connections from item f08cffd2-bd9f-4c46-b4bd-1c58f9153fde
# 2025-07-16 18:20:05,214 - INFO - Processing item 3/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=69653dc2-dcee-4688-b832-b17a2438dc9a
# 2025-07-16 18:20:05,215 - INFO - Page 1: Making initial request for item 69653dc2-dcee-4688-b832-b17a2438dc9a
# 2025-07-16 18:20:05,215 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/69653dc2-dcee-4688-b832-b17a2438dc9a/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:05,853 - INFO - Response status: 200
# 2025-07-16 18:20:05,855 - INFO - Response contains 2 connections
# 2025-07-16 18:20:05,858 - INFO - Retrieved 2 connections on page 1 for item 69653dc2-dcee-4688-b832-b17a2438dc9a
# 2025-07-16 18:20:05,859 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "69653dc2-dcee-4688-b832-b17a2438dc9a"
# }
# 2025-07-16 18:20:05,859 - INFO - No continuation token found for item 69653dc2-dcee-4688-b832-b17a2438dc9a - finished
# 2025-07-16 18:20:05,859 - INFO - Finished retrieving connections for item 69653dc2-dcee-4688-b832-b17a2438dc9a. Total count: 2
# 2025-07-16 18:20:05,860 - INFO - Added 2 connections from item 69653dc2-dcee-4688-b832-b17a2438dc9a
# 2025-07-16 18:20:05,860 - INFO - Processing item 4/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=b335dadd-91e1-4bd5-9286-fc1b11eef750
# 2025-07-16 18:20:05,861 - INFO - Page 1: Making initial request for item b335dadd-91e1-4bd5-9286-fc1b11eef750
# 2025-07-16 18:20:05,862 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/b335dadd-91e1-4bd5-9286-fc1b11eef750/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:06,145 - INFO - Response status: 200
# 2025-07-16 18:20:06,146 - INFO - Response contains 1 connections
# 2025-07-16 18:20:06,149 - INFO - Retrieved 1 connections on page 1 for item b335dadd-91e1-4bd5-9286-fc1b11eef750
# 2025-07-16 18:20:06,149 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_DEV",
#   "connectivityType": "OnPremisesGateway",
#   "id": "789151dd-51e6-491a-a4cd-0c9fa0f4e30e",
#   "gatewayId": "47d3ea9b-fb98-4e41-8516-2aa7c02b7eca",
#   "connectionDetails": {
#     "path": "QCDWLSQL02;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "b335dadd-91e1-4bd5-9286-fc1b11eef750"
# }
# 2025-07-16 18:20:06,149 - INFO - No continuation token found for item b335dadd-91e1-4bd5-9286-fc1b11eef750 - finished
# 2025-07-16 18:20:06,150 - INFO - Finished retrieving connections for item b335dadd-91e1-4bd5-9286-fc1b11eef750. Total count: 1
# 2025-07-16 18:20:06,151 - INFO - Added 1 connections from item b335dadd-91e1-4bd5-9286-fc1b11eef750
# 2025-07-16 18:20:06,151 - INFO - Processing item 5/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=8beeb061-c1e7-4717-aaf8-f7f0de781d80
# 2025-07-16 18:20:06,152 - INFO - Page 1: Making initial request for item 8beeb061-c1e7-4717-aaf8-f7f0de781d80
# 2025-07-16 18:20:06,152 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/8beeb061-c1e7-4717-aaf8-f7f0de781d80/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:06,628 - INFO - Response status: 200
# 2025-07-16 18:20:06,629 - INFO - Response contains 1 connections
# 2025-07-16 18:20:06,632 - INFO - Retrieved 1 connections on page 1 for item 8beeb061-c1e7-4717-aaf8-f7f0de781d80
# 2025-07-16 18:20:06,633 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "8beeb061-c1e7-4717-aaf8-f7f0de781d80"
# }
# 2025-07-16 18:20:06,633 - INFO - No continuation token found for item 8beeb061-c1e7-4717-aaf8-f7f0de781d80 - finished
# 2025-07-16 18:20:06,634 - INFO - Finished retrieving connections for item 8beeb061-c1e7-4717-aaf8-f7f0de781d80. Total count: 1
# 2025-07-16 18:20:06,635 - INFO - Added 1 connections from item 8beeb061-c1e7-4717-aaf8-f7f0de781d80
# 2025-07-16 18:20:06,636 - INFO - Processing item 6/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=0debddf5-8b75-408d-91a7-a034f529252f
# 2025-07-16 18:20:06,636 - INFO - Page 1: Making initial request for item 0debddf5-8b75-408d-91a7-a034f529252f
# 2025-07-16 18:20:06,637 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/0debddf5-8b75-408d-91a7-a034f529252f/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:06,924 - INFO - Response status: 200
# 2025-07-16 18:20:06,925 - INFO - Response contains 1 connections
# 2025-07-16 18:20:06,928 - INFO - Retrieved 1 connections on page 1 for item 0debddf5-8b75-408d-91a7-a034f529252f
# 2025-07-16 18:20:06,928 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "2bb58d39-bf96-4a33-8483-f73071935609",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcdwlsql02;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "0debddf5-8b75-408d-91a7-a034f529252f"
# }
# 2025-07-16 18:20:06,929 - INFO - No continuation token found for item 0debddf5-8b75-408d-91a7-a034f529252f - finished
# 2025-07-16 18:20:06,930 - INFO - Finished retrieving connections for item 0debddf5-8b75-408d-91a7-a034f529252f. Total count: 1
# 2025-07-16 18:20:06,930 - INFO - Added 1 connections from item 0debddf5-8b75-408d-91a7-a034f529252f
# 2025-07-16 18:20:06,931 - INFO - Processing item 7/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=abc87d9b-7aae-4e9a-9144-03c55b775059
# 2025-07-16 18:20:06,931 - INFO - Page 1: Making initial request for item abc87d9b-7aae-4e9a-9144-03c55b775059
# 2025-07-16 18:20:06,932 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/abc87d9b-7aae-4e9a-9144-03c55b775059/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:07,222 - INFO - Response status: 200
# 2025-07-16 18:20:07,223 - INFO - Response contains 1 connections
# 2025-07-16 18:20:07,226 - INFO - Retrieved 1 connections on page 1 for item abc87d9b-7aae-4e9a-9144-03c55b775059
# 2025-07-16 18:20:07,227 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "abc87d9b-7aae-4e9a-9144-03c55b775059"
# }
# 2025-07-16 18:20:07,227 - INFO - No continuation token found for item abc87d9b-7aae-4e9a-9144-03c55b775059 - finished
# 2025-07-16 18:20:07,228 - INFO - Finished retrieving connections for item abc87d9b-7aae-4e9a-9144-03c55b775059. Total count: 1
# 2025-07-16 18:20:07,228 - INFO - Added 1 connections from item abc87d9b-7aae-4e9a-9144-03c55b775059
# 2025-07-16 18:20:07,228 - INFO - Processing item 8/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=d695a243-9542-4498-95a3-54f1f8a2176b
# 2025-07-16 18:20:07,229 - INFO - Page 1: Making initial request for item d695a243-9542-4498-95a3-54f1f8a2176b
# 2025-07-16 18:20:07,229 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/d695a243-9542-4498-95a3-54f1f8a2176b/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:07,535 - INFO - Response status: 200
# 2025-07-16 18:20:07,536 - INFO - Response contains 1 connections
# 2025-07-16 18:20:07,539 - INFO - Retrieved 1 connections on page 1 for item d695a243-9542-4498-95a3-54f1f8a2176b
# 2025-07-16 18:20:07,540 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "2bb58d39-bf96-4a33-8483-f73071935609",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcdwlsql02;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "d695a243-9542-4498-95a3-54f1f8a2176b"
# }
# 2025-07-16 18:20:07,540 - INFO - No continuation token found for item d695a243-9542-4498-95a3-54f1f8a2176b - finished
# 2025-07-16 18:20:07,541 - INFO - Finished retrieving connections for item d695a243-9542-4498-95a3-54f1f8a2176b. Total count: 1
# 2025-07-16 18:20:07,541 - INFO - Added 1 connections from item d695a243-9542-4498-95a3-54f1f8a2176b
# 2025-07-16 18:20:07,542 - INFO - Processing item 9/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=5cde3586-177e-4d76-aeef-7983cb732f69
# 2025-07-16 18:20:07,542 - INFO - Page 1: Making initial request for item 5cde3586-177e-4d76-aeef-7983cb732f69
# 2025-07-16 18:20:07,542 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/5cde3586-177e-4d76-aeef-7983cb732f69/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:07,837 - INFO - Response status: 200
# 2025-07-16 18:20:07,837 - INFO - Response contains 1 connections
# 2025-07-16 18:20:07,841 - INFO - Retrieved 1 connections on page 1 for item 5cde3586-177e-4d76-aeef-7983cb732f69
# 2025-07-16 18:20:07,842 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "5cde3586-177e-4d76-aeef-7983cb732f69"
# }
# 2025-07-16 18:20:07,842 - INFO - No continuation token found for item 5cde3586-177e-4d76-aeef-7983cb732f69 - finished
# 2025-07-16 18:20:07,843 - INFO - Finished retrieving connections for item 5cde3586-177e-4d76-aeef-7983cb732f69. Total count: 1
# 2025-07-16 18:20:07,843 - INFO - Added 1 connections from item 5cde3586-177e-4d76-aeef-7983cb732f69
# 2025-07-16 18:20:07,844 - INFO - Processing item 10/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1
# 2025-07-16 18:20:07,844 - INFO - Page 1: Making initial request for item 3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1
# 2025-07-16 18:20:07,845 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:08,205 - INFO - Response status: 200
# 2025-07-16 18:20:08,206 - INFO - Response contains 1 connections
# 2025-07-16 18:20:08,209 - INFO - Retrieved 1 connections on page 1 for item 3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1
# 2025-07-16 18:20:08,209 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "2bb58d39-bf96-4a33-8483-f73071935609",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcdwlsql02;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1"
# }
# 2025-07-16 18:20:08,210 - INFO - No continuation token found for item 3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1 - finished
# 2025-07-16 18:20:08,210 - INFO - Finished retrieving connections for item 3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1. Total count: 1
# 2025-07-16 18:20:08,211 - INFO - Added 1 connections from item 3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1
# 2025-07-16 18:20:08,211 - INFO - Processing item 11/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=02e8492b-24e6-45c6-be48-1b6d319741ef
# 2025-07-16 18:20:08,212 - INFO - Page 1: Making initial request for item 02e8492b-24e6-45c6-be48-1b6d319741ef
# 2025-07-16 18:20:08,212 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/02e8492b-24e6-45c6-be48-1b6d319741ef/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:08,517 - INFO - Response status: 200
# 2025-07-16 18:20:08,518 - INFO - Response contains 0 connections
# 2025-07-16 18:20:08,521 - INFO - No connections found on page 1 for item 02e8492b-24e6-45c6-be48-1b6d319741ef
# 2025-07-16 18:20:08,522 - INFO - No continuation token found for item 02e8492b-24e6-45c6-be48-1b6d319741ef - finished
# 2025-07-16 18:20:08,522 - INFO - Finished retrieving connections for item 02e8492b-24e6-45c6-be48-1b6d319741ef. Total count: 0
# 2025-07-16 18:20:08,523 - INFO - Processing item 12/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8
# 2025-07-16 18:20:08,523 - INFO - Page 1: Making initial request for item de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8
# 2025-07-16 18:20:08,524 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:08,893 - INFO - Response status: 200
# 2025-07-16 18:20:08,893 - INFO - Response contains 1 connections
# 2025-07-16 18:20:08,897 - INFO - Retrieved 1 connections on page 1 for item de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8
# 2025-07-16 18:20:08,898 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8"
# }
# 2025-07-16 18:20:08,898 - INFO - No continuation token found for item de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8 - finished
# 2025-07-16 18:20:08,899 - INFO - Finished retrieving connections for item de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8. Total count: 1
# 2025-07-16 18:20:08,899 - INFO - Added 1 connections from item de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8
# 2025-07-16 18:20:08,900 - INFO - Processing item 13/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=27dd9f56-5ee2-404a-97d9-95b29a6d2868
# 2025-07-16 18:20:08,901 - INFO - Page 1: Making initial request for item 27dd9f56-5ee2-404a-97d9-95b29a6d2868
# 2025-07-16 18:20:08,901 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/27dd9f56-5ee2-404a-97d9-95b29a6d2868/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:09,217 - INFO - Response status: 200
# 2025-07-16 18:20:09,217 - INFO - Response contains 1 connections
# 2025-07-16 18:20:09,221 - INFO - Retrieved 1 connections on page 1 for item 27dd9f56-5ee2-404a-97d9-95b29a6d2868
# 2025-07-16 18:20:09,221 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "27dd9f56-5ee2-404a-97d9-95b29a6d2868"
# }
# 2025-07-16 18:20:09,222 - INFO - No continuation token found for item 27dd9f56-5ee2-404a-97d9-95b29a6d2868 - finished
# 2025-07-16 18:20:09,222 - INFO - Finished retrieving connections for item 27dd9f56-5ee2-404a-97d9-95b29a6d2868. Total count: 1
# 2025-07-16 18:20:09,222 - INFO - Added 1 connections from item 27dd9f56-5ee2-404a-97d9-95b29a6d2868
# 2025-07-16 18:20:09,223 - INFO - Processing item 14/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=b72b3066-372e-4c85-839b-c171be60dfd6
# 2025-07-16 18:20:09,223 - INFO - Page 1: Making initial request for item b72b3066-372e-4c85-839b-c171be60dfd6
# 2025-07-16 18:20:09,224 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/b72b3066-372e-4c85-839b-c171be60dfd6/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:09,540 - INFO - Response status: 200
# 2025-07-16 18:20:09,541 - INFO - Response contains 1 connections
# 2025-07-16 18:20:09,544 - INFO - Retrieved 1 connections on page 1 for item b72b3066-372e-4c85-839b-c171be60dfd6
# 2025-07-16 18:20:09,544 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "b72b3066-372e-4c85-839b-c171be60dfd6"
# }
# 2025-07-16 18:20:09,545 - INFO - No continuation token found for item b72b3066-372e-4c85-839b-c171be60dfd6 - finished
# 2025-07-16 18:20:09,546 - INFO - Finished retrieving connections for item b72b3066-372e-4c85-839b-c171be60dfd6. Total count: 1
# 2025-07-16 18:20:09,546 - INFO - Added 1 connections from item b72b3066-372e-4c85-839b-c171be60dfd6
# 2025-07-16 18:20:09,547 - INFO - Processing item 15/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=c97c34f2-02d7-46a3-876b-c3c8fc5c865c
# 2025-07-16 18:20:09,547 - INFO - Page 1: Making initial request for item c97c34f2-02d7-46a3-876b-c3c8fc5c865c
# 2025-07-16 18:20:09,548 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/c97c34f2-02d7-46a3-876b-c3c8fc5c865c/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:09,921 - INFO - Response status: 200
# 2025-07-16 18:20:09,922 - INFO - Response contains 1 connections
# 2025-07-16 18:20:09,926 - INFO - Retrieved 1 connections on page 1 for item c97c34f2-02d7-46a3-876b-c3c8fc5c865c
# 2025-07-16 18:20:09,926 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "c97c34f2-02d7-46a3-876b-c3c8fc5c865c"
# }
# 2025-07-16 18:20:09,926 - INFO - No continuation token found for item c97c34f2-02d7-46a3-876b-c3c8fc5c865c - finished
# 2025-07-16 18:20:09,927 - INFO - Finished retrieving connections for item c97c34f2-02d7-46a3-876b-c3c8fc5c865c. Total count: 1
# 2025-07-16 18:20:09,927 - INFO - Added 1 connections from item c97c34f2-02d7-46a3-876b-c3c8fc5c865c
# 2025-07-16 18:20:09,928 - INFO - Processing item 16/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81
# 2025-07-16 18:20:09,928 - INFO - Page 1: Making initial request for item 4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81
# 2025-07-16 18:20:09,929 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:10,288 - INFO - Response status: 200
# 2025-07-16 18:20:10,288 - INFO - Response contains 1 connections
# 2025-07-16 18:20:10,292 - INFO - Retrieved 1 connections on page 1 for item 4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81
# 2025-07-16 18:20:10,292 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81"
# }
# 2025-07-16 18:20:10,293 - INFO - No continuation token found for item 4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81 - finished
# 2025-07-16 18:20:10,293 - INFO - Finished retrieving connections for item 4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81. Total count: 1
# 2025-07-16 18:20:10,293 - INFO - Added 1 connections from item 4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81
# 2025-07-16 18:20:10,294 - INFO - Processing item 17/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=98c8549a-37d0-47cb-83f0-4101b9dcddc6
# 2025-07-16 18:20:10,294 - INFO - Page 1: Making initial request for item 98c8549a-37d0-47cb-83f0-4101b9dcddc6
# 2025-07-16 18:20:10,295 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/98c8549a-37d0-47cb-83f0-4101b9dcddc6/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:10,505 - INFO - Response status: 200
# 2025-07-16 18:20:10,505 - INFO - Response contains 1 connections
# 2025-07-16 18:20:10,509 - INFO - Retrieved 1 connections on page 1 for item 98c8549a-37d0-47cb-83f0-4101b9dcddc6
# 2025-07-16 18:20:10,509 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "98c8549a-37d0-47cb-83f0-4101b9dcddc6"
# }
# 2025-07-16 18:20:10,510 - INFO - No continuation token found for item 98c8549a-37d0-47cb-83f0-4101b9dcddc6 - finished
# 2025-07-16 18:20:10,510 - INFO - Finished retrieving connections for item 98c8549a-37d0-47cb-83f0-4101b9dcddc6. Total count: 1
# 2025-07-16 18:20:10,511 - INFO - Added 1 connections from item 98c8549a-37d0-47cb-83f0-4101b9dcddc6
# 2025-07-16 18:20:10,511 - INFO - Processing item 18/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=112ffecd-2aa3-4571-8daa-a7342f25a4c7
# 2025-07-16 18:20:10,512 - INFO - Page 1: Making initial request for item 112ffecd-2aa3-4571-8daa-a7342f25a4c7
# 2025-07-16 18:20:10,512 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/112ffecd-2aa3-4571-8daa-a7342f25a4c7/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:10,769 - INFO - Response status: 200
# 2025-07-16 18:20:10,770 - INFO - Response contains 1 connections
# 2025-07-16 18:20:10,773 - INFO - Retrieved 1 connections on page 1 for item 112ffecd-2aa3-4571-8daa-a7342f25a4c7
# 2025-07-16 18:20:10,774 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "112ffecd-2aa3-4571-8daa-a7342f25a4c7"
# }
# 2025-07-16 18:20:10,774 - INFO - No continuation token found for item 112ffecd-2aa3-4571-8daa-a7342f25a4c7 - finished
# 2025-07-16 18:20:10,774 - INFO - Finished retrieving connections for item 112ffecd-2aa3-4571-8daa-a7342f25a4c7. Total count: 1
# 2025-07-16 18:20:10,775 - INFO - Added 1 connections from item 112ffecd-2aa3-4571-8daa-a7342f25a4c7
# 2025-07-16 18:20:10,775 - INFO - Processing item 19/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=6dfb81c1-26e6-485e-a7f8-4951e8de683f
# 2025-07-16 18:20:10,776 - INFO - Page 1: Making initial request for item 6dfb81c1-26e6-485e-a7f8-4951e8de683f
# 2025-07-16 18:20:10,777 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/6dfb81c1-26e6-485e-a7f8-4951e8de683f/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:11,060 - INFO - Response status: 200
# 2025-07-16 18:20:11,060 - INFO - Response contains 1 connections
# 2025-07-16 18:20:11,063 - INFO - Retrieved 1 connections on page 1 for item 6dfb81c1-26e6-485e-a7f8-4951e8de683f
# 2025-07-16 18:20:11,064 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "6dfb81c1-26e6-485e-a7f8-4951e8de683f"
# }
# 2025-07-16 18:20:11,064 - INFO - No continuation token found for item 6dfb81c1-26e6-485e-a7f8-4951e8de683f - finished
# 2025-07-16 18:20:11,065 - INFO - Finished retrieving connections for item 6dfb81c1-26e6-485e-a7f8-4951e8de683f. Total count: 1
# 2025-07-16 18:20:11,065 - INFO - Added 1 connections from item 6dfb81c1-26e6-485e-a7f8-4951e8de683f
# 2025-07-16 18:20:11,065 - INFO - Processing item 20/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765
# 2025-07-16 18:20:11,066 - INFO - Page 1: Making initial request for item a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765
# 2025-07-16 18:20:11,067 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:11,262 - INFO - Response status: 200
# 2025-07-16 18:20:11,263 - INFO - Response contains 1 connections
# 2025-07-16 18:20:11,266 - INFO - Retrieved 1 connections on page 1 for item a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765
# 2025-07-16 18:20:11,267 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765"
# }
# 2025-07-16 18:20:11,267 - INFO - No continuation token found for item a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765 - finished
# 2025-07-16 18:20:11,267 - INFO - Finished retrieving connections for item a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765. Total count: 1
# 2025-07-16 18:20:11,268 - INFO - Added 1 connections from item a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765
# 2025-07-16 18:20:11,268 - INFO - Batch 1 summary: 20/20 items processed successfully, 34 connections found
# 2025-07-16 18:20:11,269 - INFO - Batch 1 completed. Waiting 2 seconds before next batch...
# 2025-07-16 18:20:13,269 - INFO - Processing batch 2/12 (items 21-40)
# 2025-07-16 18:20:13,270 - INFO - Processing item 21/231: workspace=6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba, item=aeba9b75-0a15-4610-bb75-53ccf289cea7
# 2025-07-16 18:20:13,271 - INFO - Page 1: Making initial request for item aeba9b75-0a15-4610-bb75-53ccf289cea7
# 2025-07-16 18:20:13,271 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba/items/aeba9b75-0a15-4610-bb75-53ccf289cea7/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:13,496 - INFO - Response status: 200
# 2025-07-16 18:20:13,497 - INFO - Response contains 1 connections
# 2025-07-16 18:20:13,500 - INFO - Retrieved 1 connections on page 1 for item aeba9b75-0a15-4610-bb75-53ccf289cea7
# 2025-07-16 18:20:13,501 - INFO - Sample connection: {
#   "displayName": "APOLLO_Dashboards_Xion_PRD",
#   "connectivityType": "OnPremisesGateway",
#   "id": "a4a534d9-53f3-4b68-934a-8693aa3d1da4",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connectionDetails": {
#     "path": "QCPWLSQL05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba",
#   "_item_id": "aeba9b75-0a15-4610-bb75-53ccf289cea7"
# }
# 2025-07-16 18:20:13,501 - INFO - No continuation token found for item aeba9b75-0a15-4610-bb75-53ccf289cea7 - finished
# 2025-07-16 18:20:13,502 - INFO - Finished retrieving connections for item aeba9b75-0a15-4610-bb75-53ccf289cea7. Total count: 1
# 2025-07-16 18:20:13,502 - INFO - Added 1 connections from item aeba9b75-0a15-4610-bb75-53ccf289cea7
# 2025-07-16 18:20:13,503 - INFO - Processing item 22/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=becf806f-549c-475c-9bad-8cc1422b1235
# 2025-07-16 18:20:13,503 - INFO - Page 1: Making initial request for item becf806f-549c-475c-9bad-8cc1422b1235
# 2025-07-16 18:20:13,504 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/becf806f-549c-475c-9bad-8cc1422b1235/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:13,716 - INFO - Response status: 200
# 2025-07-16 18:20:13,717 - INFO - Response contains 2 connections
# 2025-07-16 18:20:13,720 - INFO - Retrieved 2 connections on page 1 for item becf806f-549c-475c-9bad-8cc1422b1235
# 2025-07-16 18:20:13,724 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "becf806f-549c-475c-9bad-8cc1422b1235"
# }
# 2025-07-16 18:20:13,725 - INFO - No continuation token found for item becf806f-549c-475c-9bad-8cc1422b1235 - finished
# 2025-07-16 18:20:13,725 - INFO - Finished retrieving connections for item becf806f-549c-475c-9bad-8cc1422b1235. Total count: 2
# 2025-07-16 18:20:13,725 - INFO - Added 2 connections from item becf806f-549c-475c-9bad-8cc1422b1235
# 2025-07-16 18:20:13,727 - INFO - Processing item 23/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=ad7ed97b-e328-47b4-938b-0da76870aa8f
# 2025-07-16 18:20:13,728 - INFO - Page 1: Making initial request for item ad7ed97b-e328-47b4-938b-0da76870aa8f
# 2025-07-16 18:20:13,729 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/ad7ed97b-e328-47b4-938b-0da76870aa8f/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:13,916 - INFO - Response status: 200
# 2025-07-16 18:20:13,917 - INFO - Response contains 1 connections
# 2025-07-16 18:20:13,921 - INFO - Retrieved 1 connections on page 1 for item ad7ed97b-e328-47b4-938b-0da76870aa8f
# 2025-07-16 18:20:13,922 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "ad7ed97b-e328-47b4-938b-0da76870aa8f"
# }
# 2025-07-16 18:20:13,922 - INFO - No continuation token found for item ad7ed97b-e328-47b4-938b-0da76870aa8f - finished
# 2025-07-16 18:20:13,923 - INFO - Finished retrieving connections for item ad7ed97b-e328-47b4-938b-0da76870aa8f. Total count: 1
# 2025-07-16 18:20:13,923 - INFO - Added 1 connections from item ad7ed97b-e328-47b4-938b-0da76870aa8f
# 2025-07-16 18:20:13,924 - INFO - Processing item 24/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=32607afe-b6dd-4dad-83e1-2f69974a10c6
# 2025-07-16 18:20:13,925 - INFO - Page 1: Making initial request for item 32607afe-b6dd-4dad-83e1-2f69974a10c6
# 2025-07-16 18:20:13,925 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/32607afe-b6dd-4dad-83e1-2f69974a10c6/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:14,125 - INFO - Response status: 200
# 2025-07-16 18:20:14,126 - INFO - Response contains 1 connections
# 2025-07-16 18:20:14,129 - INFO - Retrieved 1 connections on page 1 for item 32607afe-b6dd-4dad-83e1-2f69974a10c6
# 2025-07-16 18:20:14,130 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "32607afe-b6dd-4dad-83e1-2f69974a10c6"
# }
# 2025-07-16 18:20:14,131 - INFO - No continuation token found for item 32607afe-b6dd-4dad-83e1-2f69974a10c6 - finished
# 2025-07-16 18:20:14,131 - INFO - Finished retrieving connections for item 32607afe-b6dd-4dad-83e1-2f69974a10c6. Total count: 1
# 2025-07-16 18:20:14,132 - INFO - Added 1 connections from item 32607afe-b6dd-4dad-83e1-2f69974a10c6
# 2025-07-16 18:20:14,132 - INFO - Processing item 25/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=d6f50cc1-2791-4f4e-86e1-9f4779bb5b09
# 2025-07-16 18:20:14,133 - INFO - Page 1: Making initial request for item d6f50cc1-2791-4f4e-86e1-9f4779bb5b09
# 2025-07-16 18:20:14,133 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/d6f50cc1-2791-4f4e-86e1-9f4779bb5b09/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:14,338 - INFO - Response status: 200
# 2025-07-16 18:20:14,339 - INFO - Response contains 1 connections
# 2025-07-16 18:20:14,343 - INFO - Retrieved 1 connections on page 1 for item d6f50cc1-2791-4f4e-86e1-9f4779bb5b09
# 2025-07-16 18:20:14,347 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "d6f50cc1-2791-4f4e-86e1-9f4779bb5b09"
# }
# 2025-07-16 18:20:14,348 - INFO - No continuation token found for item d6f50cc1-2791-4f4e-86e1-9f4779bb5b09 - finished
# 2025-07-16 18:20:14,348 - INFO - Finished retrieving connections for item d6f50cc1-2791-4f4e-86e1-9f4779bb5b09. Total count: 1
# 2025-07-16 18:20:14,349 - INFO - Added 1 connections from item d6f50cc1-2791-4f4e-86e1-9f4779bb5b09
# 2025-07-16 18:20:14,349 - INFO - Processing item 26/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=83e20066-b240-40cf-929a-9bdc55db4f00
# 2025-07-16 18:20:14,350 - INFO - Page 1: Making initial request for item 83e20066-b240-40cf-929a-9bdc55db4f00
# 2025-07-16 18:20:14,351 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/83e20066-b240-40cf-929a-9bdc55db4f00/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:14,580 - INFO - Response status: 200
# 2025-07-16 18:20:14,581 - INFO - Response contains 1 connections
# 2025-07-16 18:20:14,584 - INFO - Retrieved 1 connections on page 1 for item 83e20066-b240-40cf-929a-9bdc55db4f00
# 2025-07-16 18:20:14,585 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "83e20066-b240-40cf-929a-9bdc55db4f00"
# }
# 2025-07-16 18:20:14,585 - INFO - No continuation token found for item 83e20066-b240-40cf-929a-9bdc55db4f00 - finished
# 2025-07-16 18:20:14,585 - INFO - Finished retrieving connections for item 83e20066-b240-40cf-929a-9bdc55db4f00. Total count: 1
# 2025-07-16 18:20:14,586 - INFO - Added 1 connections from item 83e20066-b240-40cf-929a-9bdc55db4f00
# 2025-07-16 18:20:14,586 - INFO - Processing item 27/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=6c8d2fe0-06a0-4e21-be67-c826843c9d97
# 2025-07-16 18:20:14,587 - INFO - Page 1: Making initial request for item 6c8d2fe0-06a0-4e21-be67-c826843c9d97
# 2025-07-16 18:20:14,587 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/6c8d2fe0-06a0-4e21-be67-c826843c9d97/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:14,769 - INFO - Response status: 200
# 2025-07-16 18:20:14,770 - INFO - Response contains 2 connections
# 2025-07-16 18:20:14,773 - INFO - Retrieved 2 connections on page 1 for item 6c8d2fe0-06a0-4e21-be67-c826843c9d97
# 2025-07-16 18:20:14,774 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "6c8d2fe0-06a0-4e21-be67-c826843c9d97"
# }
# 2025-07-16 18:20:14,774 - INFO - No continuation token found for item 6c8d2fe0-06a0-4e21-be67-c826843c9d97 - finished
# 2025-07-16 18:20:14,774 - INFO - Finished retrieving connections for item 6c8d2fe0-06a0-4e21-be67-c826843c9d97. Total count: 2
# 2025-07-16 18:20:14,775 - INFO - Added 2 connections from item 6c8d2fe0-06a0-4e21-be67-c826843c9d97
# 2025-07-16 18:20:14,775 - INFO - Processing item 28/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97
# 2025-07-16 18:20:14,776 - INFO - Page 1: Making initial request for item d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97
# 2025-07-16 18:20:14,777 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:15,075 - INFO - Response status: 200
# 2025-07-16 18:20:15,076 - INFO - Response contains 2 connections
# 2025-07-16 18:20:15,079 - INFO - Retrieved 2 connections on page 1 for item d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97
# 2025-07-16 18:20:15,080 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "d31642e0-cdd3-4cbe-a503-a48dd57729a1",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05.mdanderson.edu;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97"
# }
# 2025-07-16 18:20:15,080 - INFO - No continuation token found for item d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97 - finished
# 2025-07-16 18:20:15,080 - INFO - Finished retrieving connections for item d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97. Total count: 2
# 2025-07-16 18:20:15,081 - INFO - Added 2 connections from item d8b8fbf9-5acf-464a-ac7b-8ff26efe9c97
# 2025-07-16 18:20:15,083 - INFO - Processing item 29/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=cc007bbe-7cae-4a44-8cb0-a2a97ad2422b
# 2025-07-16 18:20:15,084 - INFO - Page 1: Making initial request for item cc007bbe-7cae-4a44-8cb0-a2a97ad2422b
# 2025-07-16 18:20:15,084 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/cc007bbe-7cae-4a44-8cb0-a2a97ad2422b/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:15,442 - INFO - Response status: 200
# 2025-07-16 18:20:15,443 - INFO - Response contains 1 connections
# 2025-07-16 18:20:15,446 - INFO - Retrieved 1 connections on page 1 for item cc007bbe-7cae-4a44-8cb0-a2a97ad2422b
# 2025-07-16 18:20:15,447 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "cc007bbe-7cae-4a44-8cb0-a2a97ad2422b"
# }
# 2025-07-16 18:20:15,447 - INFO - No continuation token found for item cc007bbe-7cae-4a44-8cb0-a2a97ad2422b - finished
# 2025-07-16 18:20:15,448 - INFO - Finished retrieving connections for item cc007bbe-7cae-4a44-8cb0-a2a97ad2422b. Total count: 1
# 2025-07-16 18:20:15,448 - INFO - Added 1 connections from item cc007bbe-7cae-4a44-8cb0-a2a97ad2422b
# 2025-07-16 18:20:15,449 - INFO - Processing item 30/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660
# 2025-07-16 18:20:15,449 - INFO - Page 1: Making initial request for item ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660
# 2025-07-16 18:20:15,450 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:15,634 - INFO - Response status: 200
# 2025-07-16 18:20:15,635 - INFO - Response contains 2 connections
# 2025-07-16 18:20:15,638 - INFO - Retrieved 2 connections on page 1 for item ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660
# 2025-07-16 18:20:15,639 - INFO - Sample connection: {
#   "connectivityType": "OnPremisesGatewayPersonal",
#   "id": "d31642e0-cdd3-4cbe-a503-a48dd57729a1",
#   "gatewayId": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connectionDetails": {
#     "path": "qcpwlsql05.mdanderson.edu;APOLLO5",
#     "type": "SQL"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660"
# }
# 2025-07-16 18:20:15,639 - INFO - No continuation token found for item ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660 - finished
# 2025-07-16 18:20:15,639 - INFO - Finished retrieving connections for item ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660. Total count: 2
# 2025-07-16 18:20:15,641 - INFO - Added 2 connections from item ebe7b348-21f5-4c4d-a9b5-b0d6b79ee660
# 2025-07-16 18:20:15,641 - INFO - Processing item 31/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=4bf4a2d8-ad06-4e81-a735-75e5fc274286
# 2025-07-16 18:20:15,641 - INFO - Page 1: Making initial request for item 4bf4a2d8-ad06-4e81-a735-75e5fc274286
# 2025-07-16 18:20:15,642 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/4bf4a2d8-ad06-4e81-a735-75e5fc274286/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:15,899 - INFO - Response status: 200
# 2025-07-16 18:20:15,900 - INFO - Response contains 1 connections
# 2025-07-16 18:20:15,903 - INFO - Retrieved 1 connections on page 1 for item 4bf4a2d8-ad06-4e81-a735-75e5fc274286
# 2025-07-16 18:20:15,903 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "4bf4a2d8-ad06-4e81-a735-75e5fc274286"
# }
# 2025-07-16 18:20:15,903 - INFO - No continuation token found for item 4bf4a2d8-ad06-4e81-a735-75e5fc274286 - finished
# 2025-07-16 18:20:15,904 - INFO - Finished retrieving connections for item 4bf4a2d8-ad06-4e81-a735-75e5fc274286. Total count: 1
# 2025-07-16 18:20:15,904 - INFO - Added 1 connections from item 4bf4a2d8-ad06-4e81-a735-75e5fc274286
# 2025-07-16 18:20:15,904 - INFO - Processing item 32/231: workspace=122d675e-1ec9-497d-9709-7084a5bcf3ae, item=645aba88-bc2e-41f8-bfc9-4cc00a53c47c
# 2025-07-16 18:20:15,905 - INFO - Page 1: Making initial request for item 645aba88-bc2e-41f8-bfc9-4cc00a53c47c
# 2025-07-16 18:20:15,906 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/122d675e-1ec9-497d-9709-7084a5bcf3ae/items/645aba88-bc2e-41f8-bfc9-4cc00a53c47c/connections with params: {} (Attempt 1)
# 2025-07-16 18:20:16,186 - INFO - Response status: 200
# 2025-07-16 18:20:16,187 - INFO - Response contains 2 connections
# 2025-07-16 18:20:16,190 - INFO - Retrieved 2 connections on page 1 for item 645aba88-bc2e-41f8-bfc9-4cc00a53c47c
# 2025-07-16 18:20:16,190 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "8350496a-b6e8-4785-a28e-201c89630686",
#   "connectionDetails": {
#     "path": "https://worldtimeapi.org/api/timezone/america/chicago",
#     "type": "Web"
#   },
#   "_workspace_id": "122d675e-1ec9-497d-9709-7084a5bcf3ae",
#   "_item_id": "645aba88-bc2e-41f8-bfc9-4cc00a53c47c"
# }
# 2025-07-16 18:20:16,191 - INFO - No continuation token found for item 645aba88-bc2e-41f8-bfc9-4cc00a53c47c - finished
# ...
# 2025-07-16 18:26:40,164 - INFO - Response status: 200
# 2025-07-16 18:26:40,164 - INFO - Response contains 0 connections
# 2025-07-16 18:26:40,167 - INFO - No connections found on page 1 for item 965a7afc-e316-4a2e-8b65-c4570a1c4821
# 2025-07-16 18:26:40,167 - INFO - No continuation token found for item 965a7afc-e316-4a2e-8b65-c4570a1c4821 - finished
# 2025-07-16 18:26:40,168 - INFO - Finished retrieving connections for item 965a7afc-e316-4a2e-8b65-c4570a1c4821. Total count: 0
# 2025-07-16 18:26:40,168 - INFO - Processing item 225/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=4c08d546-af3a-4e9b-b61e-63f0b80e884c
# 2025-07-16 18:26:40,169 - INFO - Page 1: Making initial request for item 4c08d546-af3a-4e9b-b61e-63f0b80e884c
# 2025-07-16 18:26:40,169 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/4c08d546-af3a-4e9b-b61e-63f0b80e884c/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:40,368 - INFO - Response status: 200
# 2025-07-16 18:26:40,369 - INFO - Response contains 0 connections
# 2025-07-16 18:26:40,372 - INFO - No connections found on page 1 for item 4c08d546-af3a-4e9b-b61e-63f0b80e884c
# 2025-07-16 18:26:40,373 - INFO - No continuation token found for item 4c08d546-af3a-4e9b-b61e-63f0b80e884c - finished
# 2025-07-16 18:26:40,373 - INFO - Finished retrieving connections for item 4c08d546-af3a-4e9b-b61e-63f0b80e884c. Total count: 0
# 2025-07-16 18:26:40,374 - INFO - Processing item 226/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-16 18:26:40,374 - INFO - Page 1: Making initial request for item c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-16 18:26:40,375 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/c053b33b-5241-42c2-8785-65a1b337e7fe/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:40,758 - INFO - Response status: 200
# 2025-07-16 18:26:40,758 - INFO - Response contains 0 connections
# 2025-07-16 18:26:40,762 - INFO - No connections found on page 1 for item c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-16 18:26:40,763 - INFO - No continuation token found for item c053b33b-5241-42c2-8785-65a1b337e7fe - finished
# 2025-07-16 18:26:40,763 - INFO - Finished retrieving connections for item c053b33b-5241-42c2-8785-65a1b337e7fe. Total count: 0
# 2025-07-16 18:26:40,764 - INFO - Processing item 227/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=9025e0d8-2bc5-48d9-ac62-5513244842bd
# 2025-07-16 18:26:40,764 - INFO - Page 1: Making initial request for item 9025e0d8-2bc5-48d9-ac62-5513244842bd
# 2025-07-16 18:26:40,765 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/9025e0d8-2bc5-48d9-ac62-5513244842bd/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:41,002 - INFO - Response status: 200
# 2025-07-16 18:26:41,003 - INFO - Response contains 1 connections
# 2025-07-16 18:26:41,006 - INFO - Retrieved 1 connections on page 1 for item 9025e0d8-2bc5-48d9-ac62-5513244842bd
# 2025-07-16 18:26:41,006 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "30d92dc2-4a7b-4719-92a7-97c26a879d8a",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "type": "PowerPlatformDataflows"
#   },
#   "_workspace_id": "5d190284-0524-4c74-8389-c36e173fd290",
#   "_item_id": "9025e0d8-2bc5-48d9-ac62-5513244842bd"
# }
# 2025-07-16 18:26:41,007 - INFO - No continuation token found for item 9025e0d8-2bc5-48d9-ac62-5513244842bd - finished
# 2025-07-16 18:26:41,007 - INFO - Finished retrieving connections for item 9025e0d8-2bc5-48d9-ac62-5513244842bd. Total count: 1
# 2025-07-16 18:26:41,007 - INFO - Added 1 connections from item 9025e0d8-2bc5-48d9-ac62-5513244842bd
# 2025-07-16 18:26:41,008 - INFO - Processing item 228/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-16 18:26:41,009 - INFO - Page 1: Making initial request for item 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-16 18:26:41,009 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/48d932f8-8b64-4b34-a67c-e08de77d9c3b/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:41,614 - INFO - Response status: 200
# 2025-07-16 18:26:41,615 - INFO - Response contains 0 connections
# 2025-07-16 18:26:41,618 - INFO - No connections found on page 1 for item 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-16 18:26:41,618 - INFO - No continuation token found for item 48d932f8-8b64-4b34-a67c-e08de77d9c3b - finished
# 2025-07-16 18:26:41,619 - INFO - Finished retrieving connections for item 48d932f8-8b64-4b34-a67c-e08de77d9c3b. Total count: 0
# 2025-07-16 18:26:41,619 - INFO - Processing item 229/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-16 18:26:41,619 - INFO - Page 1: Making initial request for item 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-16 18:26:41,620 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/8d248811-c245-4a94-b409-c508f5e00677/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:41,893 - INFO - Response status: 200
# 2025-07-16 18:26:41,893 - INFO - Response contains 1 connections
# 2025-07-16 18:26:41,897 - INFO - Retrieved 1 connections on page 1 for item 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-16 18:26:41,897 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "6a2e8e24-ffb4-42ae-a5b7-9d5c0928e98c",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "type": "UsageMetricsDataConnector"
#   },
#   "_workspace_id": "5d190284-0524-4c74-8389-c36e173fd290",
#   "_item_id": "8d248811-c245-4a94-b409-c508f5e00677"
# }
# 2025-07-16 18:26:41,898 - INFO - No continuation token found for item 8d248811-c245-4a94-b409-c508f5e00677 - finished
# 2025-07-16 18:26:41,899 - INFO - Finished retrieving connections for item 8d248811-c245-4a94-b409-c508f5e00677. Total count: 1
# 2025-07-16 18:26:41,899 - INFO - Added 1 connections from item 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-16 18:26:41,900 - INFO - Processing item 230/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=26b89d56-745a-4420-ac11-405d1fa3096a
# 2025-07-16 18:26:41,900 - INFO - Page 1: Making initial request for item 26b89d56-745a-4420-ac11-405d1fa3096a
# 2025-07-16 18:26:41,901 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/26b89d56-745a-4420-ac11-405d1fa3096a/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:42,348 - INFO - Response status: 200
# 2025-07-16 18:26:42,349 - INFO - Response contains 2 connections
# 2025-07-16 18:26:42,352 - INFO - Retrieved 2 connections on page 1 for item 26b89d56-745a-4420-ac11-405d1fa3096a
# 2025-07-16 18:26:42,353 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "1b404526-46f1-446a-8cee-e3f05d319d1c",
#   "connectionDetails": {
#     "path": "GoogleBigQuery",
#     "type": "GoogleBigQuery"
#   },
#   "_workspace_id": "5d190284-0524-4c74-8389-c36e173fd290",
#   "_item_id": "26b89d56-745a-4420-ac11-405d1fa3096a"
# }
# 2025-07-16 18:26:42,353 - INFO - No continuation token found for item 26b89d56-745a-4420-ac11-405d1fa3096a - finished
# 2025-07-16 18:26:42,354 - INFO - Finished retrieving connections for item 26b89d56-745a-4420-ac11-405d1fa3096a. Total count: 2
# 2025-07-16 18:26:42,355 - INFO - Added 2 connections from item 26b89d56-745a-4420-ac11-405d1fa3096a
# 2025-07-16 18:26:42,355 - INFO - Processing item 231/231: workspace=5d190284-0524-4c74-8389-c36e173fd290, item=af6e07af-fc88-4f06-ab55-57f519a81ed3
# 2025-07-16 18:26:42,356 - INFO - Page 1: Making initial request for item af6e07af-fc88-4f06-ab55-57f519a81ed3
# 2025-07-16 18:26:42,356 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/workspaces/5d190284-0524-4c74-8389-c36e173fd290/items/af6e07af-fc88-4f06-ab55-57f519a81ed3/connections with params: {} (Attempt 1)
# 2025-07-16 18:26:42,639 - INFO - Response status: 200
# 2025-07-16 18:26:42,639 - INFO - Response contains 2 connections
# 2025-07-16 18:26:42,642 - INFO - Retrieved 2 connections on page 1 for item af6e07af-fc88-4f06-ab55-57f519a81ed3
# 2025-07-16 18:26:42,642 - INFO - Sample connection: {
#   "connectivityType": "PersonalCloud",
#   "id": "30d92dc2-4a7b-4719-92a7-97c26a879d8a",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "type": "PowerPlatformDataflows"
#   },
#   "_workspace_id": "5d190284-0524-4c74-8389-c36e173fd290",
#   "_item_id": "af6e07af-fc88-4f06-ab55-57f519a81ed3"
# }
# 2025-07-16 18:26:42,643 - INFO - No continuation token found for item af6e07af-fc88-4f06-ab55-57f519a81ed3 - finished
# 2025-07-16 18:26:42,643 - INFO - Finished retrieving connections for item af6e07af-fc88-4f06-ab55-57f519a81ed3. Total count: 2
# 2025-07-16 18:26:42,644 - INFO - Added 2 connections from item af6e07af-fc88-4f06-ab55-57f519a81ed3
# 2025-07-16 18:26:42,644 - INFO - Batch 12 summary: 11/11 items processed successfully, 6 connections found
# 2025-07-16 18:26:42,644 - INFO - Finished processing all items. Total connections found: 266
# 2025-07-16 18:26:42,645 - INFO - Creating DataFrame for 266 connections...
# 2025-07-16 18:26:52,870 - INFO - Delta table 'fabric_items_connections' already exists
# 2025-07-16 18:26:52,871 - INFO - Starting merge operation for fabric_items_connections
# 2025-07-16 18:27:07,781 - INFO - Merge operation completed successfully
# 2025-07-16 18:27:07,781 - INFO - Optimizing Delta table 'fabric_items_connections'
# +------------------------------------+------------------------------------+
# |WorkspaceID                         |ItemID                              |
# +------------------------------------+------------------------------------+
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|f08cffd2-bd9f-4c46-b4bd-1c58f9153fde|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|69653dc2-dcee-4688-b832-b17a2438dc9a|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|b335dadd-91e1-4bd5-9286-fc1b11eef750|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|8beeb061-c1e7-4717-aaf8-f7f0de781d80|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|0debddf5-8b75-408d-91a7-a034f529252f|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|abc87d9b-7aae-4e9a-9144-03c55b775059|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|d695a243-9542-4498-95a3-54f1f8a2176b|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|5cde3586-177e-4d76-aeef-7983cb732f69|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|3d9ff0bd-aa57-4e9c-9a2e-4e81ba4b80d1|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|02e8492b-24e6-45c6-be48-1b6d319741ef|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|de07e2a4-25a5-4c2a-9e02-86c2a8dd7ae8|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|27dd9f56-5ee2-404a-97d9-95b29a6d2868|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|b72b3066-372e-4c85-839b-c171be60dfd6|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|c97c34f2-02d7-46a3-876b-c3c8fc5c865c|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|4f0cbf99-9bdf-4d84-bc6f-c655e10bcb81|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|98c8549a-37d0-47cb-83f0-4101b9dcddc6|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|112ffecd-2aa3-4571-8daa-a7342f25a4c7|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|6dfb81c1-26e6-485e-a7f8-4951e8de683f|
# |6cf9f4f0-0f1a-4514-82d6-ac6eb63f40ba|a65d3c8f-6c4b-43dd-9f08-b4fcbbf5d765|
# +------------------------------------+------------------------------------+
# only showing top 20 rows
#
# +------------------------------------+------------------------------------+------------------------------------+------------+-------------------------+------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------+--------------------------+
# |workspace_id                        |item_id                             |connection_id                       |display_name|connectivity_type        |gateway_id                          |connection_details_type|connection_details_path                                                                                                         |connection_hash                 |extraction_timestamp      |
# +------------------------------------+------------------------------------+------------------------------------+------------+-------------------------+------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------+--------------------------+
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|fe1af4fe-6046-46f7-be68-71961d8aff0b|NULL        |OnPremisesGatewayPersonal|a9ef46b6-b653-474e-ad63-a58c7287c40c|File                   |file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Data%20Files_Extracts/Archived%20SI%20Extracts/SI_Extract.csv    |47144a2449549a5aa9070b5497ee045b|2025-07-16 18:26:43.826363|
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|18fd0c54-1be7-47a4-a0bf-ab4b73f52740|NULL        |OnPremisesGatewayPersonal|a9ef46b6-b653-474e-ad63-a58c7287c40c|File                   |file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Data%20Files_Extracts/RL%20Extract%201.3%20-%20General%203.csv   |0d4bab9077cf43c6c300e161eb2acc40|2025-07-16 18:26:43.826363|
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|74a2e336-2b92-43f4-862d-fd96b28ec207|NULL        |OnPremisesGatewayPersonal|a9ef46b6-b653-474e-ad63-a58c7287c40c|File                   |file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Reference_Mapping%20Tables/Medications%20-%20AHFS%20Mapping.xlsx |9b0a649a6e43d94837cb10836240339b|2025-07-16 18:26:43.826363|
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|51d34ae9-969b-41de-b13b-2157f3282ec1|NULL        |OnPremisesGatewayPersonal|a9ef46b6-b653-474e-ad63-a58c7287c40c|File                   |file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Data%20Files_Extracts/Archived%20SI%20Extracts/SI_Extract%202.csv|a18d26956f2b160a07fe65ad71b00d31|2025-07-16 18:26:43.826363|
# |3dc16785-8298-4567-880a-9919f074555f|fe1918d6-0a63-4b30-9208-afc8e5c1d5df|60073b46-44ef-4db7-8096-0f0dfe46f716|NULL        |OnPremisesGatewayPersonal|a9ef46b6-b653-474e-ad63-a58c7287c40c|File                   |file://mymdafiles/research/MedInfo/COMMON/DSS/Patient%20Safety/Data%20Files_Extracts/RL%20Extract%201.6%20-%20General%206.csv   |c59c117aa5ce85f17cf30b099859a9d2|2025-07-16 18:26:43.826363|
# +------------------------------------+------------------------------------+------------------------------------+------------+-------------------------+------------------------------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------+--------------------------+
# only showing top 5 rows
#
# +-------------------------+-----+
# |connectivity_type        |count|
# +-------------------------+-----+
# |PersonalCloud            |182  |
# |OnPremisesGatewayPersonal|46   |
# |OnPremisesGateway        |40   |
# |Automatic                |9    |
# |None                     |1    |
# +-------------------------+-----+
#
# +-------------------------+-----+
# |connection_details_type  |count|
# +-------------------------+-----+
# |Web                      |82   |
# |SQL                      |63   |
# |PowerPlatformDataflows   |30   |
# |File                     |28   |
# |AnalysisServices         |24   |
# |SharePoint               |21   |
# |UsageMetricsDataConnector|10   |
# |PowerBI                  |9    |
# |Oracle                   |5    |
# |GoogleBigQuery           |4    |
# |CommonDataService        |1    |
# |AzureDataExplorer        |1    |
# +-------------------------+-----+

# %%
from pyspark.sql import SparkSession

# create Spark session
spark = SparkSession.builder.appName("Refresh SQL Endpoint Metadata").getOrCreate()

# refresh the specific table
spark.sql("REFRESH TABLE fabric_items_connections")
print("Metadata refresh triggered successfully.")
# Out:
# StatementMeta(, d586d30c-5929-4ada-8fa4-df0be3edb891, 7, Finished, Available, Finished)
# Metadata refresh triggered successfully.
