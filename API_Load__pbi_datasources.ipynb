# %%
# DO NOT DELETE THIS CELL

# ***IMPORTANT***: This only pulls datasources for workspaces on the "MDA Institutional Capacity - PROD" capacity!!!!  See query around line 90!
# Some of these API calls result in "404 Client Error: Not Found for url". I *think* this is due to a datasource not existing for a particular dataset.

# API Name: Datasets - Get Datasources
# Command:  GET https://api.powerbi.com/v1.0/myorg/datasets/{datasetId}/datasources
# Doc:      https://learn.microsoft.com/en-us/rest/api/power-bi/datasets/get-datasources

# Loads table: pbi_datasources
# Loads table: pbi_datasources_connection_details
# Out:
# StatementMeta(, fad4e198-0861-46c0-97cc-62ecf271dbdc, 3, Finished, Available, Finished)

# %%
# CELL 1 - Title and Introduction
# ==================================
# Microsoft Power BI Datasources to Delta Lake - PySpark Notebook
# This notebook retrieves Power BI datasources using the Get Datasources API and loads them into Delta Lake tables
# with optimization for analytics workloads. Data is stored in two normalized tables:
# 1. pbi_datasources - Main datasource information
# 2. pbi_datasources_connection_details - Connection detail properties in key-value format
# ==================================


# CELL 2 - Import Libraries
# ==================================
# Import required libraries for API calls, data processing, and Delta Lake operations
import requests
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_timestamp, lit, from_json, explode, create_map
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, ArrayType, MapType
import logging
from typing import Dict, List, Optional, Tuple
from delta.tables import DeltaTable
import random
import time
import uuid
from datetime import datetime
# ==================================


# CELL 3 - Configure Logging and Initialize Spark
# ==================================
# Configure logging to track execution and debug issues
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize Spark Session with Delta Lake configurations
# In Fabric notebooks, Spark is pre-configured with Delta support
spark = SparkSession.builder \
    .appName("PowerBIDatasourcesToDelta") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Set optimal configurations for Delta operations
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "true")
spark.conf.set("spark.databricks.delta.autoCompact.enabled", "true")
# ==================================


# CELL 4 - Configuration Parameters
# ==================================
# Configuration Parameters for the notebook execution
CONFIG = {
    "API_BASE_URL": "https://api.powerbi.com/v1.0/myorg",
    "DATASOURCES_ENDPOINT": "/datasets/{dataset_id}/datasources",  # Endpoint for getting datasources
    "MAX_RETRIES": 1,  # Number of retries for handling rate limits and transient failures
    "INITIAL_BACKOFF_SEC": 1,  # Initial backoff time in seconds
    "MAX_BACKOFF_SEC": 60,  # Maximum backoff time in seconds  
    "BACKOFF_FACTOR": 2,  # Exponential backoff multiplier
    "JITTER_FACTOR": 0.1,  # Random jitter to add to backoff (as a fraction)
    "TIMEOUT": 30,  # API request timeout in seconds
    "DATASOURCES_TABLE_NAME": "pbi_datasources",  # Main datasources table
    "CONNECTION_DETAILS_TABLE_NAME": "pbi_datasources_connection_details",  # Connection details table
    "LAKEHOUSE_PATH": "Tables",  # Default Tables folder in Fabric Lakehouse
    "DEBUG_MODE": True,  # Set to True to enable extra debugging output
    "TEST_LIMIT": None,  # Limit to 20 datasets for testing (will be removed later)
    "BATCH_SIZE": 10  # Process datasets in batches to manage API rate limits
}

# Generate a unique batch ID for this execution run
BATCH_ID = str(uuid.uuid4())
logger.info(f"Starting execution with batch ID: {BATCH_ID}")
# ==================================


# CELL 5 - Get Dataset IDs Function
# ==================================
def get_dataset_ids() -> List[str]:
    """
    Execute the SQL query to get dataset IDs from the existing Fabric tables.
    
    This function runs the provided SQL query to get dataset IDs from datasets
    that belong to the 'MDA Institutional Capacity - PROD' capacity.
    
    Returns:
        list: A list of dataset ID strings
    """
    try:
        logger.info("Executing SQL query to retrieve dataset IDs...")
        
        # Execute the provided SQL query
        sql_query = """
        SELECT ds.id
        FROM 
            FabricAdmin_Lakehouse.dbo.fabric_capacities AS fc
        JOIN 
            FabricAdmin_Lakehouse.dbo.fabric_workspaces AS fw
            ON UPPER(fc.id) = fw.capacityId  
        JOIN 
            FabricAdmin_Lakehouse.dbo.pbi_datasets AS ds
            ON fw.id = ds.workspaceId  
        WHERE 
            fc.displayName = 'MDA Institutional Capacity - PROD'  
            AND fw.state = 'Active'  
            AND fw.type <> 'Personal'
        """
        
        # Add test limit for initial testing
        if CONFIG['TEST_LIMIT']:
            sql_query += f" LIMIT {CONFIG['TEST_LIMIT']}"
            logger.info(f"Limiting to {CONFIG['TEST_LIMIT']} datasets for testing")
        
        # Execute the query
        result_df = spark.sql(sql_query)
        
        # Convert to list of dataset IDs
        dataset_ids = [row.id for row in result_df.collect()]
        
        logger.info(f"Retrieved {len(dataset_ids)} dataset IDs from the database")
        
        if CONFIG['DEBUG_MODE'] and dataset_ids:
            logger.info(f"Sample dataset IDs: {dataset_ids[:5]}")
        
        return dataset_ids
        
    except Exception as e:
        logger.error(f"Failed to retrieve dataset IDs: {str(e)}")
        raise
# ==================================


# CELL 6 - Authentication Function
# ==================================
def get_access_token():
    """
    Get Azure AD access token for Power BI API authentication.
    
    In a Fabric notebook, the token is automatically available through mssparkutils.
    This function retrieves the token needed to authenticate with the Power BI REST API.
    
    Returns:
        str: The access token
    
    Note:
        mssparkutils is a utility library provided by Microsoft Fabric
        that handles authentication automatically.
    """
    try:
        # In Fabric notebooks, we can get the token using mssparkutils
        from notebookutils import mssparkutils
        token_response = mssparkutils.credentials.getToken("https://analysis.windows.net/powerbi/api")
        return token_response
    except Exception as e:
        logger.error(f"Failed to get access token: {str(e)}")
        raise
# ==================================


# CELL 7 - API Call Function
# ==================================
def call_powerbi_api(endpoint: str, access_token: str, params: Optional[Dict] = None) -> Dict:
    """
    Make a REST API call to Power BI with advanced rate limit handling.
    
    This function handles the HTTP request to the Power BI API, including:
    - Setting up authentication headers
    - Managing retries with intelligent backoff for rate limiting (429 errors)
    - Implementing jitter to avoid synchronized retries
    - Detailed error handling and logging
    
    Args:
        endpoint: The API endpoint path (e.g., "/datasets/{dataset_id}/datasources")
        access_token: The Azure AD access token
        params: Optional query parameters for the API call
    
    Returns:
        dict: The JSON response from the API
    
    Raises:
        requests.exceptions.RequestException: If the API call fails after all retries
    """
    url = f"{CONFIG['API_BASE_URL']}{endpoint}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    # Initialize backoff time
    backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
    
    # Retry logic with intelligent backoff
    for attempt in range(CONFIG['MAX_RETRIES']):
        try:
            # Log the full URL with parameters for debugging
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Making API call to: {url} with params: {params} (Attempt {attempt + 1})")
            
            response = requests.get(
                url,
                headers=headers,
                params=params,
                timeout=CONFIG['TIMEOUT']
            )
            
            # Log the response status for debugging
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Response status: {response.status_code}")
            
            # Rate limit handling (429 Too Many Requests)
            if response.status_code == 429:
                # Get retry-after header if available, otherwise use our backoff
                retry_after = response.headers.get('Retry-After')
                
                if retry_after and retry_after.isdigit():
                    # If server specified a wait time, use it
                    wait_time = int(retry_after)
                else:
                    # Calculate wait time with exponential backoff and jitter
                    jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                    wait_time = backoff_time + jitter
                    # Update backoff for next attempt
                    backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.warning(f"Rate limit exceeded (429). Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
                continue  # Skip to next retry attempt without raising exception
            
            # Log the response for debugging in case of errors
            if response.status_code >= 400:
                logger.error(f"API error: Status {response.status_code}, Response: {response.text}")
                logger.error(f"Request URL: {response.request.url}")
                logger.error(f"Request headers: {response.request.headers}")
            
            # For all other status codes, use raise_for_status to handle
            response.raise_for_status()
            
            # If we get here, the request was successful
            # Reset backoff for next API call (not next attempt)
            backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
            
            # Log a sample of the response content for debugging
            try:
                response_json = response.json()
                if "value" in response_json and isinstance(response_json["value"], list):
                    logger.info(f"Response contains {len(response_json['value'])} datasources")
                return response_json
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse response as JSON: {str(e)}")
                logger.error(f"Response content: {response.text[:1000]}")  # Log first 1000 chars of response
                raise
            
        except requests.exceptions.RequestException as e:
            last_attempt = attempt == CONFIG['MAX_RETRIES'] - 1
            
            # Special handling for non-429 errors
            if not (hasattr(e, 'response') and e.response is not None and e.response.status_code == 429):
                logger.warning(f"API call failed (Attempt {attempt + 1}): {str(e)}")
                
                if last_attempt:
                    logger.error(f"All retry attempts failed for endpoint: {endpoint}")
                    logger.error(f"Final error: {str(e)}")
                    raise
                
                # Calculate wait time with exponential backoff and jitter
                jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                wait_time = backoff_time + jitter
                # Update backoff for next attempt
                backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.info(f"Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
# ==================================


# CELL 8 - Get Datasources Function
# ==================================
def get_datasources_for_dataset(dataset_id: str, access_token: str) -> Tuple[List[Dict], List[Dict]]:
    """
    Retrieve datasources for a specific dataset from the Power BI API.
    
    This function calls the Get Datasources API for a single dataset and
    processes the response to separate main datasource info from connection details.
    
    Args:
        dataset_id: The dataset ID to get datasources for
        access_token: The Azure AD access token
    
    Returns:
        tuple: (datasources_records, connection_details_records)
            - datasources_records: List of main datasource info dictionaries
            - connection_details_records: List of connection detail key-value dictionaries
    """
    try:
        # Construct the endpoint with the dataset ID
        endpoint = CONFIG['DATASOURCES_ENDPOINT'].format(dataset_id=dataset_id)
        
        # Make the API call
        response_data = call_powerbi_api(endpoint, access_token)
        
        # Extract datasources from the response
        datasources = response_data.get("value", [])
        
        if not datasources:
            logger.info(f"No datasources found for dataset {dataset_id}")
            return [], []
        
        logger.info(f"Retrieved {len(datasources)} datasources for dataset {dataset_id}")
        
        # Process each datasource to separate main info from connection details
        datasources_records = []
        connection_details_records = []
        
        for datasource in datasources:
            # Extract main datasource information
            main_record = {
                "dataset_id": dataset_id,
                "datasource_type": datasource.get("datasourceType"),
                "datasource_id": datasource.get("datasourceId"),
                "gateway_id": datasource.get("gatewayId"),
                "connection_string": datasource.get("connectionString"),  # Deprecated field
                "name": datasource.get("name"),  # Deprecated field
                "extraction_date": datetime.now(),
                "extraction_batch_id": BATCH_ID
            }
            datasources_records.append(main_record)
            
            # Extract connection details (if they exist)
            connection_details = datasource.get("connectionDetails", {})
            
            if connection_details and isinstance(connection_details, dict):
                for property_name, property_value in connection_details.items():
                    # Only include non-null values
                    if property_value is not None:
                        detail_record = {
                            "dataset_id": dataset_id,
                            "datasource_id": datasource.get("datasourceId"),
                            "connection_property": property_name,
                            "connection_value": str(property_value),  # Convert to string for consistency
                            "extraction_date": datetime.now(),
                            "extraction_batch_id": BATCH_ID
                        }
                        connection_details_records.append(detail_record)
        
        if CONFIG['DEBUG_MODE']:
            logger.info(f"Dataset {dataset_id}: {len(datasources_records)} datasources, {len(connection_details_records)} connection details")
            
            # Log a sample datasource for debugging
            if datasources_records:
                logger.info(f"Sample datasource: {json.dumps(datasources[0], indent=2)}")
        
        return datasources_records, connection_details_records
        
    except Exception as e:
        logger.error(f"Failed to retrieve datasources for dataset {dataset_id}: {str(e)}")
        # Return empty lists instead of raising to allow processing to continue
        return [], []
# ==================================


# CELL 9 - Batch Processing Function
# ==================================
def process_datasets_in_batches(dataset_ids: List[str], access_token: str) -> Tuple[List[Dict], List[Dict]]:
    """
    Process datasets in batches to retrieve all datasources efficiently.
    
    This function processes datasets in smaller batches to:
    - Manage API rate limits more effectively
    - Provide progress updates
    - Handle failures gracefully
    
    Args:
        dataset_ids: List of dataset IDs to process
        access_token: The Azure AD access token
    
    Returns:
        tuple: (all_datasources_records, all_connection_details_records)
    """
    all_datasources = []
    all_connection_details = []
    
    total_datasets = len(dataset_ids)
    batch_size = CONFIG['BATCH_SIZE']
    
    logger.info(f"Processing {total_datasets} datasets in batches of {batch_size}")
    
    # Process datasets in batches
    for i in range(0, total_datasets, batch_size):
        batch_end = min(i + batch_size, total_datasets)
        batch_datasets = dataset_ids[i:batch_end]
        batch_number = (i // batch_size) + 1
        total_batches = (total_datasets + batch_size - 1) // batch_size
        
        logger.info(f"Processing batch {batch_number}/{total_batches} (datasets {i+1}-{batch_end})")
        
        # Process each dataset in the current batch
        for j, dataset_id in enumerate(batch_datasets):
            try:
                logger.info(f"Processing dataset {i+j+1}/{total_datasets}: {dataset_id}")
                
                datasources, connection_details = get_datasources_for_dataset(dataset_id, access_token)
                
                # Add to our collections
                all_datasources.extend(datasources)
                all_connection_details.extend(connection_details)
                
                # Add a small delay between API calls to be respectful
                time.sleep(0.1)
                
            except Exception as e:
                logger.error(f"Failed to process dataset {dataset_id}: {str(e)}")
                # Continue with the next dataset instead of failing the entire batch
                continue
        
        # Add a longer delay between batches to manage rate limits
        if batch_number < total_batches:
            logger.info(f"Completed batch {batch_number}. Waiting 2 seconds before next batch...")
            time.sleep(2)
    
    logger.info(f"Batch processing completed. Total datasources: {len(all_datasources)}, Total connection details: {len(all_connection_details)}")
    
    return all_datasources, all_connection_details
# ==================================


# CELL 10 - Create DataFrames Function
# ==================================
def create_datasources_dataframes(datasources_data: List[Dict], connection_details_data: List[Dict]) -> Tuple["DataFrame", "DataFrame"]:
    """
    Convert the datasources data into PySpark DataFrames for Delta Lake storage.
    
    This function creates two separate DataFrames:
    1. Main datasources DataFrame with core datasource information
    2. Connection details DataFrame with key-value pairs for connection properties
    
    Args:
        datasources_data: List of main datasource dictionaries
        connection_details_data: List of connection detail dictionaries
    
    Returns:
        tuple: (datasources_df, connection_details_df)
    """
    
    # Define schema for main datasources table
    datasources_schema = StructType([
        StructField("dataset_id", StringType(), False),           # Required - dataset this belongs to
        StructField("datasource_type", StringType(), True),       # Type of datasource (Sql, Oracle, etc.)
        StructField("datasource_id", StringType(), True),         # Unique datasource identifier (can be null)
        StructField("gateway_id", StringType(), True),            # Gateway ID (nullable)
        StructField("connection_string", StringType(), True),     # Deprecated field (nullable)
        StructField("name", StringType(), True),                  # Deprecated field (nullable)
        StructField("extraction_date", TimestampType(), False),   # When data was extracted
        StructField("extraction_batch_id", StringType(), False)   # Batch identifier
    ])
    
    # Define schema for connection details table
    connection_details_schema = StructType([
        StructField("dataset_id", StringType(), False),           # Required - dataset this belongs to
        StructField("datasource_id", StringType(), True),         # Datasource ID (can be null)
        StructField("connection_property", StringType(), False),  # Property name (server, database, etc.)
        StructField("connection_value", StringType(), True),      # Property value (nullable)
        StructField("extraction_date", TimestampType(), False),   # When data was extracted
        StructField("extraction_batch_id", StringType(), False)   # Batch identifier
    ])
    
    # Create main datasources DataFrame
    if datasources_data:
        logger.info(f"Creating datasources DataFrame with {len(datasources_data)} records")
        datasources_pandas_df = pd.DataFrame(datasources_data)
        datasources_df = spark.createDataFrame(datasources_pandas_df, schema=datasources_schema)
    else:
        logger.warning("No datasources data found. Creating empty DataFrame.")
        datasources_df = spark.createDataFrame([], datasources_schema)
    
    # Create connection details DataFrame
    if connection_details_data:
        logger.info(f"Creating connection details DataFrame with {len(connection_details_data)} records")
        connection_details_pandas_df = pd.DataFrame(connection_details_data)
        connection_details_df = spark.createDataFrame(connection_details_pandas_df, schema=connection_details_schema)
    else:
        logger.warning("No connection details data found. Creating empty DataFrame.")
        connection_details_df = spark.createDataFrame([], connection_details_schema)
    
    return datasources_df, connection_details_df
# ==================================


# CELL 11 - Delta Lake Operations Functions
# ==================================
def ensure_delta_table_exists(table_name: str, df_schema):
    """
    Ensure the Delta table exists, creating it if necessary.
    
    Args:
        table_name: Name of the Delta table
        df_schema: Schema of the DataFrame
    """
    try:
        # Check if table exists
        spark.sql(f"DESCRIBE TABLE {table_name}")
        logger.info(f"Delta table '{table_name}' already exists")
    except Exception:
        # Table doesn't exist, create it
        logger.info(f"Creating Delta table '{table_name}'")
        
        # Create an empty DataFrame with the schema
        empty_df = spark.createDataFrame([], df_schema)
        
        # Create the Delta table
        empty_df.write \
            .mode("overwrite") \
            .option("overwriteSchema", "true") \
            .saveAsTable(table_name)
        
        logger.info(f"Delta table '{table_name}' created successfully")


def merge_datasources_to_delta(source_df, table_name: str, merge_keys: List[str]):
    """
    Merge new datasources data into the Delta table using MERGE operation.
    
    This function performs an upsert operation based on the provided merge keys.
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
        merge_keys: List of column names to use for matching records
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    temp_view_name = f"{table_name}_updates"
    source_df.createOrReplaceTempView(temp_view_name)
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Build the merge condition
    merge_condition = " AND ".join([f"target.{key} = source.{key}" for key in merge_keys])
    
    # Get all columns for the UPDATE SET clause (excluding merge keys to avoid redundancy)
    all_columns = source_df.columns
    update_columns = [col for col in all_columns if col not in merge_keys]
    update_set_clause = ", ".join([f"target.{col} = source.{col}" for col in update_columns])
    
    # Perform the merge operation
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING {temp_view_name} AS source
    ON {merge_condition}
    WHEN MATCHED THEN
        UPDATE SET {update_set_clause}
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    if CONFIG['DEBUG_MODE']:
        logger.info(f"Executing merge query: {merge_query}")
    
    spark.sql(merge_query)
    logger.info(f"Merge operation completed successfully for {table_name}")


def optimize_delta_table(table_name: str):
    """
    Optimize the Delta table for better query performance.
    
    Args:
        table_name: Name of the Delta table to optimize
    """
    logger.info(f"Optimizing Delta table '{table_name}'")
    
    try:
        # Update table statistics for better query planning
        spark.sql(f"ANALYZE TABLE {table_name} COMPUTE STATISTICS")
        logger.info(f"Table statistics updated successfully for {table_name}")
        
        # Note: In Microsoft Fabric, Delta table optimization may be handled automatically
        logger.info("Note: Microsoft Fabric may automatically optimize Delta tables")
    except Exception as e:
        logger.warning(f"Table optimization step encountered an issue: {str(e)}")
        logger.info("Continuing with process - optimization is not critical for functionality")
# ==================================


# CELL 12 - Main Execution Function
# ==================================
def main():
    """
    Main execution function that orchestrates the entire process.
    
    This function:
    1. Gets dataset IDs from the existing Fabric tables
    2. Gets the authentication token
    3. Retrieves datasources for all datasets in batches
    4. Creates enhanced PySpark DataFrames
    5. Loads data into Delta Lake tables
    6. Optimizes tables for analytics
    """
    try:
        logger.info("Starting Power BI Datasources to Delta Lake process")
        
        # Step 1: Get dataset IDs from the database
        logger.info("Getting dataset IDs from existing Fabric tables...")
        dataset_ids = get_dataset_ids()
        
        if not dataset_ids:
            logger.warning("No dataset IDs found. Please check the SQL query and data availability.")
            return None, None
        
        # Step 2: Get authentication token
        logger.info("Getting access token...")
        access_token = get_access_token()
        logger.info("Successfully obtained access token")
        
        # Step 3: Process datasets in batches to retrieve datasources
        logger.info(f"Processing {len(dataset_ids)} datasets to retrieve datasources...")
        all_datasources, all_connection_details = process_datasets_in_batches(dataset_ids, access_token)
        
        # Step 4: Create DataFrames
        logger.info("Creating PySpark DataFrames...")
        datasources_df, connection_details_df = create_datasources_dataframes(all_datasources, all_connection_details)
        
        # Show sample data
        if all_datasources:
            logger.info("Sample of datasources data:")
            datasources_df.show(5, truncate=False)
        
        if all_connection_details:
            logger.info("Sample of connection details data:")
            connection_details_df.show(5, truncate=False)
        
        # Step 5: Prepare Delta tables
        main_table_name = CONFIG["DATASOURCES_TABLE_NAME"]
        details_table_name = CONFIG["CONNECTION_DETAILS_TABLE_NAME"]
        
        ensure_delta_table_exists(main_table_name, datasources_df.schema)
        ensure_delta_table_exists(details_table_name, connection_details_df.schema)
        
        # Step 6: Merge data into Delta tables (if we have data)
        if all_datasources:
            # Merge main datasources table (merge on dataset_id and datasource_id)
            merge_datasources_to_delta(datasources_df, main_table_name, ["dataset_id", "datasource_id"])
            optimize_delta_table(main_table_name)
        
        if all_connection_details:
            # Merge connection details table (merge on dataset_id, datasource_id, and connection_property)
            merge_datasources_to_delta(connection_details_df, details_table_name, 
                                     ["dataset_id", "datasource_id", "connection_property"])
            optimize_delta_table(details_table_name)
        
        # Step 7: Display final statistics
        logger.info("Loading completed successfully!")
        
        # Show table information for main datasources table
        logger.info(f"=== {main_table_name} Table Details ===")
        spark.sql(f"DESCRIBE DETAIL {main_table_name}").show(truncate=False)
        
        # Show row count and summary for main table
        main_row_count = spark.table(main_table_name).count()
        logger.info(f"Total rows in {main_table_name}: {main_row_count}")
        
        if main_row_count > 0:
            main_summary = spark.sql(f"""
                SELECT 
                    COUNT(*) as total_datasources,
                    COUNT(DISTINCT dataset_id) as unique_datasets,
                    COUNT(DISTINCT datasource_type) as unique_datasource_types,
                    COUNT(DISTINCT gateway_id) as unique_gateways,
                    MAX(extraction_date) as last_updated
                FROM {main_table_name}
            """)
            
            logger.info(f"=== {main_table_name} Summary Statistics ===")
            main_summary.show(truncate=False)
            
            # Show datasource type distribution
            type_distribution = spark.sql(f"""
                SELECT 
                    datasource_type,
                    COUNT(*) as count
                FROM {main_table_name}
                GROUP BY datasource_type
                ORDER BY count DESC
            """)
            
            logger.info("Datasource type distribution:")
            type_distribution.show(truncate=False)
        
        # Show table information for connection details table
        logger.info(f"=== {details_table_name} Table Details ===")
        spark.sql(f"DESCRIBE DETAIL {details_table_name}").show(truncate=False)
        
        # Show row count and summary for connection details table
        details_row_count = spark.table(details_table_name).count()
        logger.info(f"Total rows in {details_table_name}: {details_row_count}")
        
        if details_row_count > 0:
            details_summary = spark.sql(f"""
                SELECT 
                    COUNT(*) as total_connection_details,
                    COUNT(DISTINCT dataset_id) as unique_datasets,
                    COUNT(DISTINCT datasource_id) as unique_datasources,
                    COUNT(DISTINCT connection_property) as unique_properties,
                    MAX(extraction_date) as last_updated
                FROM {details_table_name}
            """)
            
            logger.info(f"=== {details_table_name} Summary Statistics ===")
            details_summary.show(truncate=False)
            
            # Show most common connection properties
            property_distribution = spark.sql(f"""
                SELECT 
                    connection_property,
                    COUNT(*) as count
                FROM {details_table_name}
                GROUP BY connection_property
                ORDER BY count DESC
                LIMIT 10
            """)
            
            logger.info("Top 10 connection properties:")
            property_distribution.show(truncate=False)
        
        return datasources_df, connection_details_df
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")
        raise
# ==================================


# CELL 13 - Execute Main Function
# ==================================
# Execute the main function
if __name__ == "__main__":
    datasources_df, connection_details_df = main()
# ==================================
# Out:
# StatementMeta(, fad4e198-0861-46c0-97cc-62ecf271dbdc, 4, Finished, Available, Finished)
# 2025-07-17 15:37:09,778 - INFO - Starting execution with batch ID: 4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a
# 2025-07-17 15:37:09,782 - INFO - Starting Power BI Datasources to Delta Lake process
# 2025-07-17 15:37:09,782 - INFO - Getting dataset IDs from existing Fabric tables...
# 2025-07-17 15:37:09,783 - INFO - Executing SQL query to retrieve dataset IDs...
# 2025-07-17 15:37:33,900 - INFO - Retrieved 147 dataset IDs from the database
# 2025-07-17 15:37:33,901 - INFO - Sample dataset IDs: ['d9a141b5-20e2-4c8a-825b-02c0f63bd691', 'c6c5b1e8-4f0c-400e-a396-72048f9b3871', '187c3787-c4a5-47a3-a35b-149b72bbd070', '09eac459-9b71-4e9b-8771-45a142078a0d', '36e4c8d8-d521-4577-93f8-307633711275']
# 2025-07-17 15:37:33,902 - INFO - Getting access token...
# 2025-07-17 15:37:33,921 - INFO - Successfully obtained access token
# 2025-07-17 15:37:33,922 - INFO - Processing 147 datasets to retrieve datasources...
# 2025-07-17 15:37:33,922 - INFO - Processing 147 datasets in batches of 10
# 2025-07-17 15:37:33,924 - INFO - Processing batch 1/15 (datasets 1-10)
# 2025-07-17 15:37:33,924 - INFO - Processing dataset 1/147: d9a141b5-20e2-4c8a-825b-02c0f63bd691
# 2025-07-17 15:37:33,925 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/d9a141b5-20e2-4c8a-825b-02c0f63bd691/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:34,210 - INFO - Response status: 200
# 2025-07-17 15:37:34,211 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:34,215 - INFO - Retrieved 1 datasources for dataset d9a141b5-20e2-4c8a-825b-02c0f63bd691
# 2025-07-17 15:37:34,216 - INFO - Dataset d9a141b5-20e2-4c8a-825b-02c0f63bd691: 1 datasources, 2 connection details
# 2025-07-17 15:37:34,217 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "gatewayId": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5"
# }
# 2025-07-17 15:37:34,317 - INFO - Processing dataset 2/147: c6c5b1e8-4f0c-400e-a396-72048f9b3871
# 2025-07-17 15:37:34,318 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/c6c5b1e8-4f0c-400e-a396-72048f9b3871/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:34,576 - INFO - Response status: 200
# 2025-07-17 15:37:34,576 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:34,580 - INFO - Retrieved 1 datasources for dataset c6c5b1e8-4f0c-400e-a396-72048f9b3871
# 2025-07-17 15:37:34,580 - INFO - Dataset c6c5b1e8-4f0c-400e-a396-72048f9b3871: 1 datasources, 2 connection details
# 2025-07-17 15:37:34,581 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "30d92dc2-4a7b-4719-92a7-97c26a879d8a",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:37:34,682 - INFO - Processing dataset 3/147: 187c3787-c4a5-47a3-a35b-149b72bbd070
# 2025-07-17 15:37:34,684 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/187c3787-c4a5-47a3-a35b-149b72bbd070/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:35,036 - INFO - Response status: 200
# 2025-07-17 15:37:35,037 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:35,040 - INFO - Retrieved 1 datasources for dataset 187c3787-c4a5-47a3-a35b-149b72bbd070
# 2025-07-17 15:37:35,040 - INFO - Dataset 187c3787-c4a5-47a3-a35b-149b72bbd070: 1 datasources, 2 connection details
# 2025-07-17 15:37:35,041 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "13c115c3-01f8-4133-a5fc-fb81163aecd2",
#   "gatewayId": "f29ff6e2-d740-44c1-a6ed-b1763344ea0d"
# }
# 2025-07-17 15:37:35,141 - INFO - Processing dataset 4/147: 09eac459-9b71-4e9b-8771-45a142078a0d
# 2025-07-17 15:37:35,142 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/09eac459-9b71-4e9b-8771-45a142078a0d/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:35,402 - INFO - Response status: 200
# 2025-07-17 15:37:35,403 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:35,405 - INFO - Retrieved 1 datasources for dataset 09eac459-9b71-4e9b-8771-45a142078a0d
# 2025-07-17 15:37:35,405 - INFO - Dataset 09eac459-9b71-4e9b-8771-45a142078a0d: 1 datasources, 2 connection details
# 2025-07-17 15:37:35,406 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "gatewayId": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5"
# }
# 2025-07-17 15:37:35,506 - INFO - Processing dataset 5/147: 36e4c8d8-d521-4577-93f8-307633711275
# 2025-07-17 15:37:35,507 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/36e4c8d8-d521-4577-93f8-307633711275/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:35,809 - INFO - Response status: 200
# 2025-07-17 15:37:35,810 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:35,813 - INFO - Retrieved 1 datasources for dataset 36e4c8d8-d521-4577-93f8-307633711275
# 2025-07-17 15:37:35,813 - INFO - Dataset 36e4c8d8-d521-4577-93f8-307633711275: 1 datasources, 2 connection details
# 2025-07-17 15:37:35,814 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "3502167a-1a61-41ff-ad9b-c240d767e570",
#   "gatewayId": "51bb2458-5a48-49cc-9a6e-ab67c9ab9e37"
# }
# 2025-07-17 15:37:35,914 - INFO - Processing dataset 6/147: 92e5929a-8148-4279-b43e-fe9eea21f273
# 2025-07-17 15:37:35,915 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/92e5929a-8148-4279-b43e-fe9eea21f273/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:36,494 - INFO - Response status: 200
# 2025-07-17 15:37:36,495 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:36,499 - INFO - Retrieved 1 datasources for dataset 92e5929a-8148-4279-b43e-fe9eea21f273
# 2025-07-17 15:37:36,499 - INFO - Dataset 92e5929a-8148-4279-b43e-fe9eea21f273: 1 datasources, 2 connection details
# 2025-07-17 15:37:36,499 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "https://tygraphkustodbus.eastus.kusto.windows.net",
#     "kind": "AzureDataExplorer"
#   },
#   "datasourceId": "dd453547-6c50-4313-910b-5793061b9bbd",
#   "gatewayId": "8d70492b-f7bb-43d5-b211-7ae1dbdf3c11"
# }
# 2025-07-17 15:37:36,600 - INFO - Processing dataset 7/147: a4e211e0-f3f5-472f-8edb-de511fc76e3f
# 2025-07-17 15:37:36,601 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/a4e211e0-f3f5-472f-8edb-de511fc76e3f/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:36,871 - INFO - Response status: 200
# 2025-07-17 15:37:36,872 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:36,874 - INFO - Retrieved 1 datasources for dataset a4e211e0-f3f5-472f-8edb-de511fc76e3f
# 2025-07-17 15:37:36,874 - INFO - Dataset a4e211e0-f3f5-472f-8edb-de511fc76e3f: 1 datasources, 2 connection details
# 2025-07-17 15:37:36,875 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "13c115c3-01f8-4133-a5fc-fb81163aecd2",
#   "gatewayId": "f29ff6e2-d740-44c1-a6ed-b1763344ea0d"
# }
# 2025-07-17 15:37:36,975 - INFO - Processing dataset 8/147: da7a41d4-00a5-4c19-bb16-b107e56c9db4
# 2025-07-17 15:37:36,976 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/da7a41d4-00a5-4c19-bb16-b107e56c9db4/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:37,588 - INFO - Response status: 200
# 2025-07-17 15:37:37,589 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:37,591 - INFO - Retrieved 1 datasources for dataset da7a41d4-00a5-4c19-bb16-b107e56c9db4
# 2025-07-17 15:37:37,592 - INFO - Dataset da7a41d4-00a5-4c19-bb16-b107e56c9db4: 1 datasources, 2 connection details
# 2025-07-17 15:37:37,592 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "gatewayId": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5"
# }
# 2025-07-17 15:37:37,693 - INFO - Processing dataset 9/147: 056d1649-e0e9-4386-b882-37188ed76b25
# 2025-07-17 15:37:37,693 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/056d1649-e0e9-4386-b882-37188ed76b25/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:37,976 - INFO - Response status: 200
# 2025-07-17 15:37:37,976 - INFO - Response contains 3 datasources
# 2025-07-17 15:37:37,979 - INFO - Retrieved 3 datasources for dataset 056d1649-e0e9-4386-b882-37188ed76b25
# 2025-07-17 15:37:37,980 - INFO - Dataset 056d1649-e0e9-4386-b882-37188ed76b25: 3 datasources, 5 connection details
# 2025-07-17 15:37:37,980 - INFO - Sample datasource: {
#   "datasourceType": "AnalysisServices",
#   "connectionDetails": {
#     "server": "powerbi://api.powerbi.com/v1.0/myorg/cba%20analytics%20models",
#     "database": "mda fte"
#   },
#   "datasourceId": "2dfba737-865c-404b-9ef7-a71a38f89d54",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:37:38,081 - INFO - Processing dataset 10/147: 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23
# 2025-07-17 15:37:38,082 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/0c811ad1-3d5c-46fc-84a7-5d6cbe949e23/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:38,360 - INFO - Response status: 200
# 2025-07-17 15:37:38,361 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:38,364 - INFO - Retrieved 1 datasources for dataset 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23
# 2025-07-17 15:37:38,365 - INFO - Dataset 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23: 1 datasources, 2 connection details
# 2025-07-17 15:37:38,365 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerBI",
#     "kind": "PowerBI"
#   },
#   "datasourceId": "6a4737f6-9034-41ac-92a5-31166be56b4e",
#   "gatewayId": "fde2b36d-72cb-446d-a62d-617b3df2299f"
# }
# 2025-07-17 15:37:38,466 - INFO - Completed batch 1. Waiting 2 seconds before next batch...
# 2025-07-17 15:37:40,467 - INFO - Processing batch 2/15 (datasets 11-20)
# 2025-07-17 15:37:40,467 - INFO - Processing dataset 11/147: 424836a1-bf59-497c-8ac9-71fd3f92a1ee
# 2025-07-17 15:37:40,468 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/424836a1-bf59-497c-8ac9-71fd3f92a1ee/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:41,056 - INFO - Response status: 200
# 2025-07-17 15:37:41,057 - INFO - Response contains 2 datasources
# 2025-07-17 15:37:41,060 - INFO - Retrieved 2 datasources for dataset 424836a1-bf59-497c-8ac9-71fd3f92a1ee
# 2025-07-17 15:37:41,061 - INFO - Dataset 424836a1-bf59-497c-8ac9-71fd3f92a1ee: 2 datasources, 4 connection details
# 2025-07-17 15:37:41,061 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerBI",
#     "kind": "PowerBI"
#   },
#   "datasourceId": "2a71bed5-d154-4afe-a895-ca31ce0677f3",
#   "gatewayId": "ab385dd9-c982-4fbb-9e8f-1ea09375e727"
# }
# 2025-07-17 15:37:41,162 - INFO - Processing dataset 12/147: f8b9a61f-406c-4d41-9922-d86ba9cd440b
# 2025-07-17 15:37:41,162 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/f8b9a61f-406c-4d41-9922-d86ba9cd440b/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:41,624 - INFO - Response status: 200
# 2025-07-17 15:37:41,624 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:41,627 - INFO - Retrieved 1 datasources for dataset f8b9a61f-406c-4d41-9922-d86ba9cd440b
# 2025-07-17 15:37:41,627 - INFO - Dataset f8b9a61f-406c-4d41-9922-d86ba9cd440b: 1 datasources, 2 connection details
# 2025-07-17 15:37:41,628 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:41,728 - INFO - Processing dataset 13/147: 573fe815-1ca9-4f23-a22c-5ff74aa2a23a
# 2025-07-17 15:37:41,728 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/573fe815-1ca9-4f23-a22c-5ff74aa2a23a/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:41,998 - INFO - Response status: 200
# 2025-07-17 15:37:41,999 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:42,001 - INFO - Retrieved 1 datasources for dataset 573fe815-1ca9-4f23-a22c-5ff74aa2a23a
# 2025-07-17 15:37:42,001 - INFO - Dataset 573fe815-1ca9-4f23-a22c-5ff74aa2a23a: 1 datasources, 2 connection details
# 2025-07-17 15:37:42,001 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:42,102 - INFO - Processing dataset 14/147: b1944f6a-1dd1-4cc7-ba41-3175d730d10d
# 2025-07-17 15:37:42,103 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/b1944f6a-1dd1-4cc7-ba41-3175d730d10d/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:42,302 - INFO - Response status: 200
# 2025-07-17 15:37:42,302 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:42,304 - INFO - Retrieved 1 datasources for dataset b1944f6a-1dd1-4cc7-ba41-3175d730d10d
# 2025-07-17 15:37:42,305 - INFO - Dataset b1944f6a-1dd1-4cc7-ba41-3175d730d10d: 1 datasources, 2 connection details
# 2025-07-17 15:37:42,305 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:42,405 - INFO - Processing dataset 15/147: 590ce045-9441-438f-9b8b-761b7529ee36
# 2025-07-17 15:37:42,405 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/590ce045-9441-438f-9b8b-761b7529ee36/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:42,566 - INFO - Response status: 200
# 2025-07-17 15:37:42,567 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:42,569 - INFO - Retrieved 1 datasources for dataset 590ce045-9441-438f-9b8b-761b7529ee36
# 2025-07-17 15:37:42,570 - INFO - Dataset 590ce045-9441-438f-9b8b-761b7529ee36: 1 datasources, 2 connection details
# 2025-07-17 15:37:42,570 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:42,671 - INFO - Processing dataset 16/147: b56d3b78-e2f0-4f1d-b010-737801884169
# 2025-07-17 15:37:42,672 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/b56d3b78-e2f0-4f1d-b010-737801884169/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:42,845 - INFO - Response status: 200
# 2025-07-17 15:37:42,846 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:42,848 - INFO - Retrieved 1 datasources for dataset b56d3b78-e2f0-4f1d-b010-737801884169
# 2025-07-17 15:37:42,849 - INFO - Dataset b56d3b78-e2f0-4f1d-b010-737801884169: 1 datasources, 2 connection details
# 2025-07-17 15:37:42,849 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:42,949 - INFO - Processing dataset 17/147: de487a1a-a878-4efb-b2fe-df46e68bf1ec
# 2025-07-17 15:37:42,950 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/de487a1a-a878-4efb-b2fe-df46e68bf1ec/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:43,220 - INFO - Response status: 200
# 2025-07-17 15:37:43,220 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:43,224 - INFO - Retrieved 1 datasources for dataset de487a1a-a878-4efb-b2fe-df46e68bf1ec
# 2025-07-17 15:37:43,224 - INFO - Dataset de487a1a-a878-4efb-b2fe-df46e68bf1ec: 1 datasources, 2 connection details
# 2025-07-17 15:37:43,225 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:43,325 - INFO - Processing dataset 18/147: 962e45cd-dd27-4d58-ae93-894e53850534
# 2025-07-17 15:37:43,326 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/962e45cd-dd27-4d58-ae93-894e53850534/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:43,517 - INFO - Response status: 200
# 2025-07-17 15:37:43,517 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:43,520 - INFO - Retrieved 1 datasources for dataset 962e45cd-dd27-4d58-ae93-894e53850534
# 2025-07-17 15:37:43,521 - INFO - Dataset 962e45cd-dd27-4d58-ae93-894e53850534: 1 datasources, 2 connection details
# 2025-07-17 15:37:43,521 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:43,622 - INFO - Processing dataset 19/147: 42018153-9894-4995-be43-30281fa8675b
# 2025-07-17 15:37:43,623 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/42018153-9894-4995-be43-30281fa8675b/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:43,811 - INFO - Response status: 200
# 2025-07-17 15:37:43,811 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:43,813 - INFO - Retrieved 1 datasources for dataset 42018153-9894-4995-be43-30281fa8675b
# 2025-07-17 15:37:43,814 - INFO - Dataset 42018153-9894-4995-be43-30281fa8675b: 1 datasources, 2 connection details
# 2025-07-17 15:37:43,814 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:43,915 - INFO - Processing dataset 20/147: 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79
# 2025-07-17 15:37:43,915 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/2546fffd-a5a2-4bfe-86fd-dbc2bca36a79/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:44,114 - INFO - Response status: 200
# 2025-07-17 15:37:44,115 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:44,117 - INFO - Retrieved 1 datasources for dataset 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79
# 2025-07-17 15:37:44,118 - INFO - Dataset 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79: 1 datasources, 2 connection details
# 2025-07-17 15:37:44,118 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:44,219 - INFO - Completed batch 2. Waiting 2 seconds before next batch...
# 2025-07-17 15:37:46,219 - INFO - Processing batch 3/15 (datasets 21-30)
# 2025-07-17 15:37:46,220 - INFO - Processing dataset 21/147: 36d80fa5-819d-40e4-bb2f-d146976e5ba9
# 2025-07-17 15:37:46,220 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/36d80fa5-819d-40e4-bb2f-d146976e5ba9/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:46,519 - INFO - Response status: 200
# 2025-07-17 15:37:46,519 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:46,522 - INFO - Retrieved 1 datasources for dataset 36d80fa5-819d-40e4-bb2f-d146976e5ba9
# 2025-07-17 15:37:46,522 - INFO - Dataset 36d80fa5-819d-40e4-bb2f-d146976e5ba9: 1 datasources, 2 connection details
# 2025-07-17 15:37:46,523 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:46,623 - INFO - Processing dataset 22/147: 0d46bdeb-cef4-42f9-8d60-080f654f525f
# 2025-07-17 15:37:46,624 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/0d46bdeb-cef4-42f9-8d60-080f654f525f/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:46,871 - INFO - Response status: 200
# 2025-07-17 15:37:46,872 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:46,875 - INFO - Retrieved 1 datasources for dataset 0d46bdeb-cef4-42f9-8d60-080f654f525f
# 2025-07-17 15:37:46,876 - INFO - Dataset 0d46bdeb-cef4-42f9-8d60-080f654f525f: 1 datasources, 1 connection details
# 2025-07-17 15:37:46,876 - INFO - Sample datasource: {
#   "datasourceType": "SharePointList",
#   "connectionDetails": {
#     "url": "https://mdandersonorg.sharepoint.com/teams/trbautomatedtoolpilot/"
#   },
#   "datasourceId": "2248100d-cffc-4bb0-b3de-5a126f4d0435",
#   "gatewayId": "b37d63a2-2f65-4488-bde6-52896ac0b01c"
# }
# 2025-07-17 15:37:46,977 - INFO - Processing dataset 23/147: 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f
# 2025-07-17 15:37:46,978 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/1edc8fc0-5e64-4fbc-ab20-6a04a28e087f/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:47,281 - INFO - Response status: 200
# 2025-07-17 15:37:47,282 - INFO - Response contains 12 datasources
# 2025-07-17 15:37:47,285 - INFO - Retrieved 12 datasources for dataset 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f
# 2025-07-17 15:37:47,285 - INFO - Dataset 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f: 12 datasources, 12 connection details
# 2025-07-17 15:37:47,286 - INFO - Sample datasource: {
#   "datasourceType": "SharePointList",
#   "connectionDetails": {
#     "url": "https://mdandersonorg.sharepoint.com/teams/trbpathlab/"
#   },
#   "datasourceId": "64967d4a-941d-44b1-911d-8410724681c8",
#   "gatewayId": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a"
# }
# 2025-07-17 15:37:47,386 - INFO - Processing dataset 24/147: b504664b-07a6-4d5f-9af0-f235fc6d7f0c
# 2025-07-17 15:37:47,386 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/b504664b-07a6-4d5f-9af0-f235fc6d7f0c/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:47,544 - INFO - Response status: 200
# 2025-07-17 15:37:47,545 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:47,546 - INFO - Retrieved 1 datasources for dataset b504664b-07a6-4d5f-9af0-f235fc6d7f0c
# 2025-07-17 15:37:47,547 - INFO - Dataset b504664b-07a6-4d5f-9af0-f235fc6d7f0c: 1 datasources, 2 connection details
# 2025-07-17 15:37:47,547 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "org65c64084.crm.dynamics.com",
#     "kind": "CommonDataService"
#   },
#   "datasourceId": "e38e8368-7ec8-4b1c-9fab-843ffe12dd84",
#   "gatewayId": "67ae466d-68ca-4710-8430-bf7567fd1f9b"
# }
# 2025-07-17 15:37:47,648 - INFO - Processing dataset 25/147: c1ed3070-34ea-4f0d-97f6-1d8220b03675
# 2025-07-17 15:37:47,649 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/c1ed3070-34ea-4f0d-97f6-1d8220b03675/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:47,937 - INFO - Response status: 200
# 2025-07-17 15:37:47,937 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:47,941 - INFO - Retrieved 1 datasources for dataset c1ed3070-34ea-4f0d-97f6-1d8220b03675
# 2025-07-17 15:37:47,941 - INFO - Dataset c1ed3070-34ea-4f0d-97f6-1d8220b03675: 1 datasources, 2 connection details
# 2025-07-17 15:37:47,942 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:48,042 - INFO - Processing dataset 26/147: 537257d3-9f04-4a6a-98d5-12dded57ce41
# 2025-07-17 15:37:48,043 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/537257d3-9f04-4a6a-98d5-12dded57ce41/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:49,268 - INFO - Response status: 200
# 2025-07-17 15:37:49,269 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:49,272 - INFO - Retrieved 1 datasources for dataset 537257d3-9f04-4a6a-98d5-12dded57ce41
# 2025-07-17 15:37:49,273 - INFO - Dataset 537257d3-9f04-4a6a-98d5-12dded57ce41: 1 datasources, 2 connection details
# 2025-07-17 15:37:49,273 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:49,373 - INFO - Processing dataset 27/147: 8f043eb2-8622-493d-91f6-ddd1c07e3dc2
# 2025-07-17 15:37:49,374 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/8f043eb2-8622-493d-91f6-ddd1c07e3dc2/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:50,202 - INFO - Response status: 200
# 2025-07-17 15:37:50,202 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:50,206 - INFO - Retrieved 1 datasources for dataset 8f043eb2-8622-493d-91f6-ddd1c07e3dc2
# 2025-07-17 15:37:50,207 - INFO - Dataset 8f043eb2-8622-493d-91f6-ddd1c07e3dc2: 1 datasources, 2 connection details
# 2025-07-17 15:37:50,207 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:50,308 - INFO - Processing dataset 28/147: 77791f59-a4db-49d4-b6e2-d17f67f0c568
# 2025-07-17 15:37:50,308 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/77791f59-a4db-49d4-b6e2-d17f67f0c568/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:50,473 - INFO - Response status: 200
# 2025-07-17 15:37:50,474 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:50,476 - INFO - Retrieved 1 datasources for dataset 77791f59-a4db-49d4-b6e2-d17f67f0c568
# 2025-07-17 15:37:50,476 - INFO - Dataset 77791f59-a4db-49d4-b6e2-d17f67f0c568: 1 datasources, 2 connection details
# 2025-07-17 15:37:50,477 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:50,577 - INFO - Processing dataset 29/147: fb89ec88-4b55-44ab-933a-4962ac10946e
# 2025-07-17 15:37:50,578 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/fb89ec88-4b55-44ab-933a-4962ac10946e/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:50,761 - INFO - Response status: 200
# 2025-07-17 15:37:50,762 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:50,765 - INFO - Retrieved 1 datasources for dataset fb89ec88-4b55-44ab-933a-4962ac10946e
# 2025-07-17 15:37:50,765 - INFO - Dataset fb89ec88-4b55-44ab-933a-4962ac10946e: 1 datasources, 2 connection details
# 2025-07-17 15:37:50,766 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:50,866 - INFO - Processing dataset 30/147: 65ff101e-fe36-480a-a7e0-c2866d7aa4a2
# 2025-07-17 15:37:50,867 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/65ff101e-fe36-480a-a7e0-c2866d7aa4a2/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:51,022 - INFO - Response status: 200
# 2025-07-17 15:37:51,023 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:51,025 - INFO - Retrieved 1 datasources for dataset 65ff101e-fe36-480a-a7e0-c2866d7aa4a2
# 2025-07-17 15:37:51,026 - INFO - Dataset 65ff101e-fe36-480a-a7e0-c2866d7aa4a2: 1 datasources, 2 connection details
# 2025-07-17 15:37:51,027 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:51,127 - INFO - Completed batch 3. Waiting 2 seconds before next batch...
# 2025-07-17 15:37:53,128 - INFO - Processing batch 4/15 (datasets 31-40)
# 2025-07-17 15:37:53,129 - INFO - Processing dataset 31/147: 5585c24a-d2fb-4a19-afaf-b85e55dfe92f
# 2025-07-17 15:37:53,129 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/5585c24a-d2fb-4a19-afaf-b85e55dfe92f/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:53,428 - INFO - Response status: 200
# 2025-07-17 15:37:53,429 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:53,432 - INFO - Retrieved 1 datasources for dataset 5585c24a-d2fb-4a19-afaf-b85e55dfe92f
# 2025-07-17 15:37:53,432 - INFO - Dataset 5585c24a-d2fb-4a19-afaf-b85e55dfe92f: 1 datasources, 2 connection details
# 2025-07-17 15:37:53,433 - INFO - Sample datasource: {
#   "datasourceType": "Sql",
#   "connectionDetails": {
#     "server": "qcpwlsql04.mdanderson.edu",
#     "database": "dmi_reportingservices"
#   },
#   "datasourceId": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "gatewayId": "96262afb-757f-4d58-a258-b8faddca905f"
# }
# 2025-07-17 15:37:53,533 - INFO - Processing dataset 32/147: f7d8423e-36ce-419d-971d-6d56b683a190
# 2025-07-17 15:37:53,534 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/f7d8423e-36ce-419d-971d-6d56b683a190/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:53,784 - INFO - Response status: 200
# 2025-07-17 15:37:53,784 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:53,787 - INFO - Retrieved 1 datasources for dataset f7d8423e-36ce-419d-971d-6d56b683a190
# 2025-07-17 15:37:53,788 - INFO - Dataset f7d8423e-36ce-419d-971d-6d56b683a190: 1 datasources, 1 connection details
# 2025-07-17 15:37:53,788 - INFO - Sample datasource: {
#   "datasourceType": "SharePointList",
#   "connectionDetails": {
#     "url": "https://mdandersonorg.sharepoint.com/teams/cpdpc/"
#   },
#   "datasourceId": "cfcda6ca-6bbc-4a9a-bab4-5e827b92aab3",
#   "gatewayId": "67ae466d-68ca-4710-8430-bf7567fd1f9b"
# }
# 2025-07-17 15:37:53,888 - INFO - Processing dataset 33/147: f3aa5d8f-941a-4716-8bdb-59ad8c984a15
# 2025-07-17 15:37:53,889 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/f3aa5d8f-941a-4716-8bdb-59ad8c984a15/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:54,058 - INFO - Response status: 200
# 2025-07-17 15:37:54,059 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:54,062 - INFO - Retrieved 1 datasources for dataset f3aa5d8f-941a-4716-8bdb-59ad8c984a15
# 2025-07-17 15:37:54,063 - INFO - Dataset f3aa5d8f-941a-4716-8bdb-59ad8c984a15: 1 datasources, 1 connection details
# 2025-07-17 15:37:54,063 - INFO - Sample datasource: {
#   "datasourceType": "SharePointList",
#   "connectionDetails": {
#     "url": "https://mdandersonorg.sharepoint.com/teams/set/"
#   },
#   "datasourceId": "c799d109-77bc-4c09-a6fd-723fe21448e8",
#   "gatewayId": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a"
# }
# 2025-07-17 15:37:54,163 - INFO - Processing dataset 34/147: 6fe68660-b156-4070-998e-e6bbbec86732
# 2025-07-17 15:37:54,164 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/6fe68660-b156-4070-998e-e6bbbec86732/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:54,346 - INFO - Response status: 200
# 2025-07-17 15:37:54,346 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:54,349 - INFO - Retrieved 1 datasources for dataset 6fe68660-b156-4070-998e-e6bbbec86732
# 2025-07-17 15:37:54,350 - INFO - Dataset 6fe68660-b156-4070-998e-e6bbbec86732: 1 datasources, 1 connection details
# 2025-07-17 15:37:54,351 - INFO - Sample datasource: {
#   "datasourceType": "SharePointList",
#   "connectionDetails": {
#     "url": "https://mdandersonorg.sharepoint.com/teams/trbautomatedtoolpilot/"
#   },
#   "datasourceId": "195612a5-2b61-494d-92be-62159e2ba832",
#   "gatewayId": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a"
# }
# 2025-07-17 15:37:54,451 - INFO - Processing dataset 35/147: 01ff15a8-6f79-4a8c-bf5b-5bcd82023883
# 2025-07-17 15:37:54,452 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/01ff15a8-6f79-4a8c-bf5b-5bcd82023883/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:54,687 - INFO - Response status: 200
# 2025-07-17 15:37:54,688 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:54,690 - INFO - Retrieved 1 datasources for dataset 01ff15a8-6f79-4a8c-bf5b-5bcd82023883
# 2025-07-17 15:37:54,691 - INFO - Dataset 01ff15a8-6f79-4a8c-bf5b-5bcd82023883: 1 datasources, 2 connection details
# 2025-07-17 15:37:54,691 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerPlatformDataflows",
#     "kind": "PowerPlatformDataflows"
#   },
#   "datasourceId": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "gatewayId": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5"
# }
# 2025-07-17 15:37:54,792 - INFO - Processing dataset 36/147: 67f9b78b-5659-4888-a1a7-67709d1f3d07
# 2025-07-17 15:37:54,792 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/67f9b78b-5659-4888-a1a7-67709d1f3d07/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:54,998 - INFO - Response status: 200
# 2025-07-17 15:37:54,998 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:55,000 - INFO - Retrieved 1 datasources for dataset 67f9b78b-5659-4888-a1a7-67709d1f3d07
# 2025-07-17 15:37:55,001 - INFO - Dataset 67f9b78b-5659-4888-a1a7-67709d1f3d07: 1 datasources, 2 connection details
# 2025-07-17 15:37:55,001 - INFO - Sample datasource: {
#   "datasourceType": "AnalysisServices",
#   "connectionDetails": {
#     "server": "powerbi://api.powerbi.com/v1.0/myorg/inpatient [prod]",
#     "database": "care team transformation dashboard"
#   },
#   "datasourceId": "5596b826-5bd5-482b-b2e5-87a77bfc7941",
#   "gatewayId": "ab385dd9-c982-4fbb-9e8f-1ea09375e727"
# }
# 2025-07-17 15:37:55,102 - INFO - Processing dataset 37/147: 78d2f263-333a-4d68-8fd8-8c5c58937844
# 2025-07-17 15:37:55,102 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/78d2f263-333a-4d68-8fd8-8c5c58937844/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:55,308 - INFO - Response status: 200
# 2025-07-17 15:37:55,309 - INFO - Response contains 1 datasources
# 2025-07-17 15:37:55,311 - INFO - Retrieved 1 datasources for dataset 78d2f263-333a-4d68-8fd8-8c5c58937844
# 2025-07-17 15:37:55,311 - INFO - Dataset 78d2f263-333a-4d68-8fd8-8c5c58937844: 1 datasources, 1 connection details
# 2025-07-17 15:37:55,312 - INFO - Sample datasource: {
#   "datasourceType": "Oracle",
#   "connectionDetails": {
#     "server": "epmp"
#   },
#   "datasourceId": "682cbdf5-dd6b-4a13-86fc-ec2047ea3288",
#   "gatewayId": "47d3ea9b-fb98-4e41-8516-2aa7c02b7eca"
# }
# 2025-07-17 15:37:55,412 - INFO - Processing dataset 38/147: c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-17 15:37:55,413 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/c053b33b-5241-42c2-8785-65a1b337e7fe/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:55,558 - INFO - Response status: 200
# 2025-07-17 15:37:55,559 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:55,561 - INFO - No datasources found for dataset c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-17 15:37:55,662 - INFO - Processing dataset 39/147: 3842cc82-7522-4d6d-8bca-627a4a0dc99b
# 2025-07-17 15:37:55,663 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/3842cc82-7522-4d6d-8bca-627a4a0dc99b/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:55,814 - INFO - Response status: 200
# 2025-07-17 15:37:55,814 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:55,816 - INFO - No datasources found for dataset 3842cc82-7522-4d6d-8bca-627a4a0dc99b
# 2025-07-17 15:37:55,917 - INFO - Processing dataset 40/147: 8d9beb02-7a15-400a-912f-558f0c07600e
# 2025-07-17 15:37:55,917 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/8d9beb02-7a15-400a-912f-558f0c07600e/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:56,055 - INFO - Response status: 200
# 2025-07-17 15:37:56,056 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:56,058 - INFO - No datasources found for dataset 8d9beb02-7a15-400a-912f-558f0c07600e
# 2025-07-17 15:37:56,159 - INFO - Completed batch 4. Waiting 2 seconds before next batch...
# 2025-07-17 15:37:58,160 - INFO - Processing batch 5/15 (datasets 41-50)
# 2025-07-17 15:37:58,161 - INFO - Processing dataset 41/147: 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-17 15:37:58,161 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/48d932f8-8b64-4b34-a67c-e08de77d9c3b/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:58,432 - INFO - Response status: 200
# 2025-07-17 15:37:58,433 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:58,436 - INFO - No datasources found for dataset 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-17 15:37:58,536 - INFO - Processing dataset 42/147: 71b51c6b-af32-47d3-8f38-ce9f7cedffc9
# 2025-07-17 15:37:58,537 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/71b51c6b-af32-47d3-8f38-ce9f7cedffc9/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:58,696 - INFO - Response status: 200
# 2025-07-17 15:37:58,696 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:58,698 - INFO - No datasources found for dataset 71b51c6b-af32-47d3-8f38-ce9f7cedffc9
# 2025-07-17 15:37:58,799 - INFO - Processing dataset 43/147: edc7ea46-a68b-47ee-835e-1554aa832d32
# 2025-07-17 15:37:58,799 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/edc7ea46-a68b-47ee-835e-1554aa832d32/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:58,975 - INFO - Response status: 200
# 2025-07-17 15:37:58,975 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:58,978 - INFO - No datasources found for dataset edc7ea46-a68b-47ee-835e-1554aa832d32
# 2025-07-17 15:37:59,078 - INFO - Processing dataset 44/147: 793c10f9-5f42-4cb4-8f24-4d5d3dc141fc
# 2025-07-17 15:37:59,079 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/793c10f9-5f42-4cb4-8f24-4d5d3dc141fc/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:59,217 - INFO - Response status: 200
# 2025-07-17 15:37:59,217 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:59,220 - INFO - No datasources found for dataset 793c10f9-5f42-4cb4-8f24-4d5d3dc141fc
# 2025-07-17 15:37:59,320 - INFO - Processing dataset 45/147: 9b8714f3-cc90-4d8e-84b4-f8cbbd681e36
# 2025-07-17 15:37:59,321 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/9b8714f3-cc90-4d8e-84b4-f8cbbd681e36/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:59,467 - INFO - Response status: 200
# 2025-07-17 15:37:59,468 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:59,470 - INFO - No datasources found for dataset 9b8714f3-cc90-4d8e-84b4-f8cbbd681e36
# 2025-07-17 15:37:59,570 - INFO - Processing dataset 46/147: d79bc5c0-8d66-4834-814c-da67438bc135
# 2025-07-17 15:37:59,570 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/d79bc5c0-8d66-4834-814c-da67438bc135/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:59,717 - INFO - Response status: 200
# 2025-07-17 15:37:59,718 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:59,721 - INFO - No datasources found for dataset d79bc5c0-8d66-4834-814c-da67438bc135
# 2025-07-17 15:37:59,821 - INFO - Processing dataset 47/147: 3e6bd48b-9e3b-4811-90af-b49ee59a30e6
# 2025-07-17 15:37:59,822 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/3e6bd48b-9e3b-4811-90af-b49ee59a30e6/datasources with params: None (Attempt 1)
# 2025-07-17 15:37:59,989 - INFO - Response status: 200
# 2025-07-17 15:37:59,989 - INFO - Response contains 0 datasources
# 2025-07-17 15:37:59,993 - INFO - No datasources found for dataset 3e6bd48b-9e3b-4811-90af-b49ee59a30e6
# 2025-07-17 15:38:00,094 - INFO - Processing dataset 48/147: ae574855-449a-4fa3-9dbe-94c73e9a674c
# 2025-07-17 15:38:00,094 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/ae574855-449a-4fa3-9dbe-94c73e9a674c/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:00,367 - INFO - Response status: 200
# 2025-07-17 15:38:00,367 - INFO - Response contains 0 datasources
# 2025-07-17 15:38:00,370 - INFO - No datasources found for dataset ae574855-449a-4fa3-9dbe-94c73e9a674c
# 2025-07-17 15:38:00,471 - INFO - Processing dataset 49/147: 22c11e64-7e29-4376-bb3c-5aa9234a1463
# 2025-07-17 15:38:00,471 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/22c11e64-7e29-4376-bb3c-5aa9234a1463/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:00,647 - INFO - Response status: 200
# 2025-07-17 15:38:00,648 - INFO - Response contains 0 datasources
# 2025-07-17 15:38:00,652 - INFO - No datasources found for dataset 22c11e64-7e29-4376-bb3c-5aa9234a1463
# 2025-07-17 15:38:00,752 - INFO - Processing dataset 50/147: e1a39240-93f0-43df-bb69-8595fbd76954
# 2025-07-17 15:38:00,753 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:00,957 - INFO - Response status: 404
# 2025-07-17 15:38:00,958 - ERROR - API error: Status 404, Response: {"error":{"code":"ItemNotFound","message":"Dataset e1a39240-93f0-43df-bb69-8595fbd76954 is not found."}}
# 2025-07-17 15:38:00,958 - ERROR - Request URL: https://api.powerbi.com/v1.0/myorg/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources
# 2025-07-17 15:38:00,959 - ERROR - Request headers: {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Bearer [REDACTED]', 'Content-Type': 'application/json'}
# 2025-07-17 15:38:00,959 - WARNING - API call failed (Attempt 1): 404 Client Error: Not Found for url: https://api.powerbi.com/v1.0/myorg/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources
# 2025-07-17 15:38:00,959 - ERROR - All retry attempts failed for endpoint: /datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources
# 2025-07-17 15:38:00,960 - ERROR - Final error: 404 Client Error: Not Found for url: https://api.powerbi.com/v1.0/myorg/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources
# 2025-07-17 15:38:00,960 - ERROR - Failed to retrieve datasources for dataset e1a39240-93f0-43df-bb69-8595fbd76954: 404 Client Error: Not Found for url: https://api.powerbi.com/v1.0/myorg/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources
# 2025-07-17 15:38:01,063 - INFO - Completed batch 5. Waiting 2 seconds before next batch...
# 2025-07-17 15:38:03,064 - INFO - Processing batch 6/15 (datasets 51-60)
# 2025-07-17 15:38:03,064 - INFO - Processing dataset 51/147: fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-17 15:38:03,065 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/fe1918d6-0a63-4b30-9208-afc8e5c1d5df/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:03,604 - INFO - Response status: 200
# 2025-07-17 15:38:03,605 - INFO - Response contains 15 datasources
# 2025-07-17 15:38:03,607 - INFO - Retrieved 15 datasources for dataset fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-17 15:38:03,608 - INFO - Dataset fe1918d6-0a63-4b30-9208-afc8e5c1d5df: 15 datasources, 15 connection details
# 2025-07-17 15:38:03,608 - INFO - Sample datasource: {
#   "datasourceType": "File",
#   "connectionDetails": {
#     "path": "\\\\mymdafiles\\research\\medinfo\\common\\dss\\patient safety\\data files_extracts\\archived si extracts\\si_extract.csv"
#   },
#   "datasourceId": "fe1af4fe-6046-46f7-be68-71961d8aff0b",
#   "gatewayId": "a9ef46b6-b653-474e-ad63-a58c7287c40c"
# }
# 2025-07-17 15:38:03,709 - INFO - Processing dataset 52/147: b983dd24-25e4-41e6-9949-016001c6ca09
# 2025-07-17 15:38:03,709 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/b983dd24-25e4-41e6-9949-016001c6ca09/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:04,019 - INFO - Response status: 200
# 2025-07-17 15:38:04,019 - INFO - Response contains 9 datasources
# 2025-07-17 15:38:04,022 - INFO - Retrieved 9 datasources for dataset b983dd24-25e4-41e6-9949-016001c6ca09
# 2025-07-17 15:38:04,022 - INFO - Dataset b983dd24-25e4-41e6-9949-016001c6ca09: 9 datasources, 11 connection details
# 2025-07-17 15:38:04,023 - INFO - Sample datasource: {
#   "datasourceType": "File",
#   "connectionDetails": {
#     "path": "c:\\users\\ttson\\desktop\\dashboard tasks\\dei dashboard\\press ganey\\2020_09-2021_09_cgcahps_same_day_answer_phone_after_hrs_tson.xlsx"
#   },
#   "datasourceId": "4bf3ff49-c023-4778-acce-9bc0ddbe666d",
#   "gatewayId": "fdc3c190-f647-4b65-9487-5af5a1646da8"
# }
# 2025-07-17 15:38:04,123 - INFO - Processing dataset 53/147: 8c982903-1747-4644-a6ca-5377b353e7dd
# 2025-07-17 15:38:04,124 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/8c982903-1747-4644-a6ca-5377b353e7dd/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:04,397 - INFO - Response status: 200
# 2025-07-17 15:38:04,398 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:04,406 - INFO - Retrieved 1 datasources for dataset 8c982903-1747-4644-a6ca-5377b353e7dd
# 2025-07-17 15:38:04,407 - INFO - Dataset 8c982903-1747-4644-a6ca-5377b353e7dd: 1 datasources, 2 connection details
# 2025-07-17 15:38:04,407 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "PowerBI",
#     "kind": "PowerBI"
#   },
#   "datasourceId": "6a4737f6-9034-41ac-92a5-31166be56b4e",
#   "gatewayId": "fde2b36d-72cb-446d-a62d-617b3df2299f"
# }
# 2025-07-17 15:38:04,508 - INFO - Processing dataset 54/147: 78869f44-55e5-4bda-92c2-18e0e71e1891
# 2025-07-17 15:38:04,508 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/78869f44-55e5-4bda-92c2-18e0e71e1891/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:04,858 - INFO - Response status: 200
# 2025-07-17 15:38:04,858 - INFO - Response contains 9 datasources
# 2025-07-17 15:38:04,861 - INFO - Retrieved 9 datasources for dataset 78869f44-55e5-4bda-92c2-18e0e71e1891
# 2025-07-17 15:38:04,861 - INFO - Dataset 78869f44-55e5-4bda-92c2-18e0e71e1891: 9 datasources, 11 connection details
# 2025-07-17 15:38:04,862 - INFO - Sample datasource: {
#   "datasourceType": "File",
#   "connectionDetails": {
#     "path": "c:\\users\\ttson\\desktop\\dashboard tasks\\dei dashboard\\press ganey\\2020_09-2021_09_cgcahps_same_day_answer_phone_after_hrs_tson.xlsx"
#   },
#   "datasourceId": "4bf3ff49-c023-4778-acce-9bc0ddbe666d",
#   "gatewayId": "fdc3c190-f647-4b65-9487-5af5a1646da8"
# }
# 2025-07-17 15:38:04,962 - INFO - Processing dataset 55/147: 0a790cc0-3687-4bfe-8f36-29feb55578f7
# 2025-07-17 15:38:04,963 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/0a790cc0-3687-4bfe-8f36-29feb55578f7/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:05,151 - INFO - Response status: 200
# 2025-07-17 15:38:05,152 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:05,155 - INFO - Retrieved 1 datasources for dataset 0a790cc0-3687-4bfe-8f36-29feb55578f7
# ...
# 2025-07-17 15:38:51,363 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:51,366 - INFO - Retrieved 1 datasources for dataset 06787f82-aee4-45a2-ae09-7c7a87563f09
# 2025-07-17 15:38:51,366 - INFO - Dataset 06787f82-aee4-45a2-ae09-7c7a87563f09: 1 datasources, 2 connection details
# 2025-07-17 15:38:51,366 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "c079f971-863c-4279-ad3f-ab1411173b6e",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:38:51,467 - INFO - Processing dataset 136/147: 1ce0a85b-ced7-40c7-9ff6-9d3540a22e29
# 2025-07-17 15:38:51,467 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/1ce0a85b-ced7-40c7-9ff6-9d3540a22e29/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:51,664 - INFO - Response status: 200
# 2025-07-17 15:38:51,664 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:51,667 - INFO - Retrieved 1 datasources for dataset 1ce0a85b-ced7-40c7-9ff6-9d3540a22e29
# 2025-07-17 15:38:51,667 - INFO - Dataset 1ce0a85b-ced7-40c7-9ff6-9d3540a22e29: 1 datasources, 2 connection details
# 2025-07-17 15:38:51,667 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "c079f971-863c-4279-ad3f-ab1411173b6e",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:38:51,768 - INFO - Processing dataset 137/147: ed700c9a-8b55-411d-94d3-771cb74951a6
# 2025-07-17 15:38:51,768 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/ed700c9a-8b55-411d-94d3-771cb74951a6/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:51,959 - INFO - Response status: 200
# 2025-07-17 15:38:51,960 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:51,963 - INFO - Retrieved 1 datasources for dataset ed700c9a-8b55-411d-94d3-771cb74951a6
# 2025-07-17 15:38:51,963 - INFO - Dataset ed700c9a-8b55-411d-94d3-771cb74951a6: 1 datasources, 2 connection details
# 2025-07-17 15:38:51,963 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "c079f971-863c-4279-ad3f-ab1411173b6e",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:38:52,064 - INFO - Processing dataset 138/147: cec3c9ed-ba07-4e3b-a426-5ebd621696e4
# 2025-07-17 15:38:52,065 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/cec3c9ed-ba07-4e3b-a426-5ebd621696e4/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:52,235 - INFO - Response status: 200
# 2025-07-17 15:38:52,235 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:52,238 - INFO - Retrieved 1 datasources for dataset cec3c9ed-ba07-4e3b-a426-5ebd621696e4
# 2025-07-17 15:38:52,238 - INFO - Dataset cec3c9ed-ba07-4e3b-a426-5ebd621696e4: 1 datasources, 2 connection details
# 2025-07-17 15:38:52,239 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "c079f971-863c-4279-ad3f-ab1411173b6e",
#   "gatewayId": "1c72182e-146a-4a10-8bb0-3c87aa65e68b"
# }
# 2025-07-17 15:38:52,339 - INFO - Processing dataset 139/147: 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-17 15:38:52,340 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/8d248811-c245-4a94-b409-c508f5e00677/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:52,570 - INFO - Response status: 200
# 2025-07-17 15:38:52,571 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:52,574 - INFO - Retrieved 1 datasources for dataset 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-17 15:38:52,575 - INFO - Dataset 8d248811-c245-4a94-b409-c508f5e00677: 1 datasources, 2 connection details
# 2025-07-17 15:38:52,575 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "6a2e8e24-ffb4-42ae-a5b7-9d5c0928e98c",
#   "gatewayId": "83c69e43-b84b-4665-a835-9c4b6a642f99"
# }
# 2025-07-17 15:38:52,675 - INFO - Processing dataset 140/147: f5247c0a-f880-4c93-9f4e-3388e140dd9d
# 2025-07-17 15:38:52,676 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/f5247c0a-f880-4c93-9f4e-3388e140dd9d/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:52,838 - INFO - Response status: 200
# 2025-07-17 15:38:52,839 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:52,840 - INFO - Retrieved 1 datasources for dataset f5247c0a-f880-4c93-9f4e-3388e140dd9d
# 2025-07-17 15:38:52,841 - INFO - Dataset f5247c0a-f880-4c93-9f4e-3388e140dd9d: 1 datasources, 2 connection details
# 2025-07-17 15:38:52,841 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "69e31456-8a26-467d-a793-dcfc3037e9b1",
#   "gatewayId": "61597236-84c8-48f5-af77-8f3cf3e558a4"
# }
# 2025-07-17 15:38:52,942 - INFO - Completed batch 14. Waiting 2 seconds before next batch...
# 2025-07-17 15:38:54,942 - INFO - Processing batch 15/15 (datasets 141-147)
# 2025-07-17 15:38:54,943 - INFO - Processing dataset 141/147: f6f59c9e-6893-490f-9629-b1cfd42c2718
# 2025-07-17 15:38:54,944 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/f6f59c9e-6893-490f-9629-b1cfd42c2718/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:55,224 - INFO - Response status: 200
# 2025-07-17 15:38:55,225 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:55,227 - INFO - Retrieved 1 datasources for dataset f6f59c9e-6893-490f-9629-b1cfd42c2718
# 2025-07-17 15:38:55,228 - INFO - Dataset f6f59c9e-6893-490f-9629-b1cfd42c2718: 1 datasources, 2 connection details
# 2025-07-17 15:38:55,228 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "dd38c5ee-983b-4a83-914f-36f90a2bacc3",
#   "gatewayId": "ab385dd9-c982-4fbb-9e8f-1ea09375e727"
# }
# 2025-07-17 15:38:55,329 - INFO - Processing dataset 142/147: 4f3e3bbc-aa78-4582-b05a-4367d4d0b361
# 2025-07-17 15:38:55,329 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/4f3e3bbc-aa78-4582-b05a-4367d4d0b361/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:55,578 - INFO - Response status: 200
# 2025-07-17 15:38:55,578 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:55,580 - INFO - Retrieved 1 datasources for dataset 4f3e3bbc-aa78-4582-b05a-4367d4d0b361
# 2025-07-17 15:38:55,581 - INFO - Dataset 4f3e3bbc-aa78-4582-b05a-4367d4d0b361: 1 datasources, 2 connection details
# 2025-07-17 15:38:55,581 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "8cb346b9-ef84-4c27-bdcf-00b6cc9d4896",
#   "gatewayId": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a"
# }
# 2025-07-17 15:38:55,682 - INFO - Processing dataset 143/147: 2fbc6e7c-1d92-4143-b886-608c28a5c1a1
# 2025-07-17 15:38:55,682 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/2fbc6e7c-1d92-4143-b886-608c28a5c1a1/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:55,881 - INFO - Response status: 200
# 2025-07-17 15:38:55,882 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:55,884 - INFO - Retrieved 1 datasources for dataset 2fbc6e7c-1d92-4143-b886-608c28a5c1a1
# 2025-07-17 15:38:55,884 - INFO - Dataset 2fbc6e7c-1d92-4143-b886-608c28a5c1a1: 1 datasources, 2 connection details
# 2025-07-17 15:38:55,885 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "f6448daa-206d-4f74-8c2e-eb2899cd50c2",
#   "gatewayId": "b37d63a2-2f65-4488-bde6-52896ac0b01c"
# }
# 2025-07-17 15:38:55,985 - INFO - Processing dataset 144/147: ecf230de-5fa7-4b69-a225-b410a3ee9676
# 2025-07-17 15:38:55,985 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/datasets/ecf230de-5fa7-4b69-a225-b410a3ee9676/datasources with params: None (Attempt 1)
# 2025-07-17 15:38:56,162 - INFO - Response status: 200
# 2025-07-17 15:38:56,162 - INFO - Response contains 1 datasources
# 2025-07-17 15:38:56,165 - INFO - Retrieved 1 datasources for dataset ecf230de-5fa7-4b69-a225-b410a3ee9676
# 2025-07-17 15:38:56,166 - INFO - Dataset ecf230de-5fa7-4b69-a225-b410a3ee9676: 1 datasources, 2 connection details
# 2025-07-17 15:38:56,166 - INFO - Sample datasource: {
#   "datasourceType": "Extension",
#   "connectionDetails": {
#     "path": "UsageMetricsDataConnector",
#     "kind": "UsageMetricsDataConnector"
#   },
#   "datasourceId": "8cb346b9-ef84-4c27-bdcf-00b6cc9d4896",
#   "gatewayId": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a"
# }
# 2025-07-17 15:39:00,704 - INFO - Delta table 'pbi_datasources' already exists
# 2025-07-17 15:39:01,395 - INFO - Delta table 'pbi_datasources_connection_details' already exists
# 2025-07-17 15:39:01,396 - INFO - Starting merge operation for pbi_datasources
# 2025-07-17 15:39:03,357 - INFO - Executing merge query:
#     MERGE INTO pbi_datasources AS target
#     USING pbi_datasources_updates AS source
#     ON target.dataset_id = source.dataset_id AND target.datasource_id = source.datasource_id
#     WHEN MATCHED THEN
#         UPDATE SET target.datasource_type = source.datasource_type, target.gateway_id = source.gateway_id, target.connection_string = source.connection_string, target.name = source.name, target.extraction_date = source.extraction_date, target.extraction_batch_id = source.extraction_batch_id
#     WHEN NOT MATCHED THEN
#         INSERT *
#
# 2025-07-17 15:39:12,390 - INFO - Merge operation completed successfully for pbi_datasources
# 2025-07-17 15:39:12,390 - INFO - Optimizing Delta table 'pbi_datasources'
# 2025-07-17 15:39:15,851 - INFO - Table statistics updated successfully for pbi_datasources
# 2025-07-17 15:39:15,852 - INFO - Note: Microsoft Fabric may automatically optimize Delta tables
# 2025-07-17 15:39:15,852 - INFO - Starting merge operation for pbi_datasources_connection_details
# 2025-07-17 15:39:17,321 - INFO - Executing merge query:
#     MERGE INTO pbi_datasources_connection_details AS target
#     USING pbi_datasources_connection_details_updates AS source
#     ON target.dataset_id = source.dataset_id AND target.datasource_id = source.datasource_id AND target.connection_property = source.connection_property
#     WHEN MATCHED THEN
#         UPDATE SET target.connection_value = source.connection_value, target.extraction_date = source.extraction_date, target.extraction_batch_id = source.extraction_batch_id
#     WHEN NOT MATCHED THEN
#         INSERT *
#
# 2025-07-17 15:39:22,953 - INFO - Merge operation completed successfully for pbi_datasources_connection_details
# 2025-07-17 15:39:22,953 - INFO - Optimizing Delta table 'pbi_datasources_connection_details'
# 2025-07-17 15:39:25,550 - INFO - Table statistics updated successfully for pbi_datasources_connection_details
# 2025-07-17 15:39:25,551 - INFO - Note: Microsoft Fabric may automatically optimize Delta tables
# 2025-07-17 15:39:25,551 - INFO - Loading completed successfully!
# 2025-07-17 15:39:25,552 - INFO - === pbi_datasources Table Details ===
# +------------------------------------+---------------+------------------------------------+------------------------------------+-----------------+----+--------------------------+------------------------------------+
# |dataset_id                          |datasource_type|datasource_id                       |gateway_id                          |connection_string|name|extraction_date           |extraction_batch_id                 |
# +------------------------------------+---------------+------------------------------------+------------------------------------+-----------------+----+--------------------------+------------------------------------+
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|Extension      |6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|7e508ae6-3f91-43a5-ba20-e24caa4b7fd5|NULL             |NULL|2025-07-17 15:37:34.216279|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|Extension      |30d92dc2-4a7b-4719-92a7-97c26a879d8a|1c72182e-146a-4a10-8bb0-3c87aa65e68b|NULL             |NULL|2025-07-17 15:37:34.580652|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |187c3787-c4a5-47a3-a35b-149b72bbd070|Extension      |13c115c3-01f8-4133-a5fc-fb81163aecd2|f29ff6e2-d740-44c1-a6ed-b1763344ea0d|NULL             |NULL|2025-07-17 15:37:35.040854|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |09eac459-9b71-4e9b-8771-45a142078a0d|Extension      |6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|7e508ae6-3f91-43a5-ba20-e24caa4b7fd5|NULL             |NULL|2025-07-17 15:37:35.405969|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |36e4c8d8-d521-4577-93f8-307633711275|Extension      |3502167a-1a61-41ff-ad9b-c240d767e570|51bb2458-5a48-49cc-9a6e-ab67c9ab9e37|NULL             |NULL|2025-07-17 15:37:35.813833|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# +------------------------------------+---------------+------------------------------------+------------------------------------+-----------------+----+--------------------------+------------------------------------+
# only showing top 5 rows
#
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# |dataset_id                          |datasource_id                       |connection_property|connection_value      |extraction_date           |extraction_batch_id                 |
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|path               |PowerPlatformDataflows|2025-07-17 15:37:34.216286|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|kind               |PowerPlatformDataflows|2025-07-17 15:37:34.216288|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|30d92dc2-4a7b-4719-92a7-97c26a879d8a|path               |PowerPlatformDataflows|2025-07-17 15:37:34.580658|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|30d92dc2-4a7b-4719-92a7-97c26a879d8a|kind               |PowerPlatformDataflows|2025-07-17 15:37:34.580659|4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# |187c3787-c4a5-47a3-a35b-149b72bbd070|13c115c3-01f8-4133-a5fc-fb81163aecd2|path               |PowerPlatformDataflows|2025-07-17 15:37:35.04086 |4fdb355c-6f7c-4135-94e3-62a3c9d2cf9a|
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# only showing top 5 rows
#
# +------------------------+---------------+------------------+-----------------+--------------------------+
# |total_connection_details|unique_datasets|unique_datasources|unique_properties|last_updated              |
# +------------------------+---------------+------------------+-----------------+--------------------------+
# |441                     |141            |122               |5                |2025-07-17 15:38:56.545455|
# +------------------------+---------------+------------------+-----------------+--------------------------+
#
# +-------------------+-----+
# |connection_property|count|
# +-------------------+-----+
# |url                |104  |
# |server             |94   |
# |path               |91   |
# |database           |89   |
# |kind               |63   |
# +-------------------+-----+

# %%
from pyspark.sql import SparkSession

# create Spark session
spark = SparkSession.builder.appName("Refresh SQL Endpoint Metadata").getOrCreate()

# refresh the specific table
spark.sql("REFRESH TABLE pbi_datasources")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE pbi_datasources_connection_details")
print("Metadata refresh triggered successfully.")
# Out:
# StatementMeta(, fad4e198-0861-46c0-97cc-62ecf271dbdc, 5, Finished, Available, Finished)
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
