# %%
# DO NOT DELETE THIS CELL

# IMPORTANT!!! This notebook is only pulling data for object on the MDA Institutional Capacity - PROD capacity! See line 244 for details.

# API Name: Gateways - Get Datasources
# Command:  GET https://api.powerbi.com/v1.0/myorg/gateways/{gatewayId}/datasources
# Doc:      https://learn.microsoft.com/en-us/rest/api/power-bi/gateways/get-datasources

# Loads table: pbi_datasets_datasources
# Loads table: pbi_datasets_datasources_connection_details

# IMPORTANT!!! This notebook is only pulling data for object on the MDA Institutional Capacity - PROD capacity! See line 244 for details.
# Note: this queries the pbi_datasets table to get a list of dataset_Id values for the API calls.
# Out:
# StatementMeta(, bc48bd6a-b0ef-452f-a9f2-189999c838f6, 3, Finished, Available, Finished)

# %%
# CELL 1 - Title and Introduction
# ==================================
# Microsoft Fabric Dataset Datasources to Delta Lake - PySpark Notebook
# This notebook retrieves dataset datasources from Power BI Admin API and loads them into Delta Lake tables
# with optimization for analytics workloads
# ==================================



# CELL 2 - Import Libraries
# ==================================
# Import required libraries
import requests
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_timestamp, lit, explode, when, isnan, isnull
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
import logging
from typing import Dict, List, Optional, Tuple
from delta.tables import DeltaTable
import random
import time
import uuid
from datetime import datetime
# ==================================


# CELL 3 - Configure Logging and Initialize Spark
# ==================================
# Configure logging
# This helps us track what's happening in our code and debug issues
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize Spark Session with Delta Lake configurations
# In Fabric notebooks, Spark is pre-configured with Delta support
spark = SparkSession.builder \
    .appName("FabricDatasetDatasourcesToDelta") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Set optimal configurations for Delta operations
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "true")
spark.conf.set("spark.databricks.delta.autoCompact.enabled", "true")
# ==================================


# CELL 4 - Configuration Parameters
# ==================================
# Configuration Parameters
# These are the settings we'll use throughout the notebook
CONFIG = {
    "API_BASE_URL": "https://api.powerbi.com/v1.0/myorg",
    "DATASOURCES_ENDPOINT_TEMPLATE": "/admin/datasets/{dataset_id}/datasources",  # Template for datasources endpoint
    "MAX_RETRIES": 5,  # Number of retries for handling rate limits
    "INITIAL_BACKOFF_SEC": 1,  # Initial backoff time in seconds
    "MAX_BACKOFF_SEC": 60,  # Maximum backoff time in seconds
    "BACKOFF_FACTOR": 2,  # Exponential backoff multiplier
    "JITTER_FACTOR": 0.1,  # Random jitter to add to backoff (as a fraction)
    "TIMEOUT": 30,  # API request timeout in seconds
    "DATASOURCES_TABLE_NAME": "pbi_datasets_datasources",  # Main table name
    "CONNECTION_DETAILS_TABLE_NAME": "pbi_datasets_datasources_connection_details",  # Details table name
    "LAKEHOUSE_PATH": "Tables",  # Default Tables folder in Fabric Lakehouse
    "DEBUG_MODE": True,  # Set to True to enable extra debugging output
    "BATCH_SIZE": 50,  # Number of datasets to process in each batch
    "RATE_LIMIT_REQUESTS_PER_HOUR": 300  # API rate limit
}

# Generate a unique batch ID for this execution
BATCH_ID = str(uuid.uuid4())
logger.info(f"Batch ID for this execution: {BATCH_ID}")
# ==================================


# CELL 5 - Authentication Function
# ==================================
def get_access_token():
    """
    Get Azure AD access token for Power BI API authentication.
    
    In a Fabric notebook, the token is automatically available through mssparkutils.
    This function retrieves the token that's needed to authenticate with the Power BI REST API.
    
    Returns:
        str: The access token
    
    Note:
        mssparkutils is a utility library provided by Microsoft Fabric
        that handles authentication automatically.
    """
    try:
        # In Fabric notebooks, we can get the token using mssparkutils
        from notebookutils import mssparkutils
        token_response = mssparkutils.credentials.getToken("https://analysis.windows.net/powerbi/api")
        return token_response
    except Exception as e:
        logger.error(f"Failed to get access token: {str(e)}")
        raise
# ==================================


# CELL 6 - API Call Function
# ==================================
def call_powerbi_api(endpoint: str, access_token: str, params: Optional[Dict] = None) -> Dict:
    """
    Make a REST API call to Power BI with advanced rate limit handling.
    
    This function handles the HTTP request to the Power BI API, including:
    - Setting up authentication headers
    - Managing retries with intelligent backoff for rate limiting (429 errors)
    - Implementing jitter to avoid synchronized retries
    - Detailed error handling and logging
    
    Args:
        endpoint: The API endpoint path (e.g., "/admin/datasets/{id}/datasources")
        access_token: The Azure AD access token
        params: Optional query parameters for the API call
    
    Returns:
        dict: The JSON response from the API
    
    Raises:
        requests.exceptions.RequestException: If the API call fails after all retries
    """
    url = f"{CONFIG['API_BASE_URL']}{endpoint}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    # Initialize backoff time
    backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
    
    # Retry logic with intelligent backoff
    for attempt in range(CONFIG['MAX_RETRIES']):
        try:
            # Log the full URL with parameters for debugging
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Making API call to: {url} with params: {params} (Attempt {attempt + 1})")
            
            response = requests.get(
                url,
                headers=headers,
                params=params,
                timeout=CONFIG['TIMEOUT']
            )
            
            # Log the response status for debugging
            if CONFIG['DEBUG_MODE']:
                logger.info(f"Response status: {response.status_code}")
            
            # Rate limit handling (429 Too Many Requests)
            if response.status_code == 429:
                # Get retry-after header if available, otherwise use our backoff
                retry_after = response.headers.get('Retry-After')
                
                if retry_after and retry_after.isdigit():
                    # If server specified a wait time, use it
                    wait_time = int(retry_after)
                else:
                    # Calculate wait time with exponential backoff and jitter
                    jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                    wait_time = backoff_time + jitter
                    # Update backoff for next attempt
                    backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.warning(f"Rate limit exceeded (429). Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
                continue  # Skip to next retry attempt without raising exception
            
            # Handle 404 - Dataset not found or no datasources
            if response.status_code == 404:
                logger.warning(f"Dataset not found or no datasources available: {endpoint}")
                return {"value": []}  # Return empty result
            
            # Handle 403 - Forbidden (insufficient permissions)
            if response.status_code == 403:
                logger.warning(f"Insufficient permissions for dataset: {endpoint}")
                return {"value": []}  # Return empty result
            
            # Log other errors for debugging
            if response.status_code >= 400:
                logger.error(f"API error: Status {response.status_code}, Response: {response.text}")
                logger.error(f"Request URL: {response.request.url}")
                logger.error(f"Request headers: {response.request.headers}")
            
            # For all other status codes, use raise_for_status to handle
            response.raise_for_status()
            
            # If we get here, the request was successful
            # Reset backoff for next API call (not next attempt)
            backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
            
            # Parse and return the JSON response
            try:
                response_json = response.json()
                if CONFIG['DEBUG_MODE'] and "value" in response_json:
                    logger.info(f"Response contains {len(response_json['value'])} datasources")
                return response_json
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse response as JSON: {str(e)}")
                logger.error(f"Response content: {response.text[:1000]}")  # Log first 1000 chars
                raise
            
        except requests.exceptions.RequestException as e:
            last_attempt = attempt == CONFIG['MAX_RETRIES'] - 1
            
            # Special handling for non-429 errors
            if not (hasattr(e, 'response') and e.response is not None and e.response.status_code == 429):
                logger.warning(f"API call failed (Attempt {attempt + 1}): {str(e)}")
                
                if last_attempt:
                    logger.error(f"All retry attempts failed for endpoint: {endpoint}")
                    logger.error(f"Final error: {str(e)}")
                    raise
                
                # Calculate wait time with exponential backoff and jitter
                jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                wait_time = backoff_time + jitter
                # Update backoff for next attempt
                backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.info(f"Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
# ==================================


# CELL 7 - Get Dataset IDs Function
# ==================================
def get_dataset_ids() -> List[str]:
    """
    Get the list of dataset IDs to process by executing the provided SQL query.
    
    This function executes the SQL query that joins capacities, workspaces, and datasets
    to get the dataset IDs for the specific capacity and criteria.
    
    Returns:
        list: A list of dataset ID strings
    """
    logger.info("Executing SQL query to get dataset IDs...")
    
    # SQL query provided in the requirements
    sql_query = """
    SELECT ds.id
    FROM 
        FabricAdmin_Lakehouse.dbo.fabric_capacities AS fc
    JOIN 
        FabricAdmin_Lakehouse.dbo.fabric_workspaces AS fw
        ON UPPER(fc.id) = fw.capacityId  -- Join on capacityId
    JOIN 
        FabricAdmin_Lakehouse.dbo.pbi_datasets AS ds
        ON fw.id = ds.workspaceId  -- Join on workspaceid
    WHERE 
        fc.displayName = 'MDA Institutional Capacity - PROD'  -- Filter for specific displayName
        and fw.state = 'Active'  -- Filter for active workspaces
        AND fw.type <> 'Personal'  -- Exclude personal workspaces
    """
    
    try:
        # Execute the query and collect results
        result_df = spark.sql(sql_query)
        dataset_ids = [row.id for row in result_df.collect()]
        
        logger.info(f"Found {len(dataset_ids)} datasets to process")
        
        if CONFIG['DEBUG_MODE'] and dataset_ids:
            logger.info(f"First 5 dataset IDs: {dataset_ids[:5]}")
        
        return dataset_ids
    
    except Exception as e:
        logger.error(f"Failed to execute SQL query: {str(e)}")
        logger.error(f"Query: {sql_query}")
        raise
# ==================================


# CELL 8 - Get Dataset Datasources Function
# ==================================
def get_dataset_datasources(dataset_id: str, access_token: str) -> Tuple[List[Dict], List[Dict]]:
    """
    Retrieve datasources for a specific dataset from the Power BI API.
    
    This function calls the GetDatasourcesAsAdmin endpoint for a specific dataset
    and returns both the main datasource data and the flattened connection details.
    
    Args:
        dataset_id: The ID of the dataset to get datasources for
        access_token: The Azure AD access token
    
    Returns:
        tuple: (main_datasources_data, connection_details_data)
            - main_datasources_data: List of main datasource records
            - connection_details_data: List of flattened connection detail records
    """
    endpoint = CONFIG['DATASOURCES_ENDPOINT_TEMPLATE'].format(dataset_id=dataset_id)
    
    try:
        response_data = call_powerbi_api(endpoint, access_token)
        datasources = response_data.get("value", [])
        
        if not datasources:
            if CONFIG['DEBUG_MODE']:
                logger.info(f"No datasources found for dataset {dataset_id}")
            return [], []
        
        logger.info(f"Found {len(datasources)} datasources for dataset {dataset_id}")
        
        # Process each datasource
        main_datasources_data = []
        connection_details_data = []
        
        for datasource in datasources:
            # Main datasource record
            main_record = {
                "dataset_id": dataset_id,
                "datasource_id": datasource.get("datasourceId"),
                "datasource_name": datasource.get("name"),
                "datasource_type": datasource.get("datasourceType"),
                "gateway_id": datasource.get("gatewayId"),
                "connection_string": datasource.get("connectionString"),
                "extraction_timestamp": datetime.now(),
                "extraction_batch_id": BATCH_ID
            }
            main_datasources_data.append(main_record)
            
            # Process connection details
            connection_details = datasource.get("connectionDetails", {})
            if connection_details and isinstance(connection_details, dict):
                for property_name, property_value in connection_details.items():
                    # Convert property value to string if it's not None
                    property_value_str = str(property_value) if property_value is not None else None
                    
                    detail_record = {
                        "dataset_id": dataset_id,
                        "datasource_id": datasource.get("datasourceId"),
                        "connection_property": property_name,
                        "connection_value": property_value_str,
                        "extraction_timestamp": datetime.now(),
                        "extraction_batch_id": BATCH_ID
                    }
                    connection_details_data.append(detail_record)
        
        if CONFIG['DEBUG_MODE'] and main_datasources_data:
            logger.info(f"Sample datasource for dataset {dataset_id}: {json.dumps(main_datasources_data[0], default=str, indent=2)}")
        
        return main_datasources_data, connection_details_data
    
    except Exception as e:
        logger.error(f"Failed to get datasources for dataset {dataset_id}: {str(e)}")
        # Return empty lists instead of raising to continue with other datasets
        return [], []
# ==================================


# CELL 9 - Process Datasets in Batches Function
# ==================================
def process_datasets_in_batches(dataset_ids: List[str], access_token: str) -> Tuple[List[Dict], List[Dict]]:
    """
    Process multiple datasets in batches to respect API rate limits.
    
    This function processes the dataset IDs in batches to avoid hitting the
    API rate limit of 300 requests per hour.
    
    Args:
        dataset_ids: List of dataset IDs to process
        access_token: The Azure AD access token
    
    Returns:
        tuple: (all_main_data, all_connection_details_data)
    """
    all_main_data = []
    all_connection_details_data = []
    
    total_datasets = len(dataset_ids)
    batch_size = CONFIG['BATCH_SIZE']
    
    # Calculate timing for rate limiting
    # API allows 300 requests per hour = 5 requests per minute
    # We'll be conservative and do 4 requests per minute
    requests_per_minute = 4
    delay_between_requests = 60 / requests_per_minute  # 15 seconds between requests
    
    logger.info(f"Processing {total_datasets} datasets in batches of {batch_size}")
    logger.info(f"Using {delay_between_requests} seconds delay between API calls to respect rate limits")
    
    for i in range(0, total_datasets, batch_size):
        batch_datasets = dataset_ids[i:i + batch_size]
        batch_num = (i // batch_size) + 1
        total_batches = (total_datasets + batch_size - 1) // batch_size
        
        logger.info(f"Processing batch {batch_num}/{total_batches} ({len(batch_datasets)} datasets)")
        
        batch_main_data = []
        batch_connection_details_data = []
        
        for j, dataset_id in enumerate(batch_datasets):
            try:
                logger.info(f"Processing dataset {i + j + 1}/{total_datasets}: {dataset_id}")
                
                main_data, connection_details_data = get_dataset_datasources(dataset_id, access_token)
                
                batch_main_data.extend(main_data)
                batch_connection_details_data.extend(connection_details_data)
                
                # Add delay between requests to respect rate limits (except for the last request)
                if j < len(batch_datasets) - 1:
                    time.sleep(delay_between_requests)
                
            except Exception as e:
                logger.error(f"Failed to process dataset {dataset_id}: {str(e)}")
                # Continue with next dataset
                continue
        
        # Add batch results to overall results
        all_main_data.extend(batch_main_data)
        all_connection_details_data.extend(batch_connection_details_data)
        
        logger.info(f"Batch {batch_num} completed. Found {len(batch_main_data)} datasources total")
        
        # Add delay between batches if not the last batch
        if batch_num < total_batches:
            batch_delay = 30  # 30 seconds between batches
            logger.info(f"Waiting {batch_delay} seconds before next batch...")
            time.sleep(batch_delay)
    
    logger.info(f"All batches completed. Total datasources found: {len(all_main_data)}")
    logger.info(f"Total connection detail records: {len(all_connection_details_data)}")
    
    return all_main_data, all_connection_details_data
# ==================================


# CELL 10 - Create DataFrames Function
# ==================================
def create_datasources_dataframes(main_data: List[Dict], connection_details_data: List[Dict]) -> Tuple["DataFrame", "DataFrame"]:
    """
    Convert the datasources data into PySpark DataFrames for Delta Lake.
    
    This function creates two DataFrames:
    1. Main datasources DataFrame
    2. Connection details DataFrame
    
    Args:
        main_data: List of main datasource dictionaries
        connection_details_data: List of connection detail dictionaries
    
    Returns:
        tuple: (main_df, connection_details_df)
    """
    # Define schema for main datasources table
    main_schema = StructType([
        StructField("dataset_id", StringType(), False),
        StructField("datasource_id", StringType(), True),
        StructField("datasource_name", StringType(), True),
        StructField("datasource_type", StringType(), True),
        StructField("gateway_id", StringType(), True),
        StructField("connection_string", StringType(), True),
        StructField("extraction_timestamp", TimestampType(), False),
        StructField("extraction_batch_id", StringType(), False)
    ])
    
    # Define schema for connection details table
    connection_details_schema = StructType([
        StructField("dataset_id", StringType(), False),
        StructField("datasource_id", StringType(), True),
        StructField("connection_property", StringType(), False),
        StructField("connection_value", StringType(), True),
        StructField("extraction_timestamp", TimestampType(), False),
        StructField("extraction_batch_id", StringType(), False)
    ])
    
    # Create main datasources DataFrame
    if main_data:
        main_pandas_df = pd.DataFrame(main_data)
        main_df = spark.createDataFrame(main_pandas_df, schema=main_schema)
        logger.info(f"Created main datasources DataFrame with {main_df.count()} rows")
    else:
        logger.warning("No main datasource data found. Creating empty DataFrame.")
        main_df = spark.createDataFrame([], main_schema)
    
    # Create connection details DataFrame
    if connection_details_data:
        connection_details_pandas_df = pd.DataFrame(connection_details_data)
        connection_details_df = spark.createDataFrame(connection_details_pandas_df, schema=connection_details_schema)
        logger.info(f"Created connection details DataFrame with {connection_details_df.count()} rows")
    else:
        logger.warning("No connection details data found. Creating empty DataFrame.")
        connection_details_df = spark.createDataFrame([], connection_details_schema)
    
    return main_df, connection_details_df
# ==================================


# CELL 11 - Delta Lake Operations Functions
# ==================================
def ensure_delta_table_exists(table_name: str, df_schema):
    """
    Ensure the Delta table exists, creating it if necessary.
    
    Args:
        table_name: Name of the Delta table
        df_schema: Schema of the DataFrame
    """
    try:
        # Check if table exists
        spark.sql(f"DESCRIBE TABLE {table_name}")
        logger.info(f"Delta table '{table_name}' already exists")
    except Exception:
        # Table doesn't exist, create it
        logger.info(f"Creating Delta table '{table_name}'")
        
        # Create an empty DataFrame with the schema
        empty_df = spark.createDataFrame([], df_schema)
        
        # Create the Delta table
        empty_df.write \
            .mode("overwrite") \
            .option("overwriteSchema", "true") \
            .saveAsTable(table_name)
        
        logger.info(f"Delta table '{table_name}' created successfully")


def merge_data_to_delta(source_df, table_name: str, merge_keys: List[str]):
    """
    Merge new data into the Delta table using MERGE operation.
    
    This function performs an upsert operation:
    - Updates existing records if the merge keys match
    - Inserts new records if the merge keys don't exist
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
        merge_keys: List of column names to use for matching records
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    source_df.createOrReplaceTempView("source_updates")
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Build the merge condition
    merge_condition = " AND ".join([f"target.{key} = source.{key}" for key in merge_keys])
    
    # Get all columns for the UPDATE SET clause (excluding merge keys to avoid redundancy)
    all_columns = source_df.columns
    update_columns = [col for col in all_columns if col not in merge_keys]
    update_set_clause = ", ".join([f"target.{col} = source.{col}" for col in update_columns])
    
    # Perform the merge operation
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING source_updates AS source
    ON {merge_condition}
    WHEN MATCHED THEN
        UPDATE SET {update_set_clause}
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    if CONFIG['DEBUG_MODE']:
        logger.info(f"Merge query: {merge_query}")
    
    spark.sql(merge_query)
    logger.info("Merge operation completed successfully")


def optimize_delta_table(table_name: str):
    """
    Optimize the Delta table for better query performance.
    
    Args:
        table_name: Name of the Delta table to optimize
    """
    logger.info(f"Optimizing Delta table '{table_name}'")
    
    try:
        # Update table statistics for better query planning
        spark.sql(f"ANALYZE TABLE {table_name} COMPUTE STATISTICS")
        logger.info("Table statistics updated successfully")
        
        logger.info("Delta table optimization completed via statistics computation")
        logger.info("Note: Microsoft Fabric may automatically optimize Delta tables")
    except Exception as e:
        logger.warning(f"Table optimization step encountered an issue: {str(e)}")
        logger.info("Continuing with process - optimization is not critical for functionality")
# ==================================


# CELL 12 - Main Execution Function
# ==================================
def main():
    """
    Main execution function that orchestrates the entire process.
    
    This function:
    1. Gets the authentication token
    2. Retrieves dataset IDs from the SQL query
    3. Processes datasets in batches to get their datasources
    4. Creates PySpark DataFrames with the data
    5. Loads data into Delta Lake tables
    6. Optimizes the tables for analytics
    """
    try:
        logger.info("Starting Dataset Datasources to Delta Lake process")
        
        # Step 1: Get authentication token
        logger.info("Getting access token...")
        access_token = get_access_token()
        logger.info("Successfully obtained access token")
        
        # Step 2: Get dataset IDs to process
        logger.info("Getting dataset IDs from SQL query...")
        dataset_ids = get_dataset_ids()
        
        if not dataset_ids:
            logger.warning("No dataset IDs found. Please check your SQL query and data.")
            return
        
        # Step 3: Process datasets in batches
        logger.info("Processing datasets to get datasources...")
        main_data, connection_details_data = process_datasets_in_batches(dataset_ids, access_token)
        
        # Step 4: Create DataFrames
        logger.info("Creating DataFrames...")
        main_df, connection_details_df = create_datasources_dataframes(main_data, connection_details_data)
        
        # Show sample data
        if main_df.count() > 0:
            logger.info("Sample of main datasources data:")
            main_df.show(5, truncate=False)
        
        if connection_details_df.count() > 0:
            logger.info("Sample of connection details data:")
            connection_details_df.show(10, truncate=False)
        
        # Step 5: Prepare Delta tables
        main_table_name = CONFIG["DATASOURCES_TABLE_NAME"]
        connection_details_table_name = CONFIG["CONNECTION_DETAILS_TABLE_NAME"]
        
        ensure_delta_table_exists(main_table_name, main_df.schema)
        ensure_delta_table_exists(connection_details_table_name, connection_details_df.schema)
        
        # Step 6: Merge data into Delta tables
        if main_df.count() > 0:
            merge_data_to_delta(main_df, main_table_name, ["dataset_id", "datasource_id"])
            optimize_delta_table(main_table_name)
        
        if connection_details_df.count() > 0:
            merge_data_to_delta(connection_details_df, connection_details_table_name, 
                              ["dataset_id", "datasource_id", "connection_property"])
            optimize_delta_table(connection_details_table_name)
        
        # Step 7: Display final statistics
        logger.info("Loading completed successfully!")
        
        # Show table information for main table
        logger.info(f"Main table ({main_table_name}) details:")
        spark.sql(f"DESCRIBE DETAIL {main_table_name}").show(truncate=False)
        
        main_row_count = spark.table(main_table_name).count()
        logger.info(f"Total rows in {main_table_name}: {main_row_count}")
        
        # Show table information for connection details table
        logger.info(f"Connection details table ({connection_details_table_name}) details:")
        spark.sql(f"DESCRIBE DETAIL {connection_details_table_name}").show(truncate=False)
        
        connection_details_row_count = spark.table(connection_details_table_name).count()
        logger.info(f"Total rows in {connection_details_table_name}: {connection_details_row_count}")
        
        # Show summary statistics for main table
        if main_row_count > 0:
            summary_stats = spark.sql(f"""
                SELECT 
                    COUNT(*) as total_datasources,
                    COUNT(DISTINCT dataset_id) as unique_datasets,
                    COUNT(DISTINCT datasource_type) as datasource_types,
                    COUNT(DISTINCT gateway_id) as unique_gateways,
                    MAX(extraction_timestamp) as last_updated
                FROM {main_table_name}
            """)
            
            logger.info("Main table summary statistics:")
            summary_stats.show(truncate=False)
            
            # Show distribution by datasource type
            type_distribution = spark.sql(f"""
                SELECT 
                    datasource_type,
                    COUNT(*) as count
                FROM {main_table_name}
                GROUP BY datasource_type
                ORDER BY count DESC
            """)
            
            logger.info("Datasource distribution by type:")
            type_distribution.show(truncate=False)
        
        # Show summary for connection details
        if connection_details_row_count > 0:
            connection_summary = spark.sql(f"""
                SELECT 
                    COUNT(*) as total_connection_properties,
                    COUNT(DISTINCT connection_property) as unique_properties,
                    COUNT(DISTINCT dataset_id) as datasets_with_details
                FROM {connection_details_table_name}
            """)
            
            logger.info("Connection details summary:")
            connection_summary.show(truncate=False)
        
        return main_df, connection_details_df
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")
        raise
# ==================================


# CELL 13 - Execute Main Function
# ==================================
# Execute the main function
if __name__ == "__main__":
    main_df, connection_details_df = main()
# ==================================
# Out:
# StatementMeta(, bc48bd6a-b0ef-452f-a9f2-189999c838f6, 4, Finished, Available, Finished)
# 2025-07-17 15:39:00,938 - INFO - Batch ID for this execution: da1dd779-45ba-42f0-bf98-49a53d0d516c
# 2025-07-17 15:39:00,942 - INFO - Starting Dataset Datasources to Delta Lake process
# 2025-07-17 15:39:00,942 - INFO - Getting access token...
# 2025-07-17 15:39:00,957 - INFO - Successfully obtained access token
# 2025-07-17 15:39:00,957 - INFO - Getting dataset IDs from SQL query...
# 2025-07-17 15:39:00,957 - INFO - Executing SQL query to get dataset IDs...
# 2025-07-17 15:39:21,253 - INFO - Found 147 datasets to process
# 2025-07-17 15:39:21,255 - INFO - First 5 dataset IDs: ['d9a141b5-20e2-4c8a-825b-02c0f63bd691', 'c6c5b1e8-4f0c-400e-a396-72048f9b3871', '187c3787-c4a5-47a3-a35b-149b72bbd070', '09eac459-9b71-4e9b-8771-45a142078a0d', '36e4c8d8-d521-4577-93f8-307633711275']
# 2025-07-17 15:39:21,257 - INFO - Processing datasets to get datasources...
# 2025-07-17 15:39:21,258 - INFO - Processing 147 datasets in batches of 50
# 2025-07-17 15:39:21,258 - INFO - Using 15.0 seconds delay between API calls to respect rate limits
# 2025-07-17 15:39:21,258 - INFO - Processing batch 1/3 (50 datasets)
# 2025-07-17 15:39:21,259 - INFO - Processing dataset 1/147: d9a141b5-20e2-4c8a-825b-02c0f63bd691
# 2025-07-17 15:39:21,259 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/d9a141b5-20e2-4c8a-825b-02c0f63bd691/datasources with params: None (Attempt 1)
# 2025-07-17 15:39:21,646 - INFO - Response status: 200
# 2025-07-17 15:39:21,647 - INFO - Response contains 1 datasources
# 2025-07-17 15:39:21,650 - INFO - Found 1 datasources for dataset d9a141b5-20e2-4c8a-825b-02c0f63bd691
# 2025-07-17 15:39:21,651 - INFO - Sample datasource for dataset d9a141b5-20e2-4c8a-825b-02c0f63bd691: {
#   "dataset_id": "d9a141b5-20e2-4c8a-825b-02c0f63bd691",
#   "datasource_id": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:39:21.651736",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:39:36,652 - INFO - Processing dataset 2/147: c6c5b1e8-4f0c-400e-a396-72048f9b3871
# 2025-07-17 15:39:36,652 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/c6c5b1e8-4f0c-400e-a396-72048f9b3871/datasources with params: None (Attempt 1)
# 2025-07-17 15:39:36,814 - INFO - Response status: 200
# 2025-07-17 15:39:36,815 - INFO - Response contains 1 datasources
# 2025-07-17 15:39:36,816 - INFO - Found 1 datasources for dataset c6c5b1e8-4f0c-400e-a396-72048f9b3871
# 2025-07-17 15:39:36,817 - INFO - Sample datasource for dataset c6c5b1e8-4f0c-400e-a396-72048f9b3871: {
#   "dataset_id": "c6c5b1e8-4f0c-400e-a396-72048f9b3871",
#   "datasource_id": "30d92dc2-4a7b-4719-92a7-97c26a879d8a",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "1c72182e-146a-4a10-8bb0-3c87aa65e68b",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:39:36.817739",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:39:51,818 - INFO - Processing dataset 3/147: 187c3787-c4a5-47a3-a35b-149b72bbd070
# 2025-07-17 15:39:51,818 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/187c3787-c4a5-47a3-a35b-149b72bbd070/datasources with params: None (Attempt 1)
# 2025-07-17 15:39:52,056 - INFO - Response status: 200
# 2025-07-17 15:39:52,056 - INFO - Response contains 1 datasources
# 2025-07-17 15:39:52,058 - INFO - Found 1 datasources for dataset 187c3787-c4a5-47a3-a35b-149b72bbd070
# 2025-07-17 15:39:52,058 - INFO - Sample datasource for dataset 187c3787-c4a5-47a3-a35b-149b72bbd070: {
#   "dataset_id": "187c3787-c4a5-47a3-a35b-149b72bbd070",
#   "datasource_id": "13c115c3-01f8-4133-a5fc-fb81163aecd2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "f29ff6e2-d740-44c1-a6ed-b1763344ea0d",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:39:52.058828",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:40:07,059 - INFO - Processing dataset 4/147: 09eac459-9b71-4e9b-8771-45a142078a0d
# 2025-07-17 15:40:07,060 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/09eac459-9b71-4e9b-8771-45a142078a0d/datasources with params: None (Attempt 1)
# 2025-07-17 15:40:08,467 - INFO - Response status: 200
# 2025-07-17 15:40:08,467 - INFO - Response contains 1 datasources
# 2025-07-17 15:40:08,470 - INFO - Found 1 datasources for dataset 09eac459-9b71-4e9b-8771-45a142078a0d
# 2025-07-17 15:40:08,471 - INFO - Sample datasource for dataset 09eac459-9b71-4e9b-8771-45a142078a0d: {
#   "dataset_id": "09eac459-9b71-4e9b-8771-45a142078a0d",
#   "datasource_id": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:40:08.471100",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:40:23,471 - INFO - Processing dataset 5/147: 36e4c8d8-d521-4577-93f8-307633711275
# 2025-07-17 15:40:23,472 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/36e4c8d8-d521-4577-93f8-307633711275/datasources with params: None (Attempt 1)
# 2025-07-17 15:40:23,644 - INFO - Response status: 200
# 2025-07-17 15:40:23,644 - INFO - Response contains 1 datasources
# 2025-07-17 15:40:23,646 - INFO - Found 1 datasources for dataset 36e4c8d8-d521-4577-93f8-307633711275
# 2025-07-17 15:40:23,647 - INFO - Sample datasource for dataset 36e4c8d8-d521-4577-93f8-307633711275: {
#   "dataset_id": "36e4c8d8-d521-4577-93f8-307633711275",
#   "datasource_id": "3502167a-1a61-41ff-ad9b-c240d767e570",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "51bb2458-5a48-49cc-9a6e-ab67c9ab9e37",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:40:23.647725",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:40:38,648 - INFO - Processing dataset 6/147: 92e5929a-8148-4279-b43e-fe9eea21f273
# 2025-07-17 15:40:38,648 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/92e5929a-8148-4279-b43e-fe9eea21f273/datasources with params: None (Attempt 1)
# 2025-07-17 15:40:39,173 - INFO - Response status: 200
# 2025-07-17 15:40:39,174 - INFO - Response contains 1 datasources
# 2025-07-17 15:40:39,176 - INFO - Found 1 datasources for dataset 92e5929a-8148-4279-b43e-fe9eea21f273
# 2025-07-17 15:40:39,177 - INFO - Sample datasource for dataset 92e5929a-8148-4279-b43e-fe9eea21f273: {
#   "dataset_id": "92e5929a-8148-4279-b43e-fe9eea21f273",
#   "datasource_id": "dd453547-6c50-4313-910b-5793061b9bbd",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "8d70492b-f7bb-43d5-b211-7ae1dbdf3c11",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:40:39.177233",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:40:54,177 - INFO - Processing dataset 7/147: a4e211e0-f3f5-472f-8edb-de511fc76e3f
# 2025-07-17 15:40:54,178 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/a4e211e0-f3f5-472f-8edb-de511fc76e3f/datasources with params: None (Attempt 1)
# 2025-07-17 15:40:54,349 - INFO - Response status: 200
# 2025-07-17 15:40:54,350 - INFO - Response contains 1 datasources
# 2025-07-17 15:40:54,351 - INFO - Found 1 datasources for dataset a4e211e0-f3f5-472f-8edb-de511fc76e3f
# 2025-07-17 15:40:54,352 - INFO - Sample datasource for dataset a4e211e0-f3f5-472f-8edb-de511fc76e3f: {
#   "dataset_id": "a4e211e0-f3f5-472f-8edb-de511fc76e3f",
#   "datasource_id": "13c115c3-01f8-4133-a5fc-fb81163aecd2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "f29ff6e2-d740-44c1-a6ed-b1763344ea0d",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:40:54.352503",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:41:09,353 - INFO - Processing dataset 8/147: da7a41d4-00a5-4c19-bb16-b107e56c9db4
# 2025-07-17 15:41:09,353 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/da7a41d4-00a5-4c19-bb16-b107e56c9db4/datasources with params: None (Attempt 1)
# 2025-07-17 15:41:09,535 - INFO - Response status: 200
# 2025-07-17 15:41:09,536 - INFO - Response contains 1 datasources
# 2025-07-17 15:41:09,538 - INFO - Found 1 datasources for dataset da7a41d4-00a5-4c19-bb16-b107e56c9db4
# 2025-07-17 15:41:09,539 - INFO - Sample datasource for dataset da7a41d4-00a5-4c19-bb16-b107e56c9db4: {
#   "dataset_id": "da7a41d4-00a5-4c19-bb16-b107e56c9db4",
#   "datasource_id": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:41:09.539225",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:41:24,539 - INFO - Processing dataset 9/147: 056d1649-e0e9-4386-b882-37188ed76b25
# 2025-07-17 15:41:24,540 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/056d1649-e0e9-4386-b882-37188ed76b25/datasources with params: None (Attempt 1)
# 2025-07-17 15:41:25,003 - INFO - Response status: 200
# 2025-07-17 15:41:25,003 - INFO - Response contains 3 datasources
# 2025-07-17 15:41:25,006 - INFO - Found 3 datasources for dataset 056d1649-e0e9-4386-b882-37188ed76b25
# 2025-07-17 15:41:25,006 - INFO - Sample datasource for dataset 056d1649-e0e9-4386-b882-37188ed76b25: {
#   "dataset_id": "056d1649-e0e9-4386-b882-37188ed76b25",
#   "datasource_id": "2dfba737-865c-404b-9ef7-a71a38f89d54",
#   "datasource_name": null,
#   "datasource_type": "AnalysisServices",
#   "gateway_id": "1c72182e-146a-4a10-8bb0-3c87aa65e68b",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:41:25.006788",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:41:40,007 - INFO - Processing dataset 10/147: 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23
# 2025-07-17 15:41:40,007 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/0c811ad1-3d5c-46fc-84a7-5d6cbe949e23/datasources with params: None (Attempt 1)
# 2025-07-17 15:41:40,171 - INFO - Response status: 200
# 2025-07-17 15:41:40,171 - INFO - Response contains 1 datasources
# 2025-07-17 15:41:40,173 - INFO - Found 1 datasources for dataset 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23
# 2025-07-17 15:41:40,173 - INFO - Sample datasource for dataset 0c811ad1-3d5c-46fc-84a7-5d6cbe949e23: {
#   "dataset_id": "0c811ad1-3d5c-46fc-84a7-5d6cbe949e23",
#   "datasource_id": "6a4737f6-9034-41ac-92a5-31166be56b4e",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "fde2b36d-72cb-446d-a62d-617b3df2299f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:41:40.173708",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:41:55,174 - INFO - Processing dataset 11/147: 424836a1-bf59-497c-8ac9-71fd3f92a1ee
# 2025-07-17 15:41:55,174 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/424836a1-bf59-497c-8ac9-71fd3f92a1ee/datasources with params: None (Attempt 1)
# 2025-07-17 15:41:55,443 - INFO - Response status: 200
# 2025-07-17 15:41:55,443 - INFO - Response contains 2 datasources
# 2025-07-17 15:41:55,445 - INFO - Found 2 datasources for dataset 424836a1-bf59-497c-8ac9-71fd3f92a1ee
# 2025-07-17 15:41:55,446 - INFO - Sample datasource for dataset 424836a1-bf59-497c-8ac9-71fd3f92a1ee: {
#   "dataset_id": "424836a1-bf59-497c-8ac9-71fd3f92a1ee",
#   "datasource_id": "2a71bed5-d154-4afe-a895-ca31ce0677f3",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "ab385dd9-c982-4fbb-9e8f-1ea09375e727",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:41:55.446166",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:42:10,446 - INFO - Processing dataset 12/147: f8b9a61f-406c-4d41-9922-d86ba9cd440b
# 2025-07-17 15:42:10,447 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/f8b9a61f-406c-4d41-9922-d86ba9cd440b/datasources with params: None (Attempt 1)
# 2025-07-17 15:42:10,854 - INFO - Response status: 200
# 2025-07-17 15:42:10,855 - INFO - Response contains 1 datasources
# 2025-07-17 15:42:10,857 - INFO - Found 1 datasources for dataset f8b9a61f-406c-4d41-9922-d86ba9cd440b
# 2025-07-17 15:42:10,858 - INFO - Sample datasource for dataset f8b9a61f-406c-4d41-9922-d86ba9cd440b: {
#   "dataset_id": "f8b9a61f-406c-4d41-9922-d86ba9cd440b",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:42:10.858206",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:42:25,858 - INFO - Processing dataset 13/147: 573fe815-1ca9-4f23-a22c-5ff74aa2a23a
# 2025-07-17 15:42:25,859 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/573fe815-1ca9-4f23-a22c-5ff74aa2a23a/datasources with params: None (Attempt 1)
# 2025-07-17 15:42:26,048 - INFO - Response status: 200
# 2025-07-17 15:42:26,048 - INFO - Response contains 1 datasources
# 2025-07-17 15:42:26,051 - INFO - Found 1 datasources for dataset 573fe815-1ca9-4f23-a22c-5ff74aa2a23a
# 2025-07-17 15:42:26,051 - INFO - Sample datasource for dataset 573fe815-1ca9-4f23-a22c-5ff74aa2a23a: {
#   "dataset_id": "573fe815-1ca9-4f23-a22c-5ff74aa2a23a",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:42:26.051913",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:42:41,052 - INFO - Processing dataset 14/147: b1944f6a-1dd1-4cc7-ba41-3175d730d10d
# 2025-07-17 15:42:41,053 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/b1944f6a-1dd1-4cc7-ba41-3175d730d10d/datasources with params: None (Attempt 1)
# 2025-07-17 15:42:41,225 - INFO - Response status: 200
# 2025-07-17 15:42:41,226 - INFO - Response contains 1 datasources
# 2025-07-17 15:42:41,227 - INFO - Found 1 datasources for dataset b1944f6a-1dd1-4cc7-ba41-3175d730d10d
# 2025-07-17 15:42:41,228 - INFO - Sample datasource for dataset b1944f6a-1dd1-4cc7-ba41-3175d730d10d: {
#   "dataset_id": "b1944f6a-1dd1-4cc7-ba41-3175d730d10d",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:42:41.228402",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:42:56,228 - INFO - Processing dataset 15/147: 590ce045-9441-438f-9b8b-761b7529ee36
# 2025-07-17 15:42:56,229 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/590ce045-9441-438f-9b8b-761b7529ee36/datasources with params: None (Attempt 1)
# 2025-07-17 15:42:56,404 - INFO - Response status: 200
# 2025-07-17 15:42:56,405 - INFO - Response contains 1 datasources
# 2025-07-17 15:42:56,407 - INFO - Found 1 datasources for dataset 590ce045-9441-438f-9b8b-761b7529ee36
# 2025-07-17 15:42:56,408 - INFO - Sample datasource for dataset 590ce045-9441-438f-9b8b-761b7529ee36: {
#   "dataset_id": "590ce045-9441-438f-9b8b-761b7529ee36",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:42:56.408540",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:43:11,409 - INFO - Processing dataset 16/147: b56d3b78-e2f0-4f1d-b010-737801884169
# 2025-07-17 15:43:11,409 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/b56d3b78-e2f0-4f1d-b010-737801884169/datasources with params: None (Attempt 1)
# 2025-07-17 15:43:11,567 - INFO - Response status: 200
# 2025-07-17 15:43:11,568 - INFO - Response contains 1 datasources
# 2025-07-17 15:43:11,570 - INFO - Found 1 datasources for dataset b56d3b78-e2f0-4f1d-b010-737801884169
# 2025-07-17 15:43:11,570 - INFO - Sample datasource for dataset b56d3b78-e2f0-4f1d-b010-737801884169: {
#   "dataset_id": "b56d3b78-e2f0-4f1d-b010-737801884169",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:43:11.570910",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:43:26,571 - INFO - Processing dataset 17/147: de487a1a-a878-4efb-b2fe-df46e68bf1ec
# 2025-07-17 15:43:26,572 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/de487a1a-a878-4efb-b2fe-df46e68bf1ec/datasources with params: None (Attempt 1)
# 2025-07-17 15:43:26,732 - INFO - Response status: 200
# 2025-07-17 15:43:26,732 - INFO - Response contains 1 datasources
# 2025-07-17 15:43:26,734 - INFO - Found 1 datasources for dataset de487a1a-a878-4efb-b2fe-df46e68bf1ec
# 2025-07-17 15:43:26,735 - INFO - Sample datasource for dataset de487a1a-a878-4efb-b2fe-df46e68bf1ec: {
#   "dataset_id": "de487a1a-a878-4efb-b2fe-df46e68bf1ec",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:43:26.735480",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:43:41,735 - INFO - Processing dataset 18/147: 962e45cd-dd27-4d58-ae93-894e53850534
# 2025-07-17 15:43:41,736 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/962e45cd-dd27-4d58-ae93-894e53850534/datasources with params: None (Attempt 1)
# 2025-07-17 15:43:41,974 - INFO - Response status: 200
# 2025-07-17 15:43:41,974 - INFO - Response contains 1 datasources
# 2025-07-17 15:43:41,976 - INFO - Found 1 datasources for dataset 962e45cd-dd27-4d58-ae93-894e53850534
# 2025-07-17 15:43:41,976 - INFO - Sample datasource for dataset 962e45cd-dd27-4d58-ae93-894e53850534: {
#   "dataset_id": "962e45cd-dd27-4d58-ae93-894e53850534",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:43:41.976959",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:43:56,977 - INFO - Processing dataset 19/147: 42018153-9894-4995-be43-30281fa8675b
# 2025-07-17 15:43:56,977 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/42018153-9894-4995-be43-30281fa8675b/datasources with params: None (Attempt 1)
# 2025-07-17 15:43:57,138 - INFO - Response status: 200
# 2025-07-17 15:43:57,139 - INFO - Response contains 1 datasources
# 2025-07-17 15:43:57,140 - INFO - Found 1 datasources for dataset 42018153-9894-4995-be43-30281fa8675b
# 2025-07-17 15:43:57,141 - INFO - Sample datasource for dataset 42018153-9894-4995-be43-30281fa8675b: {
#   "dataset_id": "42018153-9894-4995-be43-30281fa8675b",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:43:57.141283",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:44:12,141 - INFO - Processing dataset 20/147: 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79
# 2025-07-17 15:44:12,142 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/2546fffd-a5a2-4bfe-86fd-dbc2bca36a79/datasources with params: None (Attempt 1)
# 2025-07-17 15:44:12,471 - INFO - Response status: 200
# 2025-07-17 15:44:12,471 - INFO - Response contains 1 datasources
# 2025-07-17 15:44:12,474 - INFO - Found 1 datasources for dataset 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79
# 2025-07-17 15:44:12,474 - INFO - Sample datasource for dataset 2546fffd-a5a2-4bfe-86fd-dbc2bca36a79: {
#   "dataset_id": "2546fffd-a5a2-4bfe-86fd-dbc2bca36a79",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:44:12.474547",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:44:27,475 - INFO - Processing dataset 21/147: 36d80fa5-819d-40e4-bb2f-d146976e5ba9
# 2025-07-17 15:44:27,475 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/36d80fa5-819d-40e4-bb2f-d146976e5ba9/datasources with params: None (Attempt 1)
# 2025-07-17 15:44:27,701 - INFO - Response status: 200
# 2025-07-17 15:44:27,702 - INFO - Response contains 1 datasources
# 2025-07-17 15:44:27,704 - INFO - Found 1 datasources for dataset 36d80fa5-819d-40e4-bb2f-d146976e5ba9
# 2025-07-17 15:44:27,705 - INFO - Sample datasource for dataset 36d80fa5-819d-40e4-bb2f-d146976e5ba9: {
#   "dataset_id": "36d80fa5-819d-40e4-bb2f-d146976e5ba9",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:44:27.705070",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:44:42,706 - INFO - Processing dataset 22/147: 0d46bdeb-cef4-42f9-8d60-080f654f525f
# 2025-07-17 15:44:42,706 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/0d46bdeb-cef4-42f9-8d60-080f654f525f/datasources with params: None (Attempt 1)
# 2025-07-17 15:44:42,922 - INFO - Response status: 200
# 2025-07-17 15:44:42,923 - INFO - Response contains 1 datasources
# 2025-07-17 15:44:42,925 - INFO - Found 1 datasources for dataset 0d46bdeb-cef4-42f9-8d60-080f654f525f
# 2025-07-17 15:44:42,925 - INFO - Sample datasource for dataset 0d46bdeb-cef4-42f9-8d60-080f654f525f: {
#   "dataset_id": "0d46bdeb-cef4-42f9-8d60-080f654f525f",
#   "datasource_id": "2248100d-cffc-4bb0-b3de-5a126f4d0435",
#   "datasource_name": null,
#   "datasource_type": "SharePointList",
#   "gateway_id": "b37d63a2-2f65-4488-bde6-52896ac0b01c",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:44:42.925721",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:44:57,926 - INFO - Processing dataset 23/147: 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f
# 2025-07-17 15:44:57,926 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/1edc8fc0-5e64-4fbc-ab20-6a04a28e087f/datasources with params: None (Attempt 1)
# 2025-07-17 15:44:58,184 - INFO - Response status: 200
# 2025-07-17 15:44:58,185 - INFO - Response contains 12 datasources
# 2025-07-17 15:44:58,187 - INFO - Found 12 datasources for dataset 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f
# 2025-07-17 15:44:58,188 - INFO - Sample datasource for dataset 1edc8fc0-5e64-4fbc-ab20-6a04a28e087f: {
#   "dataset_id": "1edc8fc0-5e64-4fbc-ab20-6a04a28e087f",
#   "datasource_id": "64967d4a-941d-44b1-911d-8410724681c8",
#   "datasource_name": null,
#   "datasource_type": "SharePointList",
#   "gateway_id": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:44:58.188105",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:45:13,188 - INFO - Processing dataset 24/147: b504664b-07a6-4d5f-9af0-f235fc6d7f0c
# 2025-07-17 15:45:13,189 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/b504664b-07a6-4d5f-9af0-f235fc6d7f0c/datasources with params: None (Attempt 1)
# 2025-07-17 15:45:13,440 - INFO - Response status: 200
# 2025-07-17 15:45:13,440 - INFO - Response contains 1 datasources
# 2025-07-17 15:45:13,442 - INFO - Found 1 datasources for dataset b504664b-07a6-4d5f-9af0-f235fc6d7f0c
# 2025-07-17 15:45:13,442 - INFO - Sample datasource for dataset b504664b-07a6-4d5f-9af0-f235fc6d7f0c: {
#   "dataset_id": "b504664b-07a6-4d5f-9af0-f235fc6d7f0c",
#   "datasource_id": "e38e8368-7ec8-4b1c-9fab-843ffe12dd84",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "67ae466d-68ca-4710-8430-bf7567fd1f9b",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:45:13.442814",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:45:28,443 - INFO - Processing dataset 25/147: c1ed3070-34ea-4f0d-97f6-1d8220b03675
# 2025-07-17 15:45:28,443 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/c1ed3070-34ea-4f0d-97f6-1d8220b03675/datasources with params: None (Attempt 1)
# 2025-07-17 15:45:28,667 - INFO - Response status: 200
# 2025-07-17 15:45:28,667 - INFO - Response contains 1 datasources
# 2025-07-17 15:45:28,669 - INFO - Found 1 datasources for dataset c1ed3070-34ea-4f0d-97f6-1d8220b03675
# 2025-07-17 15:45:28,669 - INFO - Sample datasource for dataset c1ed3070-34ea-4f0d-97f6-1d8220b03675: {
#   "dataset_id": "c1ed3070-34ea-4f0d-97f6-1d8220b03675",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:45:28.669606",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:45:43,670 - INFO - Processing dataset 26/147: 537257d3-9f04-4a6a-98d5-12dded57ce41
# 2025-07-17 15:45:43,670 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/537257d3-9f04-4a6a-98d5-12dded57ce41/datasources with params: None (Attempt 1)
# 2025-07-17 15:45:43,845 - INFO - Response status: 200
# 2025-07-17 15:45:43,846 - INFO - Response contains 1 datasources
# 2025-07-17 15:45:43,848 - INFO - Found 1 datasources for dataset 537257d3-9f04-4a6a-98d5-12dded57ce41
# 2025-07-17 15:45:43,849 - INFO - Sample datasource for dataset 537257d3-9f04-4a6a-98d5-12dded57ce41: {
#   "dataset_id": "537257d3-9f04-4a6a-98d5-12dded57ce41",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:45:43.849316",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:45:58,850 - INFO - Processing dataset 27/147: 8f043eb2-8622-493d-91f6-ddd1c07e3dc2
# 2025-07-17 15:45:58,850 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/8f043eb2-8622-493d-91f6-ddd1c07e3dc2/datasources with params: None (Attempt 1)
# 2025-07-17 15:45:59,117 - INFO - Response status: 200
# 2025-07-17 15:45:59,117 - INFO - Response contains 1 datasources
# 2025-07-17 15:45:59,120 - INFO - Found 1 datasources for dataset 8f043eb2-8622-493d-91f6-ddd1c07e3dc2
# 2025-07-17 15:45:59,120 - INFO - Sample datasource for dataset 8f043eb2-8622-493d-91f6-ddd1c07e3dc2: {
#   "dataset_id": "8f043eb2-8622-493d-91f6-ddd1c07e3dc2",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:45:59.120777",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:46:14,121 - INFO - Processing dataset 28/147: 77791f59-a4db-49d4-b6e2-d17f67f0c568
# 2025-07-17 15:46:14,121 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/77791f59-a4db-49d4-b6e2-d17f67f0c568/datasources with params: None (Attempt 1)
# 2025-07-17 15:46:14,439 - INFO - Response status: 200
# 2025-07-17 15:46:14,439 - INFO - Response contains 1 datasources
# 2025-07-17 15:46:14,441 - INFO - Found 1 datasources for dataset 77791f59-a4db-49d4-b6e2-d17f67f0c568
# 2025-07-17 15:46:14,442 - INFO - Sample datasource for dataset 77791f59-a4db-49d4-b6e2-d17f67f0c568: {
#   "dataset_id": "77791f59-a4db-49d4-b6e2-d17f67f0c568",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:46:14.442479",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:46:29,442 - INFO - Processing dataset 29/147: fb89ec88-4b55-44ab-933a-4962ac10946e
# 2025-07-17 15:46:29,443 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/fb89ec88-4b55-44ab-933a-4962ac10946e/datasources with params: None (Attempt 1)
# 2025-07-17 15:46:29,704 - INFO - Response status: 200
# 2025-07-17 15:46:29,705 - INFO - Response contains 1 datasources
# 2025-07-17 15:46:29,707 - INFO - Found 1 datasources for dataset fb89ec88-4b55-44ab-933a-4962ac10946e
# 2025-07-17 15:46:29,707 - INFO - Sample datasource for dataset fb89ec88-4b55-44ab-933a-4962ac10946e: {
#   "dataset_id": "fb89ec88-4b55-44ab-933a-4962ac10946e",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:46:29.707788",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:46:44,708 - INFO - Processing dataset 30/147: 65ff101e-fe36-480a-a7e0-c2866d7aa4a2
# 2025-07-17 15:46:44,709 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/65ff101e-fe36-480a-a7e0-c2866d7aa4a2/datasources with params: None (Attempt 1)
# 2025-07-17 15:46:45,005 - INFO - Response status: 200
# 2025-07-17 15:46:45,006 - INFO - Response contains 1 datasources
# 2025-07-17 15:46:45,008 - INFO - Found 1 datasources for dataset 65ff101e-fe36-480a-a7e0-c2866d7aa4a2
# 2025-07-17 15:46:45,009 - INFO - Sample datasource for dataset 65ff101e-fe36-480a-a7e0-c2866d7aa4a2: {
#   "dataset_id": "65ff101e-fe36-480a-a7e0-c2866d7aa4a2",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:46:45.008991",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:47:00,009 - INFO - Processing dataset 31/147: 5585c24a-d2fb-4a19-afaf-b85e55dfe92f
# 2025-07-17 15:47:00,010 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/5585c24a-d2fb-4a19-afaf-b85e55dfe92f/datasources with params: None (Attempt 1)
# 2025-07-17 15:47:00,328 - INFO - Response status: 200
# 2025-07-17 15:47:00,329 - INFO - Response contains 1 datasources
# 2025-07-17 15:47:00,332 - INFO - Found 1 datasources for dataset 5585c24a-d2fb-4a19-afaf-b85e55dfe92f
# 2025-07-17 15:47:00,332 - INFO - Sample datasource for dataset 5585c24a-d2fb-4a19-afaf-b85e55dfe92f: {
#   "dataset_id": "5585c24a-d2fb-4a19-afaf-b85e55dfe92f",
#   "datasource_id": "0eba986f-6273-4a9b-9083-ee0813f838a2",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "96262afb-757f-4d58-a258-b8faddca905f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:47:00.332747",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:47:15,333 - INFO - Processing dataset 32/147: f7d8423e-36ce-419d-971d-6d56b683a190
# 2025-07-17 15:47:15,333 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/f7d8423e-36ce-419d-971d-6d56b683a190/datasources with params: None (Attempt 1)
# 2025-07-17 15:47:15,502 - INFO - Response status: 200
# 2025-07-17 15:47:15,503 - INFO - Response contains 1 datasources
# 2025-07-17 15:47:15,505 - INFO - Found 1 datasources for dataset f7d8423e-36ce-419d-971d-6d56b683a190
# 2025-07-17 15:47:15,505 - INFO - Sample datasource for dataset f7d8423e-36ce-419d-971d-6d56b683a190: {
#   "dataset_id": "f7d8423e-36ce-419d-971d-6d56b683a190",
#   "datasource_id": "cfcda6ca-6bbc-4a9a-bab4-5e827b92aab3",
#   "datasource_name": null,
#   "datasource_type": "SharePointList",
#   "gateway_id": "67ae466d-68ca-4710-8430-bf7567fd1f9b",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:47:15.505334",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:47:30,505 - INFO - Processing dataset 33/147: f3aa5d8f-941a-4716-8bdb-59ad8c984a15
# 2025-07-17 15:47:30,506 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/f3aa5d8f-941a-4716-8bdb-59ad8c984a15/datasources with params: None (Attempt 1)
# 2025-07-17 15:47:30,670 - INFO - Response status: 200
# 2025-07-17 15:47:30,670 - INFO - Response contains 1 datasources
# 2025-07-17 15:47:30,672 - INFO - Found 1 datasources for dataset f3aa5d8f-941a-4716-8bdb-59ad8c984a15
# 2025-07-17 15:47:30,673 - INFO - Sample datasource for dataset f3aa5d8f-941a-4716-8bdb-59ad8c984a15: {
#   "dataset_id": "f3aa5d8f-941a-4716-8bdb-59ad8c984a15",
#   "datasource_id": "c799d109-77bc-4c09-a6fd-723fe21448e8",
#   "datasource_name": null,
#   "datasource_type": "SharePointList",
#   "gateway_id": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:47:30.672992",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:47:45,673 - INFO - Processing dataset 34/147: 6fe68660-b156-4070-998e-e6bbbec86732
# 2025-07-17 15:47:45,673 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/6fe68660-b156-4070-998e-e6bbbec86732/datasources with params: None (Attempt 1)
# 2025-07-17 15:47:45,842 - INFO - Response status: 200
# 2025-07-17 15:47:45,843 - INFO - Response contains 1 datasources
# 2025-07-17 15:47:45,845 - INFO - Found 1 datasources for dataset 6fe68660-b156-4070-998e-e6bbbec86732
# 2025-07-17 15:47:45,845 - INFO - Sample datasource for dataset 6fe68660-b156-4070-998e-e6bbbec86732: {
#   "dataset_id": "6fe68660-b156-4070-998e-e6bbbec86732",
#   "datasource_id": "195612a5-2b61-494d-92be-62159e2ba832",
#   "datasource_name": null,
#   "datasource_type": "SharePointList",
#   "gateway_id": "ccd5560d-6ea9-4bb2-a5c0-6be22917dd4a",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:47:45.845945",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:48:00,846 - INFO - Processing dataset 35/147: 01ff15a8-6f79-4a8c-bf5b-5bcd82023883
# 2025-07-17 15:48:00,847 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/01ff15a8-6f79-4a8c-bf5b-5bcd82023883/datasources with params: None (Attempt 1)
# 2025-07-17 15:48:01,085 - INFO - Response status: 200
# 2025-07-17 15:48:01,085 - INFO - Response contains 1 datasources
# 2025-07-17 15:48:01,088 - INFO - Found 1 datasources for dataset 01ff15a8-6f79-4a8c-bf5b-5bcd82023883
# 2025-07-17 15:48:01,088 - INFO - Sample datasource for dataset 01ff15a8-6f79-4a8c-bf5b-5bcd82023883: {
#   "dataset_id": "01ff15a8-6f79-4a8c-bf5b-5bcd82023883",
#   "datasource_id": "6270f3eb-9cd1-4028-b4eb-25713ef9c5e2",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "7e508ae6-3f91-43a5-ba20-e24caa4b7fd5",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:48:01.088348",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:48:16,089 - INFO - Processing dataset 36/147: 67f9b78b-5659-4888-a1a7-67709d1f3d07
# 2025-07-17 15:48:16,089 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/67f9b78b-5659-4888-a1a7-67709d1f3d07/datasources with params: None (Attempt 1)
# 2025-07-17 15:48:16,247 - INFO - Response status: 200
# 2025-07-17 15:48:16,247 - INFO - Response contains 1 datasources
# 2025-07-17 15:48:16,249 - INFO - Found 1 datasources for dataset 67f9b78b-5659-4888-a1a7-67709d1f3d07
# 2025-07-17 15:48:16,250 - INFO - Sample datasource for dataset 67f9b78b-5659-4888-a1a7-67709d1f3d07: {
#   "dataset_id": "67f9b78b-5659-4888-a1a7-67709d1f3d07",
#   "datasource_id": "5596b826-5bd5-482b-b2e5-87a77bfc7941",
#   "datasource_name": null,
#   "datasource_type": "AnalysisServices",
#   "gateway_id": "ab385dd9-c982-4fbb-9e8f-1ea09375e727",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:48:16.250352",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:48:31,250 - INFO - Processing dataset 37/147: 78d2f263-333a-4d68-8fd8-8c5c58937844
# 2025-07-17 15:48:31,251 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/78d2f263-333a-4d68-8fd8-8c5c58937844/datasources with params: None (Attempt 1)
# 2025-07-17 15:48:31,539 - INFO - Response status: 200
# 2025-07-17 15:48:31,540 - INFO - Response contains 1 datasources
# 2025-07-17 15:48:31,541 - INFO - Found 1 datasources for dataset 78d2f263-333a-4d68-8fd8-8c5c58937844
# 2025-07-17 15:48:31,542 - INFO - Sample datasource for dataset 78d2f263-333a-4d68-8fd8-8c5c58937844: {
#   "dataset_id": "78d2f263-333a-4d68-8fd8-8c5c58937844",
#   "datasource_id": "682cbdf5-dd6b-4a13-86fc-ec2047ea3288",
#   "datasource_name": null,
#   "datasource_type": "Oracle",
#   "gateway_id": "47d3ea9b-fb98-4e41-8516-2aa7c02b7eca",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:48:31.542368",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:48:46,542 - INFO - Processing dataset 38/147: c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-17 15:48:46,543 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/c053b33b-5241-42c2-8785-65a1b337e7fe/datasources with params: None (Attempt 1)
# 2025-07-17 15:48:46,688 - INFO - Response status: 200
# 2025-07-17 15:48:46,689 - INFO - Response contains 0 datasources
# 2025-07-17 15:48:46,691 - INFO - No datasources found for dataset c053b33b-5241-42c2-8785-65a1b337e7fe
# 2025-07-17 15:49:01,691 - INFO - Processing dataset 39/147: 3842cc82-7522-4d6d-8bca-627a4a0dc99b
# 2025-07-17 15:49:01,692 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/3842cc82-7522-4d6d-8bca-627a4a0dc99b/datasources with params: None (Attempt 1)
# 2025-07-17 15:49:01,885 - INFO - Response status: 200
# 2025-07-17 15:49:01,886 - INFO - Response contains 0 datasources
# 2025-07-17 15:49:01,888 - INFO - No datasources found for dataset 3842cc82-7522-4d6d-8bca-627a4a0dc99b
# 2025-07-17 15:49:16,889 - INFO - Processing dataset 40/147: 8d9beb02-7a15-400a-912f-558f0c07600e
# 2025-07-17 15:49:16,889 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/8d9beb02-7a15-400a-912f-558f0c07600e/datasources with params: None (Attempt 1)
# 2025-07-17 15:49:17,027 - INFO - Response status: 200
# 2025-07-17 15:49:17,028 - INFO - Response contains 0 datasources
# 2025-07-17 15:49:17,030 - INFO - No datasources found for dataset 8d9beb02-7a15-400a-912f-558f0c07600e
# 2025-07-17 15:49:32,031 - INFO - Processing dataset 41/147: 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-17 15:49:32,031 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/48d932f8-8b64-4b34-a67c-e08de77d9c3b/datasources with params: None (Attempt 1)
# 2025-07-17 15:49:32,259 - INFO - Response status: 200
# 2025-07-17 15:49:32,260 - INFO - Response contains 0 datasources
# 2025-07-17 15:49:32,262 - INFO - No datasources found for dataset 48d932f8-8b64-4b34-a67c-e08de77d9c3b
# 2025-07-17 15:49:47,263 - INFO - Processing dataset 42/147: 71b51c6b-af32-47d3-8f38-ce9f7cedffc9
# 2025-07-17 15:49:47,264 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/71b51c6b-af32-47d3-8f38-ce9f7cedffc9/datasources with params: None (Attempt 1)
# 2025-07-17 15:49:47,423 - INFO - Response status: 200
# 2025-07-17 15:49:47,423 - INFO - Response contains 0 datasources
# 2025-07-17 15:49:47,425 - INFO - No datasources found for dataset 71b51c6b-af32-47d3-8f38-ce9f7cedffc9
# 2025-07-17 15:50:02,426 - INFO - Processing dataset 43/147: edc7ea46-a68b-47ee-835e-1554aa832d32
# 2025-07-17 15:50:02,427 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/edc7ea46-a68b-47ee-835e-1554aa832d32/datasources with params: None (Attempt 1)
# 2025-07-17 15:50:02,583 - INFO - Response status: 200
# 2025-07-17 15:50:02,583 - INFO - Response contains 0 datasources
# 2025-07-17 15:50:02,587 - INFO - No datasources found for dataset edc7ea46-a68b-47ee-835e-1554aa832d32
# 2025-07-17 15:50:17,587 - INFO - Processing dataset 44/147: 793c10f9-5f42-4cb4-8f24-4d5d3dc141fc
# 2025-07-17 15:50:17,588 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/793c10f9-5f42-4cb4-8f24-4d5d3dc141fc/datasources with params: None (Attempt 1)
# 2025-07-17 15:50:17,880 - INFO - Response status: 200
# 2025-07-17 15:50:17,880 - INFO - Response contains 0 datasources
# 2025-07-17 15:50:17,882 - INFO - No datasources found for dataset 793c10f9-5f42-4cb4-8f24-4d5d3dc141fc
# 2025-07-17 15:50:32,883 - INFO - Processing dataset 45/147: 9b8714f3-cc90-4d8e-84b4-f8cbbd681e36
# 2025-07-17 15:50:32,883 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/9b8714f3-cc90-4d8e-84b4-f8cbbd681e36/datasources with params: None (Attempt 1)
# 2025-07-17 15:50:33,025 - INFO - Response status: 200
# 2025-07-17 15:50:33,025 - INFO - Response contains 0 datasources
# 2025-07-17 15:50:33,027 - INFO - No datasources found for dataset 9b8714f3-cc90-4d8e-84b4-f8cbbd681e36
# 2025-07-17 15:50:48,028 - INFO - Processing dataset 46/147: d79bc5c0-8d66-4834-814c-da67438bc135
# 2025-07-17 15:50:48,028 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/d79bc5c0-8d66-4834-814c-da67438bc135/datasources with params: None (Attempt 1)
# 2025-07-17 15:50:48,360 - INFO - Response status: 200
# 2025-07-17 15:50:48,360 - INFO - Response contains 0 datasources
# 2025-07-17 15:50:48,363 - INFO - No datasources found for dataset d79bc5c0-8d66-4834-814c-da67438bc135
# 2025-07-17 15:51:03,363 - INFO - Processing dataset 47/147: 3e6bd48b-9e3b-4811-90af-b49ee59a30e6
# 2025-07-17 15:51:03,364 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/3e6bd48b-9e3b-4811-90af-b49ee59a30e6/datasources with params: None (Attempt 1)
# 2025-07-17 15:51:03,577 - INFO - Response status: 200
# 2025-07-17 15:51:03,578 - INFO - Response contains 0 datasources
# 2025-07-17 15:51:03,580 - INFO - No datasources found for dataset 3e6bd48b-9e3b-4811-90af-b49ee59a30e6
# 2025-07-17 15:51:18,580 - INFO - Processing dataset 48/147: ae574855-449a-4fa3-9dbe-94c73e9a674c
# 2025-07-17 15:51:18,581 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/ae574855-449a-4fa3-9dbe-94c73e9a674c/datasources with params: None (Attempt 1)
# 2025-07-17 15:51:18,819 - INFO - Response status: 200
# 2025-07-17 15:51:18,820 - INFO - Response contains 0 datasources
# 2025-07-17 15:51:18,822 - INFO - No datasources found for dataset ae574855-449a-4fa3-9dbe-94c73e9a674c
# 2025-07-17 15:51:33,823 - INFO - Processing dataset 49/147: 22c11e64-7e29-4376-bb3c-5aa9234a1463
# 2025-07-17 15:51:33,824 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/22c11e64-7e29-4376-bb3c-5aa9234a1463/datasources with params: None (Attempt 1)
# 2025-07-17 15:51:33,965 - INFO - Response status: 200
# 2025-07-17 15:51:33,965 - INFO - Response contains 0 datasources
# 2025-07-17 15:51:33,967 - INFO - No datasources found for dataset 22c11e64-7e29-4376-bb3c-5aa9234a1463
# 2025-07-17 15:51:48,968 - INFO - Processing dataset 50/147: e1a39240-93f0-43df-bb69-8595fbd76954
# 2025-07-17 15:51:48,968 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/e1a39240-93f0-43df-bb69-8595fbd76954/datasources with params: None (Attempt 1)
# 2025-07-17 15:51:49,143 - INFO - Response status: 200
# 2025-07-17 15:51:49,144 - INFO - Response contains 0 datasources
# 2025-07-17 15:51:49,146 - INFO - No datasources found for dataset e1a39240-93f0-43df-bb69-8595fbd76954
# 2025-07-17 15:51:49,146 - INFO - Batch 1 completed. Found 51 datasources total
# 2025-07-17 15:51:49,146 - INFO - Waiting 30 seconds before next batch...
# 2025-07-17 15:52:19,147 - INFO - Processing batch 2/3 (50 datasets)
# 2025-07-17 15:52:19,148 - INFO - Processing dataset 51/147: fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-17 15:52:19,148 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/fe1918d6-0a63-4b30-9208-afc8e5c1d5df/datasources with params: None (Attempt 1)
# 2025-07-17 15:52:19,335 - INFO - Response status: 200
# 2025-07-17 15:52:19,336 - INFO - Response contains 15 datasources
# 2025-07-17 15:52:19,338 - INFO - Found 15 datasources for dataset fe1918d6-0a63-4b30-9208-afc8e5c1d5df
# 2025-07-17 15:52:19,339 - INFO - Sample datasource for dataset fe1918d6-0a63-4b30-9208-afc8e5c1d5df: {
#   "dataset_id": "fe1918d6-0a63-4b30-9208-afc8e5c1d5df",
#   "datasource_id": "fe1af4fe-6046-46f7-be68-71961d8aff0b",
#   "datasource_name": null,
#   "datasource_type": "File",
#   "gateway_id": "a9ef46b6-b653-474e-ad63-a58c7287c40c",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:52:19.339559",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:52:34,340 - INFO - Processing dataset 52/147: b983dd24-25e4-41e6-9949-016001c6ca09
# 2025-07-17 15:52:34,341 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/b983dd24-25e4-41e6-9949-016001c6ca09/datasources with params: None (Attempt 1)
# 2025-07-17 15:52:34,631 - INFO - Response status: 200
# 2025-07-17 15:52:34,631 - INFO - Response contains 9 datasources
# 2025-07-17 15:52:34,633 - INFO - Found 9 datasources for dataset b983dd24-25e4-41e6-9949-016001c6ca09
# 2025-07-17 15:52:34,634 - INFO - Sample datasource for dataset b983dd24-25e4-41e6-9949-016001c6ca09: {
#   "dataset_id": "b983dd24-25e4-41e6-9949-016001c6ca09",
#   "datasource_id": "4bf3ff49-c023-4778-acce-9bc0ddbe666d",
#   "datasource_name": null,
#   "datasource_type": "File",
#   "gateway_id": "fdc3c190-f647-4b65-9487-5af5a1646da8",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:52:34.634520",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:52:49,634 - INFO - Processing dataset 53/147: 8c982903-1747-4644-a6ca-5377b353e7dd
# 2025-07-17 15:52:49,635 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/8c982903-1747-4644-a6ca-5377b353e7dd/datasources with params: None (Attempt 1)
# 2025-07-17 15:52:49,867 - INFO - Response status: 200
# 2025-07-17 15:52:49,868 - INFO - Response contains 1 datasources
# 2025-07-17 15:52:49,870 - INFO - Found 1 datasources for dataset 8c982903-1747-4644-a6ca-5377b353e7dd
# 2025-07-17 15:52:49,871 - INFO - Sample datasource for dataset 8c982903-1747-4644-a6ca-5377b353e7dd: {
#   "dataset_id": "8c982903-1747-4644-a6ca-5377b353e7dd",
#   "datasource_id": "6a4737f6-9034-41ac-92a5-31166be56b4e",
#   "datasource_name": null,
#   "datasource_type": "Extension",
#   "gateway_id": "fde2b36d-72cb-446d-a62d-617b3df2299f",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 15:52:49.871185",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 15:53:04,871 - INFO - Processing dataset 54/147: 78869f44-55e5-4bda-92c2-18e0e71e1891
# 2025-07-17 15:53:04,872 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/78869f44-55e5-4bda-92c2-18e0e71e1891/datasources with params: None (Attempt 1)
# 2025-07-17 15:53:05,177 - INFO - Response status: 200
# 2025-07-17 15:53:05,178 - INFO - Response contains 9 datasources
# 2025-07-17 15:53:05,180 - INFO - Found 9 datasources for dataset 78869f44-55e5-4bda-92c2-18e0e71e1891
# 2025-07-17 15:53:05,181 - INFO - Sample datasource for dataset 78869f44-55e5-4bda-92c2-18e0e71e1891: {
#   "dataset_id": "78869f44-55e5-4bda-92c2-18e0e71e1891",
#   "datasource_id": "4bf3ff49-c023-4778-acce-9bc0ddbe666d",
# ...
# 2025-07-17 16:13:41,894 - INFO - Response status: 200
# 2025-07-17 16:13:41,895 - INFO - Response contains 1 datasources
# 2025-07-17 16:13:41,897 - INFO - Found 1 datasources for dataset 83e20066-b240-40cf-929a-9bdc55db4f00
# 2025-07-17 16:13:41,898 - INFO - Sample datasource for dataset 83e20066-b240-40cf-929a-9bdc55db4f00: {
#   "dataset_id": "83e20066-b240-40cf-929a-9bdc55db4f00",
#   "datasource_id": "e2c09680-86e1-4147-8c11-97e5ce134f28",
#   "datasource_name": null,
#   "datasource_type": "Sql",
#   "gateway_id": "c5d345ff-fe30-4f0d-80ff-1fd86e2fe866",
#   "connection_string": null,
#   "extraction_timestamp": "2025-07-17 16:13:41.898326",
#   "extraction_batch_id": "da1dd779-45ba-42f0-bf98-49a53d0d516c"
# }
# 2025-07-17 16:13:56,898 - INFO - Processing dataset 135/147: 06787f82-aee4-45a2-ae09-7c7a87563f09
# 2025-07-17 16:13:56,899 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/06787f82-aee4-45a2-ae09-7c7a87563f09/datasources with params: None (Attempt 1)
# 2025-07-17 16:13:57,016 - INFO - Response status: 403
# 2025-07-17 16:13:57,016 - WARNING - Insufficient permissions for dataset: /admin/datasets/06787f82-aee4-45a2-ae09-7c7a87563f09/datasources
# 2025-07-17 16:13:57,019 - INFO - No datasources found for dataset 06787f82-aee4-45a2-ae09-7c7a87563f09
# 2025-07-17 16:14:12,019 - INFO - Processing dataset 136/147: 1ce0a85b-ced7-40c7-9ff6-9d3540a22e29
# 2025-07-17 16:14:12,020 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/1ce0a85b-ced7-40c7-9ff6-9d3540a22e29/datasources with params: None (Attempt 1)
# 2025-07-17 16:14:12,192 - INFO - Response status: 403
# 2025-07-17 16:14:12,192 - WARNING - Insufficient permissions for dataset: /admin/datasets/1ce0a85b-ced7-40c7-9ff6-9d3540a22e29/datasources
# 2025-07-17 16:14:12,194 - INFO - No datasources found for dataset 1ce0a85b-ced7-40c7-9ff6-9d3540a22e29
# 2025-07-17 16:14:27,195 - INFO - Processing dataset 137/147: ed700c9a-8b55-411d-94d3-771cb74951a6
# 2025-07-17 16:14:27,195 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/ed700c9a-8b55-411d-94d3-771cb74951a6/datasources with params: None (Attempt 1)
# 2025-07-17 16:14:27,280 - INFO - Response status: 403
# 2025-07-17 16:14:27,281 - WARNING - Insufficient permissions for dataset: /admin/datasets/ed700c9a-8b55-411d-94d3-771cb74951a6/datasources
# 2025-07-17 16:14:27,283 - INFO - No datasources found for dataset ed700c9a-8b55-411d-94d3-771cb74951a6
# 2025-07-17 16:14:42,284 - INFO - Processing dataset 138/147: cec3c9ed-ba07-4e3b-a426-5ebd621696e4
# 2025-07-17 16:14:42,285 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/cec3c9ed-ba07-4e3b-a426-5ebd621696e4/datasources with params: None (Attempt 1)
# 2025-07-17 16:14:42,362 - INFO - Response status: 403
# 2025-07-17 16:14:42,362 - WARNING - Insufficient permissions for dataset: /admin/datasets/cec3c9ed-ba07-4e3b-a426-5ebd621696e4/datasources
# 2025-07-17 16:14:42,365 - INFO - No datasources found for dataset cec3c9ed-ba07-4e3b-a426-5ebd621696e4
# 2025-07-17 16:14:57,365 - INFO - Processing dataset 139/147: 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-17 16:14:57,366 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/8d248811-c245-4a94-b409-c508f5e00677/datasources with params: None (Attempt 1)
# 2025-07-17 16:14:57,447 - INFO - Response status: 403
# 2025-07-17 16:14:57,447 - WARNING - Insufficient permissions for dataset: /admin/datasets/8d248811-c245-4a94-b409-c508f5e00677/datasources
# 2025-07-17 16:14:57,449 - INFO - No datasources found for dataset 8d248811-c245-4a94-b409-c508f5e00677
# 2025-07-17 16:15:12,450 - INFO - Processing dataset 140/147: f5247c0a-f880-4c93-9f4e-3388e140dd9d
# 2025-07-17 16:15:12,450 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/f5247c0a-f880-4c93-9f4e-3388e140dd9d/datasources with params: None (Attempt 1)
# 2025-07-17 16:15:12,519 - INFO - Response status: 403
# 2025-07-17 16:15:12,520 - WARNING - Insufficient permissions for dataset: /admin/datasets/f5247c0a-f880-4c93-9f4e-3388e140dd9d/datasources
# 2025-07-17 16:15:12,523 - INFO - No datasources found for dataset f5247c0a-f880-4c93-9f4e-3388e140dd9d
# 2025-07-17 16:15:27,524 - INFO - Processing dataset 141/147: f6f59c9e-6893-490f-9629-b1cfd42c2718
# 2025-07-17 16:15:27,524 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/f6f59c9e-6893-490f-9629-b1cfd42c2718/datasources with params: None (Attempt 1)
# 2025-07-17 16:15:27,590 - INFO - Response status: 403
# 2025-07-17 16:15:27,591 - WARNING - Insufficient permissions for dataset: /admin/datasets/f6f59c9e-6893-490f-9629-b1cfd42c2718/datasources
# 2025-07-17 16:15:27,593 - INFO - No datasources found for dataset f6f59c9e-6893-490f-9629-b1cfd42c2718
# 2025-07-17 16:15:42,593 - INFO - Processing dataset 142/147: 4f3e3bbc-aa78-4582-b05a-4367d4d0b361
# 2025-07-17 16:15:42,594 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/4f3e3bbc-aa78-4582-b05a-4367d4d0b361/datasources with params: None (Attempt 1)
# 2025-07-17 16:15:42,667 - INFO - Response status: 403
# 2025-07-17 16:15:42,667 - WARNING - Insufficient permissions for dataset: /admin/datasets/4f3e3bbc-aa78-4582-b05a-4367d4d0b361/datasources
# 2025-07-17 16:15:42,669 - INFO - No datasources found for dataset 4f3e3bbc-aa78-4582-b05a-4367d4d0b361
# 2025-07-17 16:15:57,669 - INFO - Processing dataset 143/147: 2fbc6e7c-1d92-4143-b886-608c28a5c1a1
# 2025-07-17 16:15:57,670 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/2fbc6e7c-1d92-4143-b886-608c28a5c1a1/datasources with params: None (Attempt 1)
# 2025-07-17 16:15:57,731 - INFO - Response status: 403
# 2025-07-17 16:15:57,732 - WARNING - Insufficient permissions for dataset: /admin/datasets/2fbc6e7c-1d92-4143-b886-608c28a5c1a1/datasources
# 2025-07-17 16:15:57,733 - INFO - No datasources found for dataset 2fbc6e7c-1d92-4143-b886-608c28a5c1a1
# 2025-07-17 16:16:12,734 - INFO - Processing dataset 144/147: ecf230de-5fa7-4b69-a225-b410a3ee9676
# 2025-07-17 16:16:12,735 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/ecf230de-5fa7-4b69-a225-b410a3ee9676/datasources with params: None (Attempt 1)
# 2025-07-17 16:16:12,806 - INFO - Response status: 403
# 2025-07-17 16:16:12,807 - WARNING - Insufficient permissions for dataset: /admin/datasets/ecf230de-5fa7-4b69-a225-b410a3ee9676/datasources
# 2025-07-17 16:16:12,809 - INFO - No datasources found for dataset ecf230de-5fa7-4b69-a225-b410a3ee9676
# 2025-07-17 16:16:27,810 - INFO - Processing dataset 145/147: ba330df1-bed2-4a73-b78d-7f9757684e29
# 2025-07-17 16:16:27,810 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/ba330df1-bed2-4a73-b78d-7f9757684e29/datasources with params: None (Attempt 1)
# 2025-07-17 16:16:27,872 - INFO - Response status: 403
# 2025-07-17 16:16:27,873 - WARNING - Insufficient permissions for dataset: /admin/datasets/ba330df1-bed2-4a73-b78d-7f9757684e29/datasources
# 2025-07-17 16:16:27,874 - INFO - No datasources found for dataset ba330df1-bed2-4a73-b78d-7f9757684e29
# 2025-07-17 16:16:42,875 - INFO - Processing dataset 146/147: 497928cb-2d27-4ee2-a78c-24f447f75fb1
# 2025-07-17 16:16:42,876 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/497928cb-2d27-4ee2-a78c-24f447f75fb1/datasources with params: None (Attempt 1)
# 2025-07-17 16:16:42,943 - INFO - Response status: 403
# 2025-07-17 16:16:42,944 - WARNING - Insufficient permissions for dataset: /admin/datasets/497928cb-2d27-4ee2-a78c-24f447f75fb1/datasources
# 2025-07-17 16:16:42,946 - INFO - No datasources found for dataset 497928cb-2d27-4ee2-a78c-24f447f75fb1
# 2025-07-17 16:16:57,946 - INFO - Processing dataset 147/147: 68cedbd8-fb2c-49f8-9a03-2bd3462fed4f
# 2025-07-17 16:16:57,947 - INFO - Making API call to: https://api.powerbi.com/v1.0/myorg/admin/datasets/68cedbd8-fb2c-49f8-9a03-2bd3462fed4f/datasources with params: None (Attempt 1)
# 2025-07-17 16:16:58,018 - INFO - Response status: 403
# 2025-07-17 16:16:58,018 - WARNING - Insufficient permissions for dataset: /admin/datasets/68cedbd8-fb2c-49f8-9a03-2bd3462fed4f/datasources
# 2025-07-17 16:16:58,020 - INFO - No datasources found for dataset 68cedbd8-fb2c-49f8-9a03-2bd3462fed4f
# 2025-07-17 16:16:58,021 - INFO - Batch 3 completed. Found 42 datasources total
# 2025-07-17 16:16:58,021 - INFO - All batches completed. Total datasources found: 259
# 2025-07-17 16:16:58,022 - INFO - Total connection detail records: 382
# 2025-07-17 16:16:58,023 - INFO - Creating DataFrames...
# 2025-07-17 16:17:10,068 - INFO - Delta table 'pbi_datasets_datasources' already exists
# 2025-07-17 16:17:10,725 - INFO - Delta table 'pbi_datasets_datasources_connection_details' already exists
# 2025-07-17 16:17:10,807 - INFO - Starting merge operation for pbi_datasets_datasources
# 2025-07-17 16:17:15,628 - INFO - Merge query:
#     MERGE INTO pbi_datasets_datasources AS target
#     USING source_updates AS source
#     ON target.dataset_id = source.dataset_id AND target.datasource_id = source.datasource_id
#     WHEN MATCHED THEN
#         UPDATE SET target.datasource_name = source.datasource_name, target.datasource_type = source.datasource_type, target.gateway_id = source.gateway_id, target.connection_string = source.connection_string, target.extraction_timestamp = source.extraction_timestamp, target.extraction_batch_id = source.extraction_batch_id
#     WHEN NOT MATCHED THEN
#         INSERT *
#
# 2025-07-17 16:17:27,761 - INFO - Merge operation completed successfully
# 2025-07-17 16:17:27,762 - INFO - Optimizing Delta table 'pbi_datasets_datasources'
# 2025-07-17 16:17:30,198 - INFO - Table statistics updated successfully
# 2025-07-17 16:17:30,199 - INFO - Delta table optimization completed via statistics computation
# 2025-07-17 16:17:30,199 - INFO - Note: Microsoft Fabric may automatically optimize Delta tables
# 2025-07-17 16:17:30,262 - INFO - Starting merge operation for pbi_datasets_datasources_connection_details
# 2025-07-17 16:17:31,522 - INFO - Merge query:
#     MERGE INTO pbi_datasets_datasources_connection_details AS target
#     USING source_updates AS source
#     ON target.dataset_id = source.dataset_id AND target.datasource_id = source.datasource_id AND target.connection_property = source.connection_property
#     WHEN MATCHED THEN
#         UPDATE SET target.connection_value = source.connection_value, target.extraction_timestamp = source.extraction_timestamp, target.extraction_batch_id = source.extraction_batch_id
#     WHEN NOT MATCHED THEN
#         INSERT *
#
# 2025-07-17 16:17:36,130 - INFO - Merge operation completed successfully
# 2025-07-17 16:17:36,131 - INFO - Optimizing Delta table 'pbi_datasets_datasources_connection_details'
# +------------------------------------+------------------------------------+---------------+---------------+------------------------------------+-----------------+--------------------------+------------------------------------+
# |dataset_id                          |datasource_id                       |datasource_name|datasource_type|gateway_id                          |connection_string|extraction_timestamp      |extraction_batch_id                 |
# +------------------------------------+------------------------------------+---------------+---------------+------------------------------------+-----------------+--------------------------+------------------------------------+
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|NULL           |Extension      |7e508ae6-3f91-43a5-ba20-e24caa4b7fd5|NULL             |2025-07-17 15:39:21.651736|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|30d92dc2-4a7b-4719-92a7-97c26a879d8a|NULL           |Extension      |1c72182e-146a-4a10-8bb0-3c87aa65e68b|NULL             |2025-07-17 15:39:36.817739|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |187c3787-c4a5-47a3-a35b-149b72bbd070|13c115c3-01f8-4133-a5fc-fb81163aecd2|NULL           |Extension      |f29ff6e2-d740-44c1-a6ed-b1763344ea0d|NULL             |2025-07-17 15:39:52.058828|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |09eac459-9b71-4e9b-8771-45a142078a0d|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|NULL           |Extension      |7e508ae6-3f91-43a5-ba20-e24caa4b7fd5|NULL             |2025-07-17 15:40:08.4711  |da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |36e4c8d8-d521-4577-93f8-307633711275|3502167a-1a61-41ff-ad9b-c240d767e570|NULL           |Extension      |51bb2458-5a48-49cc-9a6e-ab67c9ab9e37|NULL             |2025-07-17 15:40:23.647725|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# +------------------------------------+------------------------------------+---------------+---------------+------------------------------------+-----------------+--------------------------+------------------------------------+
# only showing top 5 rows
#
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# |dataset_id                          |datasource_id                       |connection_property|connection_value      |extraction_timestamp      |extraction_batch_id                 |
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|path               |PowerPlatformDataflows|2025-07-17 15:39:21.651743|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |d9a141b5-20e2-4c8a-825b-02c0f63bd691|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|kind               |PowerPlatformDataflows|2025-07-17 15:39:21.651745|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|30d92dc2-4a7b-4719-92a7-97c26a879d8a|path               |PowerPlatformDataflows|2025-07-17 15:39:36.817746|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |c6c5b1e8-4f0c-400e-a396-72048f9b3871|30d92dc2-4a7b-4719-92a7-97c26a879d8a|kind               |PowerPlatformDataflows|2025-07-17 15:39:36.817748|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |187c3787-c4a5-47a3-a35b-149b72bbd070|13c115c3-01f8-4133-a5fc-fb81163aecd2|path               |PowerPlatformDataflows|2025-07-17 15:39:52.058833|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |187c3787-c4a5-47a3-a35b-149b72bbd070|13c115c3-01f8-4133-a5fc-fb81163aecd2|kind               |PowerPlatformDataflows|2025-07-17 15:39:52.058834|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |09eac459-9b71-4e9b-8771-45a142078a0d|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|path               |PowerPlatformDataflows|2025-07-17 15:40:08.471103|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |09eac459-9b71-4e9b-8771-45a142078a0d|6270f3eb-9cd1-4028-b4eb-25713ef9c5e2|kind               |PowerPlatformDataflows|2025-07-17 15:40:08.471104|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |36e4c8d8-d521-4577-93f8-307633711275|3502167a-1a61-41ff-ad9b-c240d767e570|path               |PowerPlatformDataflows|2025-07-17 15:40:23.647729|da1dd779-45ba-42f0-bf98-49a53d0d516c|
# |36e4c8d8-d521-4577-93f8-307633711275|3502167a-1a61-41ff-ad9b-c240d767e570|kind               |PowerPlatformDataflows|2025-07-17 15:40:23.64773 |da1dd779-45ba-42f0-bf98-49a53d0d516c|
# +------------------------------------+------------------------------------+-------------------+----------------------+--------------------------+------------------------------------+
# only showing top 10 rows
#
# +----------------+-----+
# |datasource_type |count|
# +----------------+-----+
# |Web             |82   |
# |Sql             |65   |
# |Extension       |62   |
# |File            |28   |
# |AnalysisServices|24   |
# |SharePointList  |22   |
# |Oracle          |5    |
# +----------------+-----+
#
# +---------------------------+-----------------+---------------------+
# |total_connection_properties|unique_properties|datasets_with_details|
# +---------------------------+-----------------+---------------------+
# |439                        |5                |143                  |
# +---------------------------+-----------------+---------------------+

# %%
from pyspark.sql import SparkSession

# create Spark session
spark = SparkSession.builder.appName("Refresh SQL Endpoint Metadata").getOrCreate()

# refresh the specific table
spark.sql("REFRESH TABLE pbi_datasets_datasources")
print("Metadata refresh triggered successfully.")

# refresh the specific table
spark.sql("REFRESH TABLE pbi_datasets_datasources_connection_details")
print("Metadata refresh triggered successfully.")
# Out:
# StatementMeta(, bc48bd6a-b0ef-452f-a9f2-189999c838f6, 5, Finished, Available, Finished)
# Metadata refresh triggered successfully.
# Metadata refresh triggered successfully.
