# %%
# CELL 1 - Title and Introduction
# ==================================
# Microsoft Fabric Workspace Access Details to Delta Lake - PySpark Notebook
# This notebook retrieves Microsoft Fabric workspace access details and loads them into Delta Lake tables
# with optimization for analytics workloads using a multi-table approach for different principal types
# 
# The notebook automatically retrieves workspace IDs from the lakehouse and processes each workspace
# ==================================


# CELL 2 - Import Libraries
# ==================================
# Import required libraries
import requests
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_timestamp, lit, from_json, when, isnotnull
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
import logging
from typing import Dict, List, Optional
from delta.tables import DeltaTable
import random
import time
# ==================================


# CELL 3 - Configure Logging and Initialize Spark
# ==================================
# Configure logging
# This helps us track what's happening in our code and debug issues
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize Spark Session with Delta Lake configurations
# In Fabric notebooks, Spark is pre-configured with Delta support
spark = SparkSession.builder \
    .appName("FabricWorkspaceAccessDetailsToDelta") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Set optimal configurations for Delta operations
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "true")
spark.conf.set("spark.databricks.delta.autoCompact.enabled", "true")
# ==================================


# CELL 4 - Configuration Parameters
# ==================================
# Configuration Parameters
# These are the settings we'll use throughout the notebook
CONFIG = {
    "API_BASE_URL": "https://api.fabric.microsoft.com/v1",
    "WORKSPACE_ACCESS_ENDPOINT": "/admin/workspaces/{workspaceId}/users",  # Endpoint for workspace access details
    "MAX_RETRIES": 5,  # Increased number of retries for handling rate limits
    "INITIAL_BACKOFF_SEC": 1,  # Initial backoff time in seconds
    "MAX_BACKOFF_SEC": 60,  # Maximum backoff time in seconds
    "BACKOFF_FACTOR": 2,  # Exponential backoff multiplier
    "JITTER_FACTOR": 0.1,  # Random jitter to add to backoff (as a fraction)
    "TIMEOUT": 30,  # API request timeout in seconds
    # Multi-table approach for different principal types
    "ACCESS_CORE_TABLE_NAME": "fabric_workspaces_access_core",  # Core access table
    "ACCESS_USERS_TABLE_NAME": "fabric_workspaces_access_users",  # User details table
    "ACCESS_GROUPS_TABLE_NAME": "fabric_workspaces_access_groups",  # Group details table
    "ACCESS_SERVICE_PRINCIPALS_TABLE_NAME": "fabric_workspaces_access_service_principals",  # Service principal details table
    "ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME": "fabric_workspaces_access_service_principal_profiles",  # Service principal profile details table
    "LAKEHOUSE_PATH": "Tables",  # Default Tables folder in Fabric Lakehouse
    "DEBUG_MODE": True,  # Set to True to enable extra debugging output
    # Lakehouse configuration for workspace retrieval
    "WORKSPACE_SOURCE_LAKEHOUSE": "FabricAdmin_Lakehouse",
    "WORKSPACE_SOURCE_SCHEMA": "dbo",
    "WORKSPACE_SOURCE_TABLE": "fabric_workspaces",
    "TARGET_CAPACITY_ID": "C73A5223-9EF6-4514-83CC-3E70297EE377"  # Target capacity ID for filtering workspaces
}
# ==================================


# CELL 5 - Get Workspace IDs from Lakehouse
# ==================================
def get_workspace_ids_from_lakehouse() -> List[str]:
    """
    Retrieve workspace IDs from the lakehouse based on the specified criteria.
    
    This function queries the fabric_workspaces table to get all active, non-personal
    workspaces from the specified capacity.
    
    Returns:
        list: A list of workspace IDs that match the criteria
    """
    logger.info("Retrieving workspace IDs from lakehouse...")
    
    try:
        # Construct the fully qualified table name
        table_name = f"{CONFIG['WORKSPACE_SOURCE_LAKEHOUSE']}.{CONFIG['WORKSPACE_SOURCE_SCHEMA']}.{CONFIG['WORKSPACE_SOURCE_TABLE']}"
        
        # Query to get workspace IDs based on the criteria
        query = f"""
        SELECT id 
        FROM {table_name}
        WHERE state = 'Active'
        AND type <> 'Personal'
        AND capacityId = '{CONFIG['TARGET_CAPACITY_ID']}'
        """
        
        logger.info(f"Executing query: {query}")
        
        # Execute the query
        workspace_df = spark.sql(query)
        
        # Convert to list of workspace IDs
        workspace_ids = [row['id'] for row in workspace_df.collect()]
        
        logger.info(f"Found {len(workspace_ids)} workspaces to process")
        
        # Log first few workspace IDs for verification if in debug mode
        if CONFIG['DEBUG_MODE'] and workspace_ids:
            logger.info(f"Sample workspace IDs: {workspace_ids[:3]}...")
        
        return workspace_ids
        
    except Exception as e:
        logger.error(f"Failed to retrieve workspace IDs from lakehouse: {str(e)}")
        logger.error("Please ensure the table exists and you have appropriate permissions")
        raise
# ==================================


# CELL 6 - Authentication Function
# ==================================
def get_access_token():
    """
    Get Azure AD access token for Fabric API authentication.
    
    In a Fabric notebook, the token is automatically available through mssparkutils.
    This function retrieves the token that's needed to authenticate with the Fabric REST API.
    
    Returns:
        str: The access token
    
    Note:
        mssparkutils is a utility library provided by Microsoft Fabric
        that handles authentication automatically.
    """
    try:
        # In Fabric notebooks, we can get the token using mssparkutils
        from notebookutils import mssparkutils
        token_response = mssparkutils.credentials.getToken("https://api.fabric.microsoft.com")
        return token_response
    except Exception as e:
        logger.error(f"Failed to get access token: {str(e)}")
        raise
# ==================================


# CELL 7 - API Call Function
# ==================================
def call_fabric_api(endpoint: str, access_token: str, params: Optional[Dict] = None) -> Dict:
    """
    Make a REST API call to Microsoft Fabric with advanced rate limit handling.
    
    This function handles the HTTP request to the Fabric API, including:
    - Setting up authentication headers
    - Managing retries with intelligent backoff for rate limiting (429 errors)
    - Implementing jitter to avoid synchronized retries
    - Detailed error handling and logging
    
    Args:
        endpoint: The API endpoint path (e.g., "/admin/workspaces/{workspaceId}/users")
        access_token: The Azure AD access token
        params: Optional query parameters for the API call
    
    Returns:
        dict: The JSON response from the API
    
    Raises:
        requests.exceptions.RequestException: If the API call fails after all retries
    """
    url = f"{CONFIG['API_BASE_URL']}{endpoint}"
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    
    # Initialize backoff time
    backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
    
    # Retry logic with intelligent backoff
    for attempt in range(CONFIG['MAX_RETRIES']):
        try:
            # Log the full URL with parameters for debugging
            logger.info(f"Making API call to: {url} with params: {params} (Attempt {attempt + 1})")
            
            response = requests.get(
                url,
                headers=headers,
                params=params,
                timeout=CONFIG['TIMEOUT']
            )
            
            # Log the full response for debugging
            logger.info(f"Response status: {response.status_code}")
            
            # Rate limit handling (429 Too Many Requests)
            if response.status_code == 429:
                # Get retry-after header if available, otherwise use our backoff
                retry_after = response.headers.get('Retry-After')
                
                if retry_after and retry_after.isdigit():
                    # If server specified a wait time, use it
                    wait_time = int(retry_after)
                else:
                    # Calculate wait time with exponential backoff and jitter
                    jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                    wait_time = backoff_time + jitter
                    # Update backoff for next attempt
                    backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.warning(f"Rate limit exceeded (429). Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
                continue  # Skip to next retry attempt without raising exception
            
            # Log the response for debugging in case of errors
            if response.status_code >= 400:
                logger.error(f"API error: Status {response.status_code}, Response: {response.text}")
                logger.error(f"Request URL: {response.request.url}")
                logger.error(f"Request headers: {response.request.headers}")
            
            # For all other status codes, use raise_for_status to handle
            response.raise_for_status()
            
            # If we get here, the request was successful
            # Reset backoff for next API call (not next attempt)
            backoff_time = CONFIG['INITIAL_BACKOFF_SEC']
            
            # Log a sample of the response content for debugging
            try:
                response_json = response.json()
                if "accessDetails" in response_json and isinstance(response_json["accessDetails"], list):
                    logger.info(f"Response contains {len(response_json['accessDetails'])} items in 'accessDetails' array")
                return response_json
            except json.JSONDecodeError as e:
                logger.error(f"Failed to parse response as JSON: {str(e)}")
                logger.error(f"Response content: {response.text[:1000]}")  # Log first 1000 chars of response
                raise
            
        except requests.exceptions.RequestException as e:
            last_attempt = attempt == CONFIG['MAX_RETRIES'] - 1
            
            # Special handling for non-429 errors
            if not (hasattr(e, 'response') and e.response is not None and e.response.status_code == 429):
                logger.warning(f"API call failed (Attempt {attempt + 1}): {str(e)}")
                
                if last_attempt:
                    logger.error(f"All retry attempts failed for endpoint: {endpoint}")
                    logger.error(f"Final error: {str(e)}")
                    raise
                
                # Calculate wait time with exponential backoff and jitter
                jitter = random.uniform(0, CONFIG['JITTER_FACTOR'] * backoff_time)
                wait_time = backoff_time + jitter
                # Update backoff for next attempt
                backoff_time = min(backoff_time * CONFIG['BACKOFF_FACTOR'], CONFIG['MAX_BACKOFF_SEC'])
                
                logger.info(f"Waiting {wait_time:.2f} seconds before retry.")
                time.sleep(wait_time)
# ==================================


# CELL 8 - Get Workspace Access Details Function
# ==================================
def get_workspace_access_details(access_token: str, workspace_id: str) -> List[Dict]:
    """
    Retrieve workspace access details for a specific workspace from the Fabric API.
    
    This function makes a request to the List Workspace Access Details API endpoint
    to get all users, groups, and service principals that have access to the workspace.
    
    Args:
        access_token: The Azure AD access token
        workspace_id: The workspace ID to get access details for
    
    Returns:
        list: A list of all access detail objects containing principal and workspace access information
    """
    logger.info(f"Retrieving access details for workspace: {workspace_id}")
    
    # Construct the endpoint with the workspace ID
    endpoint = CONFIG['WORKSPACE_ACCESS_ENDPOINT'].format(workspaceId=workspace_id)
    
    try:
        # Make the API call
        response_data = call_fabric_api(endpoint, access_token)
        
        # Log the response structure for debugging
        if CONFIG['DEBUG_MODE']:
            logger.info(f"Response keys: {list(response_data.keys())}")
        
        # Extract access details from the response
        access_details = response_data.get("accessDetails", [])
        
        if access_details:
            logger.info(f"Retrieved {len(access_details)} access details for workspace {workspace_id}")
            
            # Log first access detail for debugging
            if CONFIG['DEBUG_MODE'] and access_details:
                logger.info(f"Sample access detail: {json.dumps(access_details[0], indent=2)}")
        else:
            logger.warning(f"No access details found for workspace {workspace_id}")
        
        return access_details
        
    except requests.exceptions.RequestException as e:
        logger.error(f"API call failed for workspace {workspace_id}: {str(e)}")
        raise
# ==================================


# CELL 9 - Create Core Access DataFrame Function
# ==================================
def create_core_access_dataframe(access_details: List[Dict], workspace_id: str) -> "DataFrame":
    """
    Convert the access details data into a core access PySpark DataFrame.
    
    This function creates the main access table containing the core information
    that's common across all principal types.
    
    Args:
        access_details: List of access detail dictionaries from the API
        workspace_id: The workspace ID this data relates to
    
    Returns:
        DataFrame: A PySpark DataFrame with core access information
    """
    logger.info("Creating core access DataFrame")
    
    # Extract core access information from each access detail
    core_access_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        workspace_access = access_detail.get("workspaceAccessDetails", {})
        
        core_record = {
            "workspace_id": workspace_id,
            "principal_id": principal.get("id"),
            "principal_display_name": principal.get("displayName"),
            "principal_type": principal.get("type"),
            "workspace_role": workspace_access.get("workspaceRole"),
            "workspace_type": workspace_access.get("type")
        }
        core_access_data.append(core_record)
    
    # Define the schema for the core access table
    schema = StructType([
        StructField("workspace_id", StringType(), False),
        StructField("principal_id", StringType(), False),
        StructField("principal_display_name", StringType(), True),
        StructField("principal_type", StringType(), False),
        StructField("workspace_role", StringType(), True),
        StructField("workspace_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not core_access_data:
        logger.warning("No access details found. Creating empty core DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        core_df = spark.createDataFrame(empty_rdd, schema)
        return core_df
    
    # Convert to pandas DataFrame first, then to Spark DataFrame
    pandas_df = pd.DataFrame(core_access_data)
    
    # Create the initial Spark DataFrame
    required_columns = ["workspace_id", "principal_id", "principal_display_name", "principal_type", "workspace_role", "workspace_type"]
    
    # Ensure all columns exist in the pandas DataFrame
    for col_name in required_columns:
        if col_name not in pandas_df.columns:
            pandas_df[col_name] = None
    
    spark_df = spark.createDataFrame(pandas_df[required_columns])
    
    # Add metadata column for tracking when this data was extracted
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created core access DataFrame with {enhanced_df.count()} records")
    return enhanced_df
# ==================================


# CELL 10 - Create Principal-Specific DataFrames Functions
# ==================================
def create_user_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for user principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with user-specific details
    """
    logger.info("Creating user details DataFrame")
    
    user_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process User principals
        if principal.get("type") == "User":
            user_details = principal.get("userDetails", {})
            
            user_record = {
                "principal_id": principal.get("id"),
                "user_principal_name": user_details.get("userPrincipalName")
            }
            user_details_data.append(user_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("user_principal_name", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not user_details_data:
        logger.info("No user principals found. Creating empty user details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        user_df = spark.createDataFrame(empty_rdd, schema)
        return user_df
    
    pandas_df = pd.DataFrame(user_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created user details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_group_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for group principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with group-specific details
    """
    logger.info("Creating group details DataFrame")
    
    group_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process Group principals
        if principal.get("type") == "Group":
            group_details = principal.get("groupDetails", {})
            
            group_record = {
                "principal_id": principal.get("id"),
                "group_type": group_details.get("groupType")
            }
            group_details_data.append(group_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("group_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not group_details_data:
        logger.info("No group principals found. Creating empty group details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        group_df = spark.createDataFrame(empty_rdd, schema)
        return group_df
    
    pandas_df = pd.DataFrame(group_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created group details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_service_principal_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for service principal details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with service principal-specific details
    """
    logger.info("Creating service principal details DataFrame")
    
    sp_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process ServicePrincipal principals
        if principal.get("type") == "ServicePrincipal":
            sp_details = principal.get("servicePrincipalDetails", {})
            
            sp_record = {
                "principal_id": principal.get("id"),
                "aad_app_id": sp_details.get("aadAppId")
            }
            sp_details_data.append(sp_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("aad_app_id", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not sp_details_data:
        logger.info("No service principals found. Creating empty service principal details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        sp_df = spark.createDataFrame(empty_rdd, schema)
        return sp_df
    
    pandas_df = pd.DataFrame(sp_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created service principal details DataFrame with {enhanced_df.count()} records")
    return enhanced_df


def create_service_principal_profile_details_dataframe(access_details: List[Dict]) -> "DataFrame":
    """
    Create a DataFrame specifically for service principal profile details.
    
    Args:
        access_details: List of access detail dictionaries from the API
    
    Returns:
        DataFrame: A PySpark DataFrame with service principal profile-specific details
    """
    logger.info("Creating service principal profile details DataFrame")
    
    spp_details_data = []
    
    for access_detail in access_details:
        principal = access_detail.get("principal", {})
        
        # Only process ServicePrincipalProfile principals
        if principal.get("type") == "ServicePrincipalProfile":
            spp_details = principal.get("servicePrincipalProfileDetails", {})
            parent_principal = spp_details.get("parentPrincipal", {})
            
            spp_record = {
                "principal_id": principal.get("id"),
                "parent_principal_id": parent_principal.get("id"),
                "parent_principal_display_name": parent_principal.get("displayName"),
                "parent_principal_type": parent_principal.get("type")
            }
            spp_details_data.append(spp_record)
    
    # Define schema
    schema = StructType([
        StructField("principal_id", StringType(), False),
        StructField("parent_principal_id", StringType(), True),
        StructField("parent_principal_display_name", StringType(), True),
        StructField("parent_principal_type", StringType(), True),
        StructField("last_updated_timestamp", TimestampType(), False)
    ])
    
    # Create DataFrame
    if not spp_details_data:
        logger.info("No service principal profiles found. Creating empty service principal profile details DataFrame.")
        empty_rdd = spark.sparkContext.emptyRDD()
        spp_df = spark.createDataFrame(empty_rdd, schema)
        return spp_df
    
    pandas_df = pd.DataFrame(spp_details_data)
    spark_df = spark.createDataFrame(pandas_df)
    enhanced_df = spark_df.withColumn("last_updated_timestamp", current_timestamp())
    
    logger.info(f"Created service principal profile details DataFrame with {enhanced_df.count()} records")
    return enhanced_df
# ==================================


# CELL 11 - Delta Lake Operations Functions
# ==================================
def ensure_delta_table_exists(table_name: str, df_schema):
    """
    Ensure the Delta table exists, creating it if necessary.
    
    Args:
        table_name: Name of the Delta table
        df_schema: Schema of the DataFrame
    """
    try:
        # Check if table exists
        spark.sql(f"DESCRIBE TABLE {table_name}")
        logger.info(f"Delta table '{table_name}' already exists")
    except Exception:
        # Table doesn't exist, create it
        logger.info(f"Creating Delta table '{table_name}'")
        
        # Create an empty DataFrame with the schema
        empty_df = spark.createDataFrame([], df_schema)
        
        # Create the Delta table
        empty_df.write \
            .mode("overwrite") \
            .option("overwriteSchema", "true") \
            .saveAsTable(table_name)
        
        logger.info(f"Delta table '{table_name}' created successfully")


def merge_core_access_data_to_delta(source_df, table_name: str):
    """
    Merge new core access data into the Delta table using MERGE operation.
    
    This function performs an upsert operation:
    - Updates existing records if workspace_id + principal_id matches
    - Inserts new records if the combination doesn't exist
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    source_df.createOrReplaceTempView("access_updates")
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Perform the merge operation (composite key: workspace_id + principal_id)
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING access_updates AS source
    ON target.workspace_id = source.workspace_id AND target.principal_id = source.principal_id
    WHEN MATCHED THEN
        UPDATE SET 
            target.principal_display_name = source.principal_display_name,
            target.principal_type = source.principal_type,
            target.workspace_role = source.workspace_role,
            target.workspace_type = source.workspace_type,
            target.last_updated_timestamp = source.last_updated_timestamp
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    spark.sql(merge_query)
    logger.info("Core access merge operation completed successfully")


def merge_principal_details_to_delta(source_df, table_name: str):
    """
    Merge principal-specific details into the Delta table using MERGE operation.
    
    This function performs an upsert operation based on principal_id.
    
    Args:
        source_df: DataFrame with new data
        table_name: Name of the target Delta table
    """
    logger.info(f"Starting merge operation for {table_name}")
    
    # Create a temporary view for the merge operation
    temp_view_name = f"{table_name.replace('fabric_', '')}_updates"
    source_df.createOrReplaceTempView(temp_view_name)
    
    # If the table is empty, just insert all records
    if spark.table(table_name).count() == 0:
        logger.info(f"Table {table_name} is empty. Inserting all records.")
        source_df.write.mode("append").saveAsTable(table_name)
        return
    
    # Get column names excluding principal_id and last_updated_timestamp for dynamic UPDATE SET
    columns = [col for col in source_df.columns if col not in ['principal_id', 'last_updated_timestamp']]
    update_set_clause = ", ".join([f"target.{col} = source.{col}" for col in columns])
    update_set_clause += ", target.last_updated_timestamp = source.last_updated_timestamp"
    
    # Perform the merge operation
    merge_query = f"""
    MERGE INTO {table_name} AS target
    USING {temp_view_name} AS source
    ON target.principal_id = source.principal_id
    WHEN MATCHED THEN
        UPDATE SET {update_set_clause}
    WHEN NOT MATCHED THEN
        INSERT *
    """
    
    spark.sql(merge_query)
    logger.info(f"Principal details merge operation completed successfully for {table_name}")


def optimize_delta_table(table_name: str):
    """
    Optimize the Delta table for better query performance.
    
    Args:
        table_name: Name of the Delta table to optimize
    """
    logger.info(f"Optimizing Delta table '{table_name}'")
    
    try:
        # Update table statistics for better query planning
        spark.sql(f"ANALYZE TABLE {table_name} COMPUTE STATISTICS")
        logger.info(f"Table statistics updated successfully for {table_name}")
        
        logger.info(f"Delta table optimization completed for {table_name}")
    except Exception as e:
        logger.warning(f"Table optimization step encountered an issue for {table_name}: {str(e)}")
        logger.info("Continuing with process - optimization is not critical for functionality")
# ==================================


# CELL 12 - Process Single Workspace Function
# ==================================
def process_single_workspace(workspace_id: str, access_token: str) -> Dict:
    """
    Process access details for a single workspace.
    
    This function handles the complete processing for one workspace:
    1. Retrieves access details from the API
    2. Creates DataFrames for different principal types
    3. Merges data into Delta tables
    
    Args:
        workspace_id: The workspace ID to process
        access_token: The Azure AD access token
    
    Returns:
        dict: Summary information about the processed workspace
    """
    logger.info(f"Processing workspace: {workspace_id}")
    
    try:
        # Retrieve access details
        access_details = get_workspace_access_details(access_token, workspace_id)
        
        if not access_details:
            logger.warning(f"No access details found for workspace {workspace_id}")
            return {
                "workspace_id": workspace_id,
                "status": "no_data",
                "records_processed": 0
            }
        
        # Create DataFrames
        core_access_df = create_core_access_dataframe(access_details, workspace_id)
        user_details_df = create_user_details_dataframe(access_details)
        group_details_df = create_group_details_dataframe(access_details)
        sp_details_df = create_service_principal_details_dataframe(access_details)
        spp_details_df = create_service_principal_profile_details_dataframe(access_details)
        
        # Process each table
        table_configs = [
            (CONFIG["ACCESS_CORE_TABLE_NAME"], core_access_df, merge_core_access_data_to_delta),
            (CONFIG["ACCESS_USERS_TABLE_NAME"], user_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_GROUPS_TABLE_NAME"], group_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_SERVICE_PRINCIPALS_TABLE_NAME"], sp_details_df, merge_principal_details_to_delta),
            (CONFIG["ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME"], spp_details_df, merge_principal_details_to_delta)
        ]
        
        records_processed = 0
        
        for table_name, df, merge_function in table_configs:
            # Ensure table exists
            ensure_delta_table_exists(table_name, df.schema)
            
            # Merge data if DataFrame has records
            if df.count() > 0:
                merge_function(df, table_name)
                records_processed += df.count()
        
        logger.info(f"Successfully processed workspace {workspace_id} with {core_access_df.count()} access records")
        
        return {
            "workspace_id": workspace_id,
            "status": "success",
            "records_processed": core_access_df.count(),
            "user_count": user_details_df.count(),
            "group_count": group_details_df.count(),
            "service_principal_count": sp_details_df.count(),
            "service_principal_profile_count": spp_details_df.count()
        }
        
    except Exception as e:
        logger.error(f"Error processing workspace {workspace_id}: {str(e)}")
        return {
            "workspace_id": workspace_id,
            "status": "error",
            "error": str(e)
        }
# ==================================


# CELL 13 - Main Execution Function
# ==================================
def main():
    """
    Main execution function that orchestrates the entire process.
    
    This function:
    1. Gets the authentication token
    2. Retrieves workspace IDs from the lakehouse
    3. Processes each workspace in sequence
    4. Provides summary statistics
    
    Returns:
        list: Summary information for all processed workspaces
    """
    try:
        logger.info("Starting Fabric Workspace Access Details to Delta Lake process")
        
        # Step 1: Get authentication token
        logger.info("Getting access token...")
        access_token = get_access_token()
        logger.info("Successfully obtained access token")
        
        # Step 2: Get workspace IDs from lakehouse
        logger.info("Retrieving workspace IDs from lakehouse...")
        workspace_ids = get_workspace_ids_from_lakehouse()
        
        if not workspace_ids:
            logger.warning("No workspace IDs found matching the criteria. Please check your lakehouse query.")
            return []
        
        logger.info(f"Found {len(workspace_ids)} workspaces to process")
        
        # Step 3: Process each workspace
        logger.info("Starting to process workspaces...")
        processing_results = []
        successful_workspaces = 0
        failed_workspaces = 0
        total_records_processed = 0
        
        for idx, workspace_id in enumerate(workspace_ids, 1):
            logger.info(f"Processing workspace {idx} of {len(workspace_ids)}: {workspace_id}")
            
            # Process the workspace
            result = process_single_workspace(workspace_id, access_token)
            processing_results.append(result)
            
            # Update counters
            if result["status"] == "success":
                successful_workspaces += 1
                total_records_processed += result.get("records_processed", 0)
            elif result["status"] == "error":
                failed_workspaces += 1
            
            # Add a small delay between workspaces to avoid rate limiting
            if idx < len(workspace_ids):
                time.sleep(0.5)
        
        # Step 4: Display final statistics
        logger.info("=" * 60)
        logger.info("PROCESSING COMPLETED")
        logger.info("=" * 60)
        logger.info(f"Total workspaces processed: {len(workspace_ids)}")
        logger.info(f"Successful: {successful_workspaces}")
        logger.info(f"Failed: {failed_workspaces}")
        logger.info(f"No data: {len(workspace_ids) - successful_workspaces - failed_workspaces}")
        logger.info(f"Total access records processed: {total_records_processed}")
        
        # Show table statistics
        logger.info("\n=== DELTA TABLE STATISTICS ===")
        
        table_names = [
            CONFIG["ACCESS_CORE_TABLE_NAME"],
            CONFIG["ACCESS_USERS_TABLE_NAME"],
            CONFIG["ACCESS_GROUPS_TABLE_NAME"],
            CONFIG["ACCESS_SERVICE_PRINCIPALS_TABLE_NAME"],
            CONFIG["ACCESS_SERVICE_PRINCIPAL_PROFILES_TABLE_NAME"]
        ]
        
        for table_name in table_names:
            try:
                row_count = spark.table(table_name).count()
                logger.info(f"{table_name}: {row_count} rows")
            except Exception as e:
                logger.warning(f"Could not get statistics for {table_name}: {str(e)}")
        
        # Optimize all tables
        logger.info("\n=== OPTIMIZING DELTA TABLES ===")
        for table_name in table_names:
            optimize_delta_table(table_name)
        
        # Return processing results for further analysis
        return processing_results
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")
        raise
# ==================================


# CELL 14 - Execute Main Function
# ==================================
# Execute the main function
if __name__ == "__main__":
    # Process all workspaces from the lakehouse
    processing_results = main()
    
    # Display detailed results if needed
    if CONFIG['DEBUG_MODE'] and processing_results:
        logger.info("\n=== DETAILED PROCESSING RESULTS ===")
        for result in processing_results[:10]:  # Show first 10 results
            logger.info(f"Workspace {result['workspace_id']}: {result['status']}")
            if result['status'] == 'success':
                logger.info(f"  - Records: {result['records_processed']}")
                logger.info(f"  - Users: {result.get('user_count', 0)}")
                logger.info(f"  - Groups: {result.get('group_count', 0)}")
# ==================================
# Out:
# StatementMeta(, 40cfb356-a779-4bc9-8371-bcd62cbbd3fc, 3, Finished, Available, Finished)
# 2025-05-27 19:39:16,548 - INFO - Starting Fabric Workspace Access Details to Delta Lake process
# 2025-05-27 19:39:16,549 - INFO - Getting access token...
# 2025-05-27 19:39:17,392 - INFO - Successfully obtained access token
# 2025-05-27 19:39:17,393 - INFO - Retrieving workspace IDs from lakehouse...
# 2025-05-27 19:39:17,394 - INFO - Retrieving workspace IDs from lakehouse...
# 2025-05-27 19:39:17,395 - INFO - Executing query:
#         SELECT id
#         FROM FabricAdmin_Lakehouse.dbo.fabric_workspaces
#         WHERE state = 'Active'
#         AND type <> 'Personal'
#         AND capacityId = 'C73A5223-9EF6-4514-83CC-3E70297EE377'
#
# 2025-05-27 19:39:30,864 - INFO - Found 37 workspaces to process
# 2025-05-27 19:39:30,865 - INFO - Sample workspace IDs: ['263575b7-d1ee-4dcc-bd05-ca67158e1bb4', 'be770ec6-b0f5-4323-9efd-1554201ff583', '73fac372-490a-4068-a2aa-856837eb6a6b']...
# 2025-05-27 19:39:30,865 - INFO - Found 37 workspaces to process
# 2025-05-27 19:39:30,867 - INFO - Starting to process workspaces...
# 2025-05-27 19:39:30,867 - INFO - Processing workspace 1 of 37: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-05-27 19:39:30,867 - INFO - Processing workspace: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-05-27 19:39:30,868 - INFO - Retrieving access details for workspace: 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-05-27 19:39:30,868 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/263575b7-d1ee-4dcc-bd05-ca67158e1bb4/users with params: None (Attempt 1)
# 2025-05-27 19:39:31,123 - INFO - Response status: 200
# 2025-05-27 19:39:31,123 - INFO - Response contains 4 items in 'accessDetails' array
# 2025-05-27 19:39:31,127 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:39:31,127 - INFO - Retrieved 4 access details for workspace 263575b7-d1ee-4dcc-bd05-ca67158e1bb4
# 2025-05-27 19:39:31,128 - INFO - Sample access detail: {
#   "principal": {
#     "id": "eeb21f9e-edfe-40f6-aa48-fb10095de645",
#     "displayName": "",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "edpbiinfrastructure@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "AdminWorkspace",
#     "workspaceRole": "Viewer"
#   }
# }
# 2025-05-27 19:39:31,129 - INFO - Creating core access DataFrame
# 2025-05-27 19:39:32,753 - INFO - Created core access DataFrame with 4 records
# 2025-05-27 19:39:32,754 - INFO - Creating user details DataFrame
# 2025-05-27 19:39:32,925 - INFO - Created user details DataFrame with 4 records
# 2025-05-27 19:39:32,926 - INFO - Creating group details DataFrame
# 2025-05-27 19:39:32,927 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:39:32,965 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:39:32,966 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:39:32,988 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:39:32,989 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:39:33,823 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:39:33,928 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:39:42,725 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:39:43,351 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:39:43,426 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:39:49,290 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:39:49,833 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:39:50,342 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:39:50,768 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:39:50,905 - INFO - Successfully processed workspace 263575b7-d1ee-4dcc-bd05-ca67158e1bb4 with 4 access records
# 2025-05-27 19:39:51,678 - INFO - Processing workspace 2 of 37: be770ec6-b0f5-4323-9efd-1554201ff583
# 2025-05-27 19:39:51,679 - INFO - Processing workspace: be770ec6-b0f5-4323-9efd-1554201ff583
# 2025-05-27 19:39:51,679 - INFO - Retrieving access details for workspace: be770ec6-b0f5-4323-9efd-1554201ff583
# 2025-05-27 19:39:51,680 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/be770ec6-b0f5-4323-9efd-1554201ff583/users with params: None (Attempt 1)
# 2025-05-27 19:39:51,845 - INFO - Response status: 200
# 2025-05-27 19:39:51,845 - INFO - Response contains 28 items in 'accessDetails' array
# 2025-05-27 19:39:51,849 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:39:51,849 - INFO - Retrieved 28 access details for workspace be770ec6-b0f5-4323-9efd-1554201ff583
# 2025-05-27 19:39:51,850 - INFO - Sample access detail: {
#   "principal": {
#     "id": "5c85840e-4e88-4f1a-ba2b-032b4ab2eefa",
#     "displayName": "Aneeqa Zafar",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "AZafar1@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:39:51,850 - INFO - Creating core access DataFrame
# 2025-05-27 19:39:51,951 - INFO - Created core access DataFrame with 28 records
# 2025-05-27 19:39:51,952 - INFO - Creating user details DataFrame
# 2025-05-27 19:39:52,041 - INFO - Created user details DataFrame with 28 records
# 2025-05-27 19:39:52,042 - INFO - Creating group details DataFrame
# 2025-05-27 19:39:52,043 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:39:52,059 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:39:52,061 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:39:52,076 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:39:52,076 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:39:52,222 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:39:52,314 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:39:57,421 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:39:57,629 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:39:57,696 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:40:02,320 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:40:02,506 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:40:02,689 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:40:02,852 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:40:02,943 - INFO - Successfully processed workspace be770ec6-b0f5-4323-9efd-1554201ff583 with 28 access records
# 2025-05-27 19:40:03,771 - INFO - Processing workspace 3 of 37: 73fac372-490a-4068-a2aa-856837eb6a6b
# 2025-05-27 19:40:03,772 - INFO - Processing workspace: 73fac372-490a-4068-a2aa-856837eb6a6b
# 2025-05-27 19:40:03,772 - INFO - Retrieving access details for workspace: 73fac372-490a-4068-a2aa-856837eb6a6b
# 2025-05-27 19:40:03,773 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/73fac372-490a-4068-a2aa-856837eb6a6b/users with params: None (Attempt 1)
# 2025-05-27 19:40:03,922 - INFO - Response status: 200
# 2025-05-27 19:40:03,923 - INFO - Response contains 5 items in 'accessDetails' array
# 2025-05-27 19:40:03,926 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:40:03,926 - INFO - Retrieved 5 access details for workspace 73fac372-490a-4068-a2aa-856837eb6a6b
# 2025-05-27 19:40:03,926 - INFO - Sample access detail: {
#   "principal": {
#     "id": "1e64ce24-44d8-432a-8097-846181dc3193",
#     "displayName": "Tevie Son",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "TTSon@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:40:03,927 - INFO - Creating core access DataFrame
# 2025-05-27 19:40:03,998 - INFO - Created core access DataFrame with 5 records
# 2025-05-27 19:40:03,999 - INFO - Creating user details DataFrame
# 2025-05-27 19:40:04,068 - INFO - Created user details DataFrame with 5 records
# 2025-05-27 19:40:04,069 - INFO - Creating group details DataFrame
# 2025-05-27 19:40:04,070 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:40:04,087 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:40:04,088 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:40:04,105 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:40:04,105 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:40:04,243 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:40:04,299 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:40:08,834 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:40:09,032 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:40:09,093 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:40:14,882 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:40:15,093 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:40:15,257 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:40:15,467 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:40:15,619 - INFO - Successfully processed workspace 73fac372-490a-4068-a2aa-856837eb6a6b with 5 access records
# 2025-05-27 19:40:16,352 - INFO - Processing workspace 4 of 37: 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-05-27 19:40:16,353 - INFO - Processing workspace: 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-05-27 19:40:16,353 - INFO - Retrieving access details for workspace: 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-05-27 19:40:16,354 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/0ce709ca-36e5-41a1-a318-119dcb311247/users with params: None (Attempt 1)
# 2025-05-27 19:40:16,504 - INFO - Response status: 200
# 2025-05-27 19:40:16,505 - INFO - Response contains 38 items in 'accessDetails' array
# 2025-05-27 19:40:16,508 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:40:16,509 - INFO - Retrieved 38 access details for workspace 0ce709ca-36e5-41a1-a318-119dcb311247
# 2025-05-27 19:40:16,510 - INFO - Sample access detail: {
#   "principal": {
#     "id": "67a46eff-10d7-4cd2-9ef2-bea43635d331",
#     "displayName": "James DeLoach",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "JBDeLoach@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Contributor"
#   }
# }
# 2025-05-27 19:40:16,510 - INFO - Creating core access DataFrame
# 2025-05-27 19:40:16,584 - INFO - Created core access DataFrame with 38 records
# 2025-05-27 19:40:16,585 - INFO - Creating user details DataFrame
# 2025-05-27 19:40:16,654 - INFO - Created user details DataFrame with 38 records
# 2025-05-27 19:40:16,655 - INFO - Creating group details DataFrame
# 2025-05-27 19:40:16,656 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:40:16,671 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:40:16,671 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:40:16,688 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:40:16,689 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:40:16,837 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:40:16,900 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:40:21,174 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:40:21,399 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:40:21,453 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:40:27,450 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:40:27,644 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:40:27,800 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:40:27,947 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:40:28,038 - INFO - Successfully processed workspace 0ce709ca-36e5-41a1-a318-119dcb311247 with 38 access records
# 2025-05-27 19:40:28,768 - INFO - Processing workspace 5 of 37: 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8
# 2025-05-27 19:40:28,769 - INFO - Processing workspace: 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8
# 2025-05-27 19:40:28,769 - INFO - Retrieving access details for workspace: 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8
# 2025-05-27 19:40:28,770 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/50fefe6b-4bba-4e4c-a239-ec9e4de21ea8/users with params: None (Attempt 1)
# 2025-05-27 19:40:29,007 - INFO - Response status: 200
# 2025-05-27 19:40:29,008 - INFO - Response contains 17 items in 'accessDetails' array
# 2025-05-27 19:40:29,011 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:40:29,011 - INFO - Retrieved 17 access details for workspace 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8
# 2025-05-27 19:40:29,012 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:40:29,012 - INFO - Creating core access DataFrame
# 2025-05-27 19:40:29,077 - INFO - Created core access DataFrame with 17 records
# 2025-05-27 19:40:29,078 - INFO - Creating user details DataFrame
# 2025-05-27 19:40:29,149 - INFO - Created user details DataFrame with 16 records
# 2025-05-27 19:40:29,150 - INFO - Creating group details DataFrame
# 2025-05-27 19:40:29,208 - INFO - Created group details DataFrame with 1 records
# 2025-05-27 19:40:29,209 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:40:29,210 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:40:29,224 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:40:29,225 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:40:29,362 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:40:29,428 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:40:33,600 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:40:33,794 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:40:33,862 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:40:39,377 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:40:39,574 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:40:39,616 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-05-27 19:40:43,242 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-05-27 19:40:43,414 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:40:43,555 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:40:43,634 - INFO - Successfully processed workspace 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8 with 17 access records
# 2025-05-27 19:40:44,381 - INFO - Processing workspace 6 of 37: 26795226-4c6a-4624-a7c2-6ae70d4f8557
# 2025-05-27 19:40:44,382 - INFO - Processing workspace: 26795226-4c6a-4624-a7c2-6ae70d4f8557
# 2025-05-27 19:40:44,382 - INFO - Retrieving access details for workspace: 26795226-4c6a-4624-a7c2-6ae70d4f8557
# 2025-05-27 19:40:44,382 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/26795226-4c6a-4624-a7c2-6ae70d4f8557/users with params: None (Attempt 1)
# 2025-05-27 19:40:44,516 - INFO - Response status: 200
# 2025-05-27 19:40:44,517 - INFO - Response contains 9 items in 'accessDetails' array
# 2025-05-27 19:40:44,520 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:40:44,520 - INFO - Retrieved 9 access details for workspace 26795226-4c6a-4624-a7c2-6ae70d4f8557
# 2025-05-27 19:40:44,521 - INFO - Sample access detail: {
#   "principal": {
#     "id": "c50923ec-165d-4a96-8c91-f9001289b11f",
#     "displayName": "Jaymeen Patel",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "JKPatel1@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:40:44,521 - INFO - Creating core access DataFrame
# 2025-05-27 19:40:44,587 - INFO - Created core access DataFrame with 9 records
# 2025-05-27 19:40:44,588 - INFO - Creating user details DataFrame
# 2025-05-27 19:40:44,647 - INFO - Created user details DataFrame with 5 records
# 2025-05-27 19:40:44,647 - INFO - Creating group details DataFrame
# 2025-05-27 19:40:44,711 - INFO - Created group details DataFrame with 4 records
# 2025-05-27 19:40:44,712 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:40:44,712 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:40:44,728 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:40:44,729 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:40:44,888 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:40:44,937 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:40:48,829 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:40:49,005 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:40:49,053 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:40:54,005 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:40:54,192 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:40:54,245 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-05-27 19:40:57,779 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-05-27 19:40:57,932 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:40:58,077 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:40:58,160 - INFO - Successfully processed workspace 26795226-4c6a-4624-a7c2-6ae70d4f8557 with 9 access records
# 2025-05-27 19:40:58,897 - INFO - Processing workspace 7 of 37: f9f25eb2-e5ee-49c5-b734-f16a9d06cc46
# 2025-05-27 19:40:58,898 - INFO - Processing workspace: f9f25eb2-e5ee-49c5-b734-f16a9d06cc46
# 2025-05-27 19:40:58,898 - INFO - Retrieving access details for workspace: f9f25eb2-e5ee-49c5-b734-f16a9d06cc46
# 2025-05-27 19:40:58,899 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/f9f25eb2-e5ee-49c5-b734-f16a9d06cc46/users with params: None (Attempt 1)
# 2025-05-27 19:40:59,143 - INFO - Response status: 200
# 2025-05-27 19:40:59,144 - INFO - Response contains 9 items in 'accessDetails' array
# 2025-05-27 19:40:59,147 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:40:59,147 - INFO - Retrieved 9 access details for workspace f9f25eb2-e5ee-49c5-b734-f16a9d06cc46
# 2025-05-27 19:40:59,148 - INFO - Sample access detail: {
#   "principal": {
#     "id": "26e70876-47e5-4c09-b907-8df99e990b62",
#     "displayName": "Spiwe Mazunga",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "SMazunga@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:40:59,148 - INFO - Creating core access DataFrame
# 2025-05-27 19:40:59,218 - INFO - Created core access DataFrame with 9 records
# 2025-05-27 19:40:59,218 - INFO - Creating user details DataFrame
# 2025-05-27 19:40:59,284 - INFO - Created user details DataFrame with 9 records
# 2025-05-27 19:40:59,285 - INFO - Creating group details DataFrame
# 2025-05-27 19:40:59,285 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:40:59,299 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:40:59,299 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:40:59,311 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:40:59,312 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:40:59,438 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:40:59,496 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:41:03,282 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:41:03,446 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:41:03,507 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:41:07,857 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:41:08,032 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:41:08,171 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:41:08,304 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:41:08,446 - INFO - Successfully processed workspace f9f25eb2-e5ee-49c5-b734-f16a9d06cc46 with 9 access records
# 2025-05-27 19:41:09,165 - INFO - Processing workspace 8 of 37: 5e0c2947-af05-4183-8772-3b1d1105d32a
# 2025-05-27 19:41:09,166 - INFO - Processing workspace: 5e0c2947-af05-4183-8772-3b1d1105d32a
# 2025-05-27 19:41:09,166 - INFO - Retrieving access details for workspace: 5e0c2947-af05-4183-8772-3b1d1105d32a
# 2025-05-27 19:41:09,167 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/5e0c2947-af05-4183-8772-3b1d1105d32a/users with params: None (Attempt 1)
# 2025-05-27 19:41:09,300 - INFO - Response status: 200
# 2025-05-27 19:41:09,301 - INFO - Response contains 0 items in 'accessDetails' array
# 2025-05-27 19:41:09,304 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:41:09,304 - WARNING - No access details found for workspace 5e0c2947-af05-4183-8772-3b1d1105d32a
# 2025-05-27 19:41:09,305 - WARNING - No access details found for workspace 5e0c2947-af05-4183-8772-3b1d1105d32a
# 2025-05-27 19:41:09,806 - INFO - Processing workspace 9 of 37: e79933b9-9b89-498b-b764-4176a4a99a54
# 2025-05-27 19:41:09,806 - INFO - Processing workspace: e79933b9-9b89-498b-b764-4176a4a99a54
# 2025-05-27 19:41:09,806 - INFO - Retrieving access details for workspace: e79933b9-9b89-498b-b764-4176a4a99a54
# 2025-05-27 19:41:09,807 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/e79933b9-9b89-498b-b764-4176a4a99a54/users with params: None (Attempt 1)
# 2025-05-27 19:41:10,018 - INFO - Response status: 200
# 2025-05-27 19:41:10,019 - INFO - Response contains 2 items in 'accessDetails' array
# 2025-05-27 19:41:10,021 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:41:10,022 - INFO - Retrieved 2 access details for workspace e79933b9-9b89-498b-b764-4176a4a99a54
# 2025-05-27 19:41:10,023 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:41:10,024 - INFO - Creating core access DataFrame
# 2025-05-27 19:41:10,084 - INFO - Created core access DataFrame with 2 records
# 2025-05-27 19:41:10,085 - INFO - Creating user details DataFrame
# 2025-05-27 19:41:10,145 - INFO - Created user details DataFrame with 2 records
# 2025-05-27 19:41:10,146 - INFO - Creating group details DataFrame
# 2025-05-27 19:41:10,146 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:41:10,160 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:41:10,161 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:41:10,171 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:41:10,172 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:41:10,304 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:41:10,345 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:41:14,284 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:41:14,851 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:41:14,893 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:41:19,028 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:41:19,178 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:41:19,312 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:41:19,447 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:41:19,523 - INFO - Successfully processed workspace e79933b9-9b89-498b-b764-4176a4a99a54 with 2 access records
# 2025-05-27 19:41:20,196 - INFO - Processing workspace 10 of 37: 36736283-6d3a-4ff9-a414-9befe32f4d68
# 2025-05-27 19:41:20,196 - INFO - Processing workspace: 36736283-6d3a-4ff9-a414-9befe32f4d68
# 2025-05-27 19:41:20,197 - INFO - Retrieving access details for workspace: 36736283-6d3a-4ff9-a414-9befe32f4d68
# 2025-05-27 19:41:20,197 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/36736283-6d3a-4ff9-a414-9befe32f4d68/users with params: None (Attempt 1)
# 2025-05-27 19:41:20,333 - INFO - Response status: 200
# 2025-05-27 19:41:20,333 - INFO - Response contains 2 items in 'accessDetails' array
# 2025-05-27 19:41:20,337 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:41:20,337 - INFO - Retrieved 2 access details for workspace 36736283-6d3a-4ff9-a414-9befe32f4d68
# 2025-05-27 19:41:20,337 - INFO - Sample access detail: {
#   "principal": {
#     "id": "1e64ce24-44d8-432a-8097-846181dc3193",
#     "displayName": "Tevie Son",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "TTSon@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:41:20,338 - INFO - Creating core access DataFrame
# 2025-05-27 19:41:20,398 - INFO - Created core access DataFrame with 2 records
# 2025-05-27 19:41:20,399 - INFO - Creating user details DataFrame
# 2025-05-27 19:41:20,455 - INFO - Created user details DataFrame with 2 records
# 2025-05-27 19:41:20,456 - INFO - Creating group details DataFrame
# 2025-05-27 19:41:20,456 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:41:20,469 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:41:20,469 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:41:20,483 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:41:20,484 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:41:20,636 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:41:20,675 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:41:26,915 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:41:27,670 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:41:27,714 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:41:34,385 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:41:34,581 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:41:34,743 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:41:34,884 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:41:34,977 - INFO - Successfully processed workspace 36736283-6d3a-4ff9-a414-9befe32f4d68 with 2 access records
# 2025-05-27 19:41:35,690 - INFO - Processing workspace 11 of 37: 685dd153-6949-46e6-a370-f512f79d092c
# 2025-05-27 19:41:35,690 - INFO - Processing workspace: 685dd153-6949-46e6-a370-f512f79d092c
# 2025-05-27 19:41:35,691 - INFO - Retrieving access details for workspace: 685dd153-6949-46e6-a370-f512f79d092c
# 2025-05-27 19:41:35,691 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/685dd153-6949-46e6-a370-f512f79d092c/users with params: None (Attempt 1)
# 2025-05-27 19:41:35,920 - INFO - Response status: 200
# 2025-05-27 19:41:35,920 - INFO - Response contains 1 items in 'accessDetails' array
# 2025-05-27 19:41:35,923 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:41:35,924 - INFO - Retrieved 1 access details for workspace 685dd153-6949-46e6-a370-f512f79d092c
# 2025-05-27 19:41:35,924 - INFO - Sample access detail: {
#   "principal": {
#     "id": "30e97b16-d758-4871-83ee-ac59ec8fa753",
#     "displayName": "Amber Stokes",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "ALStokes@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:41:35,925 - INFO - Creating core access DataFrame
# 2025-05-27 19:41:35,978 - INFO - Created core access DataFrame with 1 records
# 2025-05-27 19:41:35,979 - INFO - Creating user details DataFrame
# 2025-05-27 19:41:36,048 - INFO - Created user details DataFrame with 1 records
# 2025-05-27 19:41:36,049 - INFO - Creating group details DataFrame
# 2025-05-27 19:41:36,049 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:41:36,062 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:41:36,062 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:41:36,073 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:41:36,074 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:41:36,435 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:41:36,483 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:42:19,108 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:42:19,596 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:42:19,656 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:42:27,314 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:42:28,114 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:42:28,249 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:42:28,375 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:42:28,456 - INFO - Successfully processed workspace 685dd153-6949-46e6-a370-f512f79d092c with 1 access records
# 2025-05-27 19:42:29,151 - INFO - Processing workspace 12 of 37: e99a2369-a622-4efe-a594-905add02659d
# 2025-05-27 19:42:29,152 - INFO - Processing workspace: e99a2369-a622-4efe-a594-905add02659d
# 2025-05-27 19:42:29,153 - INFO - Retrieving access details for workspace: e99a2369-a622-4efe-a594-905add02659d
# 2025-05-27 19:42:29,153 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/e99a2369-a622-4efe-a594-905add02659d/users with params: None (Attempt 1)
# 2025-05-27 19:42:29,376 - INFO - Response status: 200
# 2025-05-27 19:42:29,377 - INFO - Response contains 14 items in 'accessDetails' array
# 2025-05-27 19:42:29,379 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:42:29,380 - INFO - Retrieved 14 access details for workspace e99a2369-a622-4efe-a594-905add02659d
# 2025-05-27 19:42:29,380 - INFO - Sample access detail: {
#   "principal": {
#     "id": "12e387e0-e8cd-493f-84ce-73669e6e00d3",
#     "displayName": "Omer Piperdi",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "OAPiperdi@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:42:29,380 - INFO - Creating core access DataFrame
# 2025-05-27 19:42:29,458 - INFO - Created core access DataFrame with 14 records
# 2025-05-27 19:42:29,459 - INFO - Creating user details DataFrame
# 2025-05-27 19:42:29,532 - INFO - Created user details DataFrame with 13 records
# 2025-05-27 19:42:29,532 - INFO - Creating group details DataFrame
# 2025-05-27 19:42:29,595 - INFO - Created group details DataFrame with 1 records
# 2025-05-27 19:42:29,596 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:42:29,596 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:42:29,610 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:42:29,610 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:42:29,745 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:42:29,806 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:42:34,326 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:42:34,531 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:42:34,590 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:42:39,135 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:42:39,319 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:42:39,371 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-05-27 19:42:43,008 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-05-27 19:42:43,173 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:42:43,317 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:42:43,397 - INFO - Successfully processed workspace e99a2369-a622-4efe-a594-905add02659d with 14 access records
# 2025-05-27 19:42:44,092 - INFO - Processing workspace 13 of 37: 94a8bbe6-8b2c-48c5-9a2c-c1235f42002e
# 2025-05-27 19:42:44,093 - INFO - Processing workspace: 94a8bbe6-8b2c-48c5-9a2c-c1235f42002e
# 2025-05-27 19:42:44,093 - INFO - Retrieving access details for workspace: 94a8bbe6-8b2c-48c5-9a2c-c1235f42002e
# 2025-05-27 19:42:44,094 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/94a8bbe6-8b2c-48c5-9a2c-c1235f42002e/users with params: None (Attempt 1)
# 2025-05-27 19:42:44,314 - INFO - Response status: 200
# 2025-05-27 19:42:44,314 - INFO - Response contains 4 items in 'accessDetails' array
# 2025-05-27 19:42:44,317 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:42:44,317 - INFO - Retrieved 4 access details for workspace 94a8bbe6-8b2c-48c5-9a2c-c1235f42002e
# 2025-05-27 19:42:44,317 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:42:44,318 - INFO - Creating core access DataFrame
# 2025-05-27 19:42:44,387 - INFO - Created core access DataFrame with 4 records
# 2025-05-27 19:42:44,387 - INFO - Creating user details DataFrame
# 2025-05-27 19:42:44,442 - INFO - Created user details DataFrame with 4 records
# 2025-05-27 19:42:44,442 - INFO - Creating group details DataFrame
# 2025-05-27 19:42:44,443 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:42:44,456 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:42:44,457 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:42:44,468 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:42:44,468 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:42:44,600 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:42:44,646 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:42:48,289 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:42:48,458 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:42:48,506 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:42:52,379 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:42:52,571 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:42:52,712 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:42:52,841 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:42:52,913 - INFO - Successfully processed workspace 94a8bbe6-8b2c-48c5-9a2c-c1235f42002e with 4 access records
# 2025-05-27 19:42:53,650 - INFO - Processing workspace 14 of 37: dd33a385-a2a5-436e-93fa-ee247f6a3fac
# 2025-05-27 19:42:53,651 - INFO - Processing workspace: dd33a385-a2a5-436e-93fa-ee247f6a3fac
# 2025-05-27 19:42:53,651 - INFO - Retrieving access details for workspace: dd33a385-a2a5-436e-93fa-ee247f6a3fac
# 2025-05-27 19:42:53,651 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/dd33a385-a2a5-436e-93fa-ee247f6a3fac/users with params: None (Attempt 1)
# 2025-05-27 19:42:53,888 - INFO - Response status: 200
# 2025-05-27 19:42:53,889 - INFO - Response contains 3 items in 'accessDetails' array
# 2025-05-27 19:42:53,892 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:42:53,892 - INFO - Retrieved 3 access details for workspace dd33a385-a2a5-436e-93fa-ee247f6a3fac
# 2025-05-27 19:42:53,893 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:42:53,893 - INFO - Creating core access DataFrame
# 2025-05-27 19:42:53,959 - INFO - Created core access DataFrame with 3 records
# 2025-05-27 19:42:53,960 - INFO - Creating user details DataFrame
# 2025-05-27 19:42:54,026 - INFO - Created user details DataFrame with 3 records
# 2025-05-27 19:42:54,027 - INFO - Creating group details DataFrame
# 2025-05-27 19:42:54,028 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:42:54,041 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:42:54,041 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:42:54,052 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:42:54,052 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:42:54,177 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:42:54,230 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:42:58,180 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:42:58,355 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:42:58,394 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:43:02,947 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:43:03,111 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:43:03,250 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:43:03,398 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:43:03,474 - INFO - Successfully processed workspace dd33a385-a2a5-436e-93fa-ee247f6a3fac with 3 access records
# 2025-05-27 19:43:04,154 - INFO - Processing workspace 15 of 37: 12abcfaa-3c5f-4bce-a1f4-2d930e413275
# 2025-05-27 19:43:04,155 - INFO - Processing workspace: 12abcfaa-3c5f-4bce-a1f4-2d930e413275
# 2025-05-27 19:43:04,155 - INFO - Retrieving access details for workspace: 12abcfaa-3c5f-4bce-a1f4-2d930e413275
# 2025-05-27 19:43:04,155 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/12abcfaa-3c5f-4bce-a1f4-2d930e413275/users with params: None (Attempt 1)
# 2025-05-27 19:43:04,298 - INFO - Response status: 200
# 2025-05-27 19:43:04,299 - INFO - Response contains 6 items in 'accessDetails' array
# 2025-05-27 19:43:04,302 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:43:04,302 - INFO - Retrieved 6 access details for workspace 12abcfaa-3c5f-4bce-a1f4-2d930e413275
# 2025-05-27 19:43:04,303 - INFO - Sample access detail: {
#   "principal": {
#     "id": "651cd702-2932-4eac-90d8-9dc769619d5a",
#     "displayName": "Whitney McClain",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bmcclain@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:43:04,303 - INFO - Creating core access DataFrame
# 2025-05-27 19:43:04,361 - INFO - Created core access DataFrame with 6 records
# 2025-05-27 19:43:04,361 - INFO - Creating user details DataFrame
# 2025-05-27 19:43:04,420 - INFO - Created user details DataFrame with 6 records
# 2025-05-27 19:43:04,421 - INFO - Creating group details DataFrame
# 2025-05-27 19:43:04,422 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:43:04,433 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:43:04,434 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:43:04,444 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:43:04,444 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:43:04,566 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:43:04,609 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:43:08,004 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:43:08,160 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:43:08,202 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:43:12,494 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:43:12,639 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:43:12,766 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:43:12,909 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:43:13,017 - INFO - Successfully processed workspace 12abcfaa-3c5f-4bce-a1f4-2d930e413275 with 6 access records
# 2025-05-27 19:43:13,775 - INFO - Processing workspace 16 of 37: 5d190284-0524-4c74-8389-c36e173fd290
# 2025-05-27 19:43:13,776 - INFO - Processing workspace: 5d190284-0524-4c74-8389-c36e173fd290
# 2025-05-27 19:43:13,776 - INFO - Retrieving access details for workspace: 5d190284-0524-4c74-8389-c36e173fd290
# 2025-05-27 19:43:13,776 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/5d190284-0524-4c74-8389-c36e173fd290/users with params: None (Attempt 1)
# 2025-05-27 19:43:14,030 - INFO - Response status: 200
# 2025-05-27 19:43:14,030 - INFO - Response contains 29 items in 'accessDetails' array
# 2025-05-27 19:43:14,034 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:43:14,034 - INFO - Retrieved 29 access details for workspace 5d190284-0524-4c74-8389-c36e173fd290
# 2025-05-27 19:43:14,035 - INFO - Sample access detail: {
#   "principal": {
#     "id": "efffae68-f4de-48e2-a47a-e3f813820089",
#     "displayName": "Netri Mehta",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "nmehta@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:43:14,035 - INFO - Creating core access DataFrame
# 2025-05-27 19:43:14,174 - INFO - Created core access DataFrame with 29 records
# 2025-05-27 19:43:14,175 - INFO - Creating user details DataFrame
# 2025-05-27 19:43:14,293 - INFO - Created user details DataFrame with 29 records
# 2025-05-27 19:43:14,294 - INFO - Creating group details DataFrame
# 2025-05-27 19:43:14,294 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:43:14,307 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:43:14,307 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:43:14,318 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:43:14,319 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:43:15,547 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:43:15,594 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:43:18,934 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:43:19,139 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:43:19,204 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:43:23,561 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:43:23,821 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:43:23,953 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:43:24,084 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# ...
# 2025-05-27 19:46:26,451 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:46:26,804 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:46:26,844 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:46:30,065 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:46:30,205 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:46:30,249 - INFO - Starting merge operation for fabric_workspaces_access_groups
# 2025-05-27 19:46:33,320 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_groups
# 2025-05-27 19:46:34,221 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:46:34,339 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:46:34,401 - INFO - Successfully processed workspace e0690bc6-df24-41d8-87d7-1c6c16d18970 with 2 access records
# 2025-05-27 19:46:35,062 - INFO - Processing workspace 34 of 37: 8dc44572-000d-45f4-9dee-b9a1b01af73f
# 2025-05-27 19:46:35,063 - INFO - Processing workspace: 8dc44572-000d-45f4-9dee-b9a1b01af73f
# 2025-05-27 19:46:35,064 - INFO - Retrieving access details for workspace: 8dc44572-000d-45f4-9dee-b9a1b01af73f
# 2025-05-27 19:46:35,064 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/8dc44572-000d-45f4-9dee-b9a1b01af73f/users with params: None (Attempt 1)
# 2025-05-27 19:46:35,274 - INFO - Response status: 200
# 2025-05-27 19:46:35,274 - INFO - Response contains 5 items in 'accessDetails' array
# 2025-05-27 19:46:35,277 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:46:35,278 - INFO - Retrieved 5 access details for workspace 8dc44572-000d-45f4-9dee-b9a1b01af73f
# 2025-05-27 19:46:35,279 - INFO - Sample access detail: {
#   "principal": {
#     "id": "f12096e4-4ee8-4adc-8f64-1b25cc463fc4",
#     "displayName": "Brent Hand",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "bwhand@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:46:35,279 - INFO - Creating core access DataFrame
# 2025-05-27 19:46:35,360 - INFO - Created core access DataFrame with 5 records
# 2025-05-27 19:46:35,361 - INFO - Creating user details DataFrame
# 2025-05-27 19:46:35,419 - INFO - Created user details DataFrame with 5 records
# 2025-05-27 19:46:35,420 - INFO - Creating group details DataFrame
# 2025-05-27 19:46:35,421 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:46:35,434 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:46:35,435 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:46:35,446 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:46:35,447 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:46:35,590 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:46:35,625 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:46:38,917 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:46:39,060 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:46:39,101 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:46:42,984 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:46:43,132 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:46:43,257 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:46:43,407 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:46:43,493 - INFO - Successfully processed workspace 8dc44572-000d-45f4-9dee-b9a1b01af73f with 5 access records
# 2025-05-27 19:46:44,153 - INFO - Processing workspace 35 of 37: c0753fb8-05d6-4e4f-ab16-4758be11c41e
# 2025-05-27 19:46:44,154 - INFO - Processing workspace: c0753fb8-05d6-4e4f-ab16-4758be11c41e
# 2025-05-27 19:46:44,154 - INFO - Retrieving access details for workspace: c0753fb8-05d6-4e4f-ab16-4758be11c41e
# 2025-05-27 19:46:44,155 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/c0753fb8-05d6-4e4f-ab16-4758be11c41e/users with params: None (Attempt 1)
# 2025-05-27 19:46:44,288 - INFO - Response status: 200
# 2025-05-27 19:46:44,288 - INFO - Response contains 0 items in 'accessDetails' array
# 2025-05-27 19:46:44,291 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:46:44,292 - WARNING - No access details found for workspace c0753fb8-05d6-4e4f-ab16-4758be11c41e
# 2025-05-27 19:46:44,292 - WARNING - No access details found for workspace c0753fb8-05d6-4e4f-ab16-4758be11c41e
# 2025-05-27 19:46:44,793 - INFO - Processing workspace 36 of 37: 4b33c59d-a69e-4bf3-b555-e515530d3e70
# 2025-05-27 19:46:44,793 - INFO - Processing workspace: 4b33c59d-a69e-4bf3-b555-e515530d3e70
# 2025-05-27 19:46:44,794 - INFO - Retrieving access details for workspace: 4b33c59d-a69e-4bf3-b555-e515530d3e70
# 2025-05-27 19:46:44,794 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/4b33c59d-a69e-4bf3-b555-e515530d3e70/users with params: None (Attempt 1)
# 2025-05-27 19:46:45,032 - INFO - Response status: 200
# 2025-05-27 19:46:45,032 - INFO - Response contains 3 items in 'accessDetails' array
# 2025-05-27 19:46:45,034 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:46:45,035 - INFO - Retrieved 3 access details for workspace 4b33c59d-a69e-4bf3-b555-e515530d3e70
# 2025-05-27 19:46:45,035 - INFO - Sample access detail: {
#   "principal": {
#     "id": "d87d15b5-62cd-41e0-87fd-92329908fadb",
#     "displayName": "Rey Allen Gatilao",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "rgatilao@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:46:45,036 - INFO - Creating core access DataFrame
# 2025-05-27 19:46:45,090 - INFO - Created core access DataFrame with 3 records
# 2025-05-27 19:46:45,091 - INFO - Creating user details DataFrame
# 2025-05-27 19:46:45,140 - INFO - Created user details DataFrame with 3 records
# 2025-05-27 19:46:45,140 - INFO - Creating group details DataFrame
# 2025-05-27 19:46:45,141 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:46:45,152 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:46:45,153 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:46:45,164 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:46:45,164 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:46:45,326 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:46:45,369 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:46:48,961 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:46:49,100 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:46:49,144 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:46:52,927 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:46:53,088 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:46:53,216 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:46:53,332 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:46:53,396 - INFO - Successfully processed workspace 4b33c59d-a69e-4bf3-b555-e515530d3e70 with 3 access records
# 2025-05-27 19:46:54,044 - INFO - Processing workspace 37 of 37: cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-05-27 19:46:54,045 - INFO - Processing workspace: cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-05-27 19:46:54,045 - INFO - Retrieving access details for workspace: cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-05-27 19:46:54,046 - INFO - Making API call to: https://api.fabric.microsoft.com/v1/admin/workspaces/cd9d5418-e35d-400e-938d-ea91ea486e07/users with params: None (Attempt 1)
# 2025-05-27 19:46:54,274 - INFO - Response status: 200
# 2025-05-27 19:46:54,275 - INFO - Response contains 8 items in 'accessDetails' array
# 2025-05-27 19:46:54,278 - INFO - Response keys: ['accessDetails']
# 2025-05-27 19:46:54,278 - INFO - Retrieved 8 access details for workspace cd9d5418-e35d-400e-938d-ea91ea486e07
# 2025-05-27 19:46:54,279 - INFO - Sample access detail: {
#   "principal": {
#     "id": "c84e2798-cb31-43e5-bb8d-d1d0b8d941b4",
#     "displayName": "AVJoshi Joshi",
#     "type": "User",
#     "userDetails": {
#       "userPrincipalName": "AVJoshi-mda@mdanderson.org"
#     }
#   },
#   "workspaceAccessDetails": {
#     "type": "Workspace",
#     "workspaceRole": "Admin"
#   }
# }
# 2025-05-27 19:46:54,279 - INFO - Creating core access DataFrame
# 2025-05-27 19:46:54,335 - INFO - Created core access DataFrame with 8 records
# 2025-05-27 19:46:54,336 - INFO - Creating user details DataFrame
# 2025-05-27 19:46:54,386 - INFO - Created user details DataFrame with 8 records
# 2025-05-27 19:46:54,386 - INFO - Creating group details DataFrame
# 2025-05-27 19:46:54,387 - INFO - No group principals found. Creating empty group details DataFrame.
# 2025-05-27 19:46:54,398 - INFO - Creating service principal details DataFrame
# 2025-05-27 19:46:54,399 - INFO - No service principals found. Creating empty service principal details DataFrame.
# 2025-05-27 19:46:54,408 - INFO - Creating service principal profile details DataFrame
# 2025-05-27 19:46:54,408 - INFO - No service principal profiles found. Creating empty service principal profile details DataFrame.
# 2025-05-27 19:46:54,532 - INFO - Delta table 'fabric_workspaces_access_core' already exists
# 2025-05-27 19:46:54,574 - INFO - Starting merge operation for fabric_workspaces_access_core
# 2025-05-27 19:46:58,352 - INFO - Core access merge operation completed successfully
# 2025-05-27 19:46:58,518 - INFO - Delta table 'fabric_workspaces_access_users' already exists
# 2025-05-27 19:46:58,630 - INFO - Starting merge operation for fabric_workspaces_access_users
# 2025-05-27 19:47:02,497 - INFO - Principal details merge operation completed successfully for fabric_workspaces_access_users
# 2025-05-27 19:47:02,670 - INFO - Delta table 'fabric_workspaces_access_groups' already exists
# 2025-05-27 19:47:02,797 - INFO - Delta table 'fabric_workspaces_access_service_principals' already exists
# 2025-05-27 19:47:02,923 - INFO - Delta table 'fabric_workspaces_access_service_principal_profiles' already exists
# 2025-05-27 19:47:02,994 - INFO - Successfully processed workspace cd9d5418-e35d-400e-938d-ea91ea486e07 with 8 access records
# 2025-05-27 19:47:03,161 - INFO - ============================================================
# 2025-05-27 19:47:03,161 - INFO - PROCESSING COMPLETED
# 2025-05-27 19:47:03,162 - INFO - ============================================================
# 2025-05-27 19:47:03,163 - INFO - Total workspaces processed: 37
# 2025-05-27 19:47:03,163 - INFO - Successful: 35
# 2025-05-27 19:47:03,164 - INFO - Failed: 0
# 2025-05-27 19:47:03,165 - INFO - No data: 2
# 2025-05-27 19:47:03,165 - INFO - Total access records processed: 387
# 2025-05-27 19:47:03,166 - INFO -
# === DELTA TABLE STATISTICS ===
# 2025-05-27 19:47:04,209 - INFO - fabric_workspaces_access_core: 399 rows
# 2025-05-27 19:47:05,253 - INFO - fabric_workspaces_access_users: 255 rows
# 2025-05-27 19:47:06,301 - INFO - fabric_workspaces_access_groups: 14 rows
# 2025-05-27 19:47:07,138 - INFO - fabric_workspaces_access_service_principals: 4 rows
# 2025-05-27 19:47:08,078 - INFO - fabric_workspaces_access_service_principal_profiles: 0 rows
# 2025-05-27 19:47:08,079 - INFO -
# === OPTIMIZING DELTA TABLES ===
# 2025-05-27 19:47:08,080 - INFO - Optimizing Delta table 'fabric_workspaces_access_core'
# 2025-05-27 19:47:09,241 - INFO - Table statistics updated successfully for fabric_workspaces_access_core
# 2025-05-27 19:47:09,242 - INFO - Delta table optimization completed for fabric_workspaces_access_core
# 2025-05-27 19:47:09,243 - INFO - Optimizing Delta table 'fabric_workspaces_access_users'
# 2025-05-27 19:47:10,169 - INFO - Table statistics updated successfully for fabric_workspaces_access_users
# 2025-05-27 19:47:10,170 - INFO - Delta table optimization completed for fabric_workspaces_access_users
# 2025-05-27 19:47:10,170 - INFO - Optimizing Delta table 'fabric_workspaces_access_groups'
# 2025-05-27 19:47:11,060 - INFO - Table statistics updated successfully for fabric_workspaces_access_groups
# 2025-05-27 19:47:11,060 - INFO - Delta table optimization completed for fabric_workspaces_access_groups
# 2025-05-27 19:47:11,061 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principals'
# 2025-05-27 19:47:11,789 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principals
# 2025-05-27 19:47:11,790 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principals
# 2025-05-27 19:47:11,790 - INFO - Optimizing Delta table 'fabric_workspaces_access_service_principal_profiles'
# 2025-05-27 19:47:12,539 - INFO - Table statistics updated successfully for fabric_workspaces_access_service_principal_profiles
# 2025-05-27 19:47:12,540 - INFO - Delta table optimization completed for fabric_workspaces_access_service_principal_profiles
# 2025-05-27 19:47:12,541 - INFO -
# === DETAILED PROCESSING RESULTS ===
# 2025-05-27 19:47:12,541 - INFO - Workspace 263575b7-d1ee-4dcc-bd05-ca67158e1bb4: success
# 2025-05-27 19:47:12,542 - INFO -   - Records: 4
# 2025-05-27 19:47:12,542 - INFO -   - Users: 4
# 2025-05-27 19:47:12,543 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,543 - INFO - Workspace be770ec6-b0f5-4323-9efd-1554201ff583: success
# 2025-05-27 19:47:12,543 - INFO -   - Records: 28
# 2025-05-27 19:47:12,544 - INFO -   - Users: 28
# 2025-05-27 19:47:12,545 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,545 - INFO - Workspace 73fac372-490a-4068-a2aa-856837eb6a6b: success
# 2025-05-27 19:47:12,546 - INFO -   - Records: 5
# 2025-05-27 19:47:12,546 - INFO -   - Users: 5
# 2025-05-27 19:47:12,547 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,547 - INFO - Workspace 0ce709ca-36e5-41a1-a318-119dcb311247: success
# 2025-05-27 19:47:12,548 - INFO -   - Records: 38
# 2025-05-27 19:47:12,548 - INFO -   - Users: 38
# 2025-05-27 19:47:12,549 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,549 - INFO - Workspace 50fefe6b-4bba-4e4c-a239-ec9e4de21ea8: success
# 2025-05-27 19:47:12,549 - INFO -   - Records: 17
# 2025-05-27 19:47:12,550 - INFO -   - Users: 16
# 2025-05-27 19:47:12,550 - INFO -   - Groups: 1
# 2025-05-27 19:47:12,551 - INFO - Workspace 26795226-4c6a-4624-a7c2-6ae70d4f8557: success
# 2025-05-27 19:47:12,551 - INFO -   - Records: 9
# 2025-05-27 19:47:12,552 - INFO -   - Users: 5
# 2025-05-27 19:47:12,552 - INFO -   - Groups: 4
# 2025-05-27 19:47:12,552 - INFO - Workspace f9f25eb2-e5ee-49c5-b734-f16a9d06cc46: success
# 2025-05-27 19:47:12,553 - INFO -   - Records: 9
# 2025-05-27 19:47:12,553 - INFO -   - Users: 9
# 2025-05-27 19:47:12,553 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,554 - INFO - Workspace 5e0c2947-af05-4183-8772-3b1d1105d32a: no_data
# 2025-05-27 19:47:12,554 - INFO - Workspace e79933b9-9b89-498b-b764-4176a4a99a54: success
# 2025-05-27 19:47:12,554 - INFO -   - Records: 2
# 2025-05-27 19:47:12,556 - INFO -   - Users: 2
# 2025-05-27 19:47:12,556 - INFO -   - Groups: 0
# 2025-05-27 19:47:12,557 - INFO - Workspace 36736283-6d3a-4ff9-a414-9befe32f4d68: success
# 2025-05-27 19:47:12,557 - INFO -   - Records: 2
# 2025-05-27 19:47:12,558 - INFO -   - Users: 2
# 2025-05-27 19:47:12,558 - INFO -   - Groups: 0
